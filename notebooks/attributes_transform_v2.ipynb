# %%
import pandas as pd
import pymorphy2 
import json, re

# %%
df_attributes = pd.read_parquet('../data/test/attributes_test.parquet', columns=["variantid", "characteristic_attributes_mapping"], engine='pyarrow')

# %%
df_attributes.head()
# Out:
#    variantid                  characteristic_attributes_mapping
# 0   47920382  {"Цвет товара": ["бежевый", "светло-розовый"],...
# 1   49801845  {"Количество в упаковке, шт": ["1"], "Бренд": ...
# 2   49853444  {"Бренд": ["Vervaco"], "Тип": ["Набор для выши...
# 3   49893028  {"Цвет товара": ["серый"], "Ширина, см": ["0.8...
# 4   49987483  {"Цвет товара": ["разноцветный"], "Название цв...

# %%
def is_number(s):
    try:
        float(s)  # Попробуем преобразовать строку в float
        return True
    except ValueError:
        return False

def get_uniq_attributes(df):
    """
    Функция возвращает dict из уникальных атрибутов

    return: dict

    """
    result_dict = dict()
    for row in df[:]['characteristic_attributes_mapping']:
        #print(row)
        row_dct = json.loads(row)


        for key, val in row_dct.items():
            if result_dict.get(key) is None:
                result_dict[key] = (is_number(val[0]), val)
            elif result_dict.get(key)[0]:
                result_dict[key] = (is_number(val[0]), val)
                
    return result_dict

# %%
uniq_attr = get_uniq_attributes(df_attributes)

# %%
uniq_attr
# Out:
# {'Цвет товара': (False, ['бежевый', 'светло-розовый']),
#  'Пол ребенка': (False, ['Унисекс']),
#  'Бренд': (False, ['Funny Ducks']),
#  'Тип': (False, ['Игрушка для ванной']),
#  'Страна-изготовитель': (False, ['Китай']),
#  'Развитие навыков': (False, ['Воображение', 'Кругозор', 'Моторика']),
#  'Код ТРУ': (False, ['']),
#  'Минимальный возраст ребенка': (False, ['От 3 лет']),
#  'Материал': (False, ['ПВХ пластизоль']),
#  'Вес товара, г': (False, ['подвесная люстра (лампа не в комплекте)']),
#  'Максимальный возраст ребенка': (False, ['До 18 лет']),
#  'Количество в упаковке, шт': (False, ['with a charging case']),
#  'Материалы набора': (False, ['Акрил', 'Бумага', 'Канва', 'Металл', 'Хлопок']),
#  'Техника вышивки': (False, ['Простой крест']),
#  'Возрастные ограничения': (False, ['От 7 лет']),
#  'Длина по горизонтали, см': (False, ['200 мм']),
#  'Длина по вертикали, см': (False, ['200 мм']),
#  'Размеры, мм': (False, ['400 х 400']),
#  'Ширина, см': (False, ['29 см']),
#  'Состав ниток': (False, ['Ткань']),
#  'Длина, м': (False, ['1 м Безэкранный']),
#  'Название цвета': (False, ['мультиколор']),
#  'Минимальная продолжительность партии, мин.': (False, ['30 минут']),
#  'Минимальное число игроков': (False, ['2 - 4 игрока']),
#  'Максимальное число игроков': (False, ['2 - 4 игрока']),
#  'Вид выпуска товара': (False, ['Фабричное производство']),
#  'Целевая аудитория': (False, ['Детская']),
#  'Вид настольной игры': (False, ['Башни и пирамиды']),
#  'Максимальная продолжительность партии, мин.': (True, ['30']),
#  'Целевая аудитория игры': (False, ['Для компании']),
#  'Артикул': (False, ['ОШО 4 - 3 Л']),
#  'Вес, кг': (False, ['Механическое']),
#  'Размерность': (False, ['200x220']),
#  'Материал чехла': (False, ['Поликоттон']),
#  'Материал наполнителя': (False, ['Шерсть']),
#  'Плотность наполнителя, г/м2': (True, ['300']),
#  'Количество предметов в комплекте': (True, ['1']),
#  'Технология пошива': (False, ['Стеганое']),
#  'Комплектация': (False, ['- чайник, 900 мл\n- коробка, картон']),
#  'Объем, мл': (False, ['300 мл']),
#  'Фильтр': (False, ['Механизм «Гунфу»']),
#  'Тип цоколя': (False, ['E14']),
#  'Вид ламп': (False, ['Накаливания']),
#  'Количество ламп, шт': (False,
#   ['Лампа 12V W16W 16W W2,1x9,5d LYNXauto 1 шт. картон L12816']),
#  'Макс. мощность ламп, Вт': (False, ['12W']),
#  'Материал плафона': (False, ['Ткань']),
#  'Вид питания': (False, ['От сети 220В']),
#  'Цвет плафона': (False, ['Бронза']),
#  'Площадь освещения, кв.м': (False, ['15-25']),
#  'Тип выключателя': (False, ['Механический']),
#  'Партномер': (False, ['1274-3T']),
#  'Состав': (False,
#   ['5-15% Anionic Surfactants, <5% Non-Ionic Surfactants, Oxygen-Based Bleaching Agents, Phosphonates, Polycarboxylates, Zeolites, Enzymes, Optical Brighteners, Perfumes']),
#  'Упаковка': (False, ['Пластиковая коробка']),
#  'Назначение средства для стирки': (False, ['Для цветных тканей']),
#  'Название аромата': (False, ['Свежий']),
#  'Аромат': (False, ['Свежий']),
#  'Размер упаковки (Длина х Ширина х Высота), см': (False, ['25 x 22 x 8']),
#  'Вид стирки': (False, ['Автоматическая', 'Ручная']),
#  'Форма выпуска средства': (False, ['Порошок']),
#  'Особенности применения': (False, ['Гипоаллергенность', 'Концентрат']),
#  'Единиц в одном товаре': (False, ['взимание денег']),
#  'Число стирок': (False, ['18 стирок']),
#  'Размерность комплекта': (False, ['2-x спальный']),
#  'Гарантийный срок': (False, ['до 200 стирок']),
#  'Отделка': (False, ['Без отделки']),
#  'Застежка пододеяльника': (False, ['с прорезью']),
#  'Название материала': (False, ['Перкаль']),
#  'Застежка наволочки/чехла': (False, ['с клапаном']),
#  'Образец цвета': (False,
#   ['https://cdn1.ozone.ru/s3/multimedia-v/6234336667.jpg']),
#  'Размер простыни': (False, ['195x220']),
#  'Состав материала': (False, ['Хлопок']),
#  'Размер наволочки': (False, ['70x70']),
#  'Размер пододеяльника': (False, ['185x215']),
#  'Комплектация постельного белья': (False,
#   ['1 пододеяльник, 1 простыня, 2 наволочки']),
#  'Режим стирки': (False, ['При 40 градусах']),
#  'Вид простыни': (False, ['стандартная']),
#  'Размер крышки, см': (False, ['26х26']),
#  'Совместимые плиты': (False,
#   ['Для газовых плит',
#    'Для галогеновых конфорок',
#    'Для индукционных плит',
#    'Для стеклокерамических плит',
#    'Для электрических плит']),
#  'Крышка': (False, ['с крышкой']),
#  'Особенности посуды': (False, ['Крышка в комплекте']),
#  'Диаметр дна, см': (False,
#   ['Бежевый лягушка завтрак горшок (газ) скребок масляная щетка']),
#  'Расход, кг/м2': (True, ['0.35']),
#  'Помещение': (False,
#   ['Для балкона',
#    'Для гостиной',
#    'Для коридора/прихожей',
#    'Для офиса/кабинета']),
#  'Тип помещения': (False,
#   ['С повышенной влажностью', 'С умеренной влажностью', 'Сухое']),
#  'Марка эмали': (False, ['МА-15']),
#  'Количество компонентов': (False, ['Однокомпонентная']),
#  'Возможность колеровки': (False, ['Нет']),
#  'Рекомендуемое количество слоев': (True, ['2']),
#  'Степень блеска покрытия': (False, ['Глянцевое покрытие']),
#  'Время высыхания, часов': (False, ['24 ч']),
#  'Срок годности в днях': (True, ['540']),
#  'Основа краски': (False, ['Масляная']),
#  'Область применения состава': (False,
#   ['Для беседок', 'Для дверей', 'Для дерева', 'Для заборов', 'Для металла']),
#  'Назначение': (False, ['Декоративное', 'Защита от износа', 'Упрочнение']),
#  'Работы': (False, ['Внутренние', 'Наружные']),
#  'Можно мыть': (False, ['Да']),
#  'Вид краски': (False, ['Быстросохнущая', 'Гладкая']),
#  'Способ нанесения': (False, ['Валик', 'Кисть', 'Краскопульт']),
#  'Объем, л': (False, ['новый L6 белый трехрежимный 12L']),
#  'Расход, л/м2': (False, ['12 м²/л']),
#  'Аэрозоль': (False, ['Нет']),
#  'Тип растворителя': (False, ['Сольвент', 'Уайт-спирит']),
#  'Материал основания': (False, ['ДВП', 'ДСП', 'Дерево', 'Металл', 'Фанера']),
#  'Вид шампура': (False, ['Палочки']),
#  'Длина шампура, см': (True, ['75']),
#  'Количество шампуров, шт': (True, ['6']),
#  'Толщина, мм': (True, ['0.06']),
#  'Материал рукояти': (False, ['Дерево']),
#  'Вибрация': (False, ['Без вибрации']),
#  'Состав комплекта': (False, ['Фиксатор для запястий и лодыжек']),
#  'Размер БДСМ-атрибутики': (False, ['Универсальный']),
#  'Пол': (False, ['Для нее']),
#  'Назначение товара 18+': (False, ['Для БДСМ', 'Для ролевых игр']),
#  'Размер секс-игрушек': (False, ['Medium: 13-20 см']),
#  'Длина, см': (False, ['30*40*2 60*40*1']),
#  'Тип мастурбатора': (False, ['Вагина']),
#  'Вид насадки': (False, ['На член']),
#  'Ширина/диаметр, мм': (False, ['2-3.4']),
#  'Особенности 18+': (False, ['Для массажа простаты']),
#  'Вид стимулятора': (False, ['Классический', 'Реалистичный']),
#  'Количество внешних карманов': (False, ['2 шт.']),
#  'Количество внутренних отделений': (False, ['1 шт.']),
#  'Внешние размеры, мм': (False, ['370x470']),
#  'Консистенция краски/клея': (False, ['Масляная']),
#  'Количество цветов, шт': (True, ['16']),
#  'Цветовые эффекты': (False, ['Классическая']),
#  'Форма выпуска краски': (False, ['Поштучно']),
#  'Вид ручки': (False, ['Шариковая']),
#  'Цвет чернил': (False, ['Синий']),
#  'Толщина линии, мм': (False, ['0.3-0.5']),
#  'Плотность, г/м2': (False, ['80 г']),
#  'Формат': (False, ['A1 (59.4 × 84.1 см)']),
#  'Размер одежды/аксессуара для животных': (False, ['XL']),
#  'Сезон': (False, ['Демисезон']),
#  'Особенности одежды, обуви': (False, ['С капюшоном', 'Со стяжкой']),
#  'Размер животного': (False, ['Малый']),
#  'Вид одежды': (False, ['Комбинезон']),
#  'Предназначено для': (False, ['Для собак']),
#  'Содержание мяса, субпродуктов, %': (False,
#   ['мясо и продукты переработки мяса (из которыхтелятина мин. 4%). рыба и продукты переработки рыбы. минеральные вещества. аминокислоты, продукты переработки растительного сырья, сахара, витамины, загустители, консерванты.']),
#  'Особенности': (False,
#   ['Без ГМО', 'Без искусственных консервантов', 'Без усилителей вкуса']),
#  'Порода собаки': (False, ['Для любой породы']),
#  'Основной ингредиент': (False, ['Мясо']),
#  'Возраст животного': (False, ['Для маленьких']),
#  'Особые потребности': (False, ['Гиперактивные']),
#  'Вкус корма для животных': (False, ['Субпродукты', 'Язык']),
#  'Консистенция корма для животных': (False, ['Фарш']),
#  'Условия хранения': (False, ['При температуре до +25`C']),
#  'Упаковка консервированных кормов': (False, ['Консервная банка']),
#  'Минеральные вещества': (False, ['фосфор, кальций']),
#  'Класс корма': (False, ['Супер-премиум']),
#  'Длина большей стороны, см': (False, ['24 см']),
#  'Длина меньшей стороны, см': (False, ['24 см']),
#  'Наполнитель лежака/домика для животных': (False, ['Алюминий', 'Полиэфир']),
#  'Форма выпуска корма': (False, ['Гранулы']),
#  'Страна бренда': (False, ['Россия']),
#  'Материал подошвы обуви': (False, ['ПВХ (поливинилхлорид)']),
#  'Вид каблука': (False, ['Без каблука']),
#  'Материал стельки': (False, ['Искусственные материалы']),
#  'Российский размер (обуви)': (False, ['37,5']),
#  'Полнота': (False, ['F']),
#  'Вид застёжки': (False, ['Шнурки']),
#  'Особенности модели': (False, ['Низкая модель']),
#  'Внутренний материал': (False, ['Байка']),
#  'Посадка': (False, ['Нормальная']),
#  'Спортивное назначение': (False, ['Спортивная ходьба']),
#  'Материал верха': (False, ['Текстиль']),
#  'Коллекция': (False, ['Весна-лето 2022']),
#  'Размер производителя': (False, ['T11']),
#  'Бренд в одежде и обуви': (False, ['Jovinni Rossi']),
#  'Праздник': (False,
#   ['14 февраля',
#    '8 марта',
#    'Gender Reveal Party',
#    'День рождения',
#    'Свадьба',
#    'Универсальный']),
#  'Эффект от использования уходовой косметики': (False, ['Питание']),
#  'Применение': (False, ['От пигментации', 'От покраснений']),
#  'Тип кожи': (False, ['Для всех типов кожи']),
#  'Область использования': (False, ['Область вокруг глаз']),
#  'Способ применения': (False,
#   ['Крем наносится на кожу вокруг глаз 1-3 раза в день (в удобное время), отступив от реснитчатого края нижнего века не менее 1 мм. Дополнительно рекомендуем использовать для ухода за кожей гель "Система Гиалуроновых кислот 1800 мДа-0.8 кДа" (есть три разновидности), крем "Многофакторный Восстановитель кожи" и маску-крем "Система гиалуроновых кислот и витаминов"']),
#  'Особенности состава': (False,
#   ['Аптечная косметика',
#    'Без аммиака',
#    'Без дибутилфталата',
#    'Без камфоры',
#    'Без минеральных масел',
#    'Без отдушек',
#    'Без парабенов',
#    'Без спирта',
#    'Без сульфатов',
#    'Без толуола',
#    'Без формальдегида',
#    'Без фтора',
#    'Гипоаллергенная',
#    'Не комедогенна',
#    'Не тестируется на животных',
#    'Органическая косметика',
#    'Подходит для ежедневного применения']),
#  'Возрастной диапазон': (False, ['от 20 лет']),
#  'Эффект': (False, ['Окрашивание']),
#  'Тип волос': (False, ['Для всех типов волос']),
#  'Вес, г': (False, ['указан на упаковке.']),
#  'Вид средства для ухода': (False, ['пенка']),
#  'Бьюти-ингредиент': (False, ['Гиалуроновая кислота', 'Глицерин']),
#  'Основной материал': (False, ['Пластик']),
#  'Материал щетины': (False, ['Искусственная щетина']),
#  'Внутренний диаметр брашинга, мм': (True, ['18']),
#  'Вид парикмахерской расчески': (False, ['Для стрижки классическая']),
#  'Дней до замены': (False, ['1 день']),
#  'Режим ношения': (False, ['Дневной']),
#  'Оптическая сила': (True, ['+4.00']),
#  'Радиус кривизны': (True, ['8.5']),
#  'Диаметр, мм': (False, ['4.0mm']),
#  'Количество в упаковке': (False, ['Touchpad']),
#  'Влагосодержание, %': (True, ['55']),
#  'Особенности контактных линз': (False,
#   ['Безопасный край линзы',
#    'Силикон-гидрогель',
#    'Сферический дизайн',
#    'УФ-фильтр']),
#  'Материал контактных линз': (False, ['Нарафилкон А']),
#  'Кислородопропускание, Dk/t': (False, ['113,75']),
#  'Основа состава': (False, ['Водная']),
#  'Эффект интимного средства': (False, ['Возбуждающий']),
#  'Признак 18+': (False, ['false']),
#  'Уровень шума (при работе), дБ': (False, ['33 дБ']),
#  'Вид ингалятора': (False, ['Компрессорный (струйный)']),
#  'Мин. размер частиц, мкм': (False, ['0,5']),
#  'Скорость ингаляции, мл/мин': (False, ['0,2']),
#  'Вид средства для обуви/одежды': (False, ['Крем']),
#  'Для каких материалов': (False,
#   ['Искусственная кожа', 'Кожа с покрытием', 'Натуральная кожа']),
#  'Эффект от использования': (False, ['Защита']),
#  'Тип застежки': (False, ['Молния']),
#  'Количество внешних карманов, шт': (True, ['1']),
#  'Размер рюкзака': (False, ['Маленький (до 20 л.)']),
#  'Вид рюкзака': (False, ['Городской']),
#  'Ручки': (False, ['Широкие лямки']),
#  'Особенности конструкции сумки': (False, ['Петля для подвешивания']),
#  'Материал подкладки': (False, ['Полиэстер']),
#  'Фактура материала': (False, ['Махровая']),
#  'Размер, см': (False, ['70x130']),
#  'Плотность ткани, г/кв.м': (True, ['1']),
#  'Вид принта': (False, ['Животные']),
#  'Количество насадок': (True, ['3']),
#  'Материал корпуса': (False, ['Пластик']),
#  'Длина шнура, м': (False, ['1.8 м']),
#  'Системы защиты': (False, ['Защита от перегрева']),
#  'Материал чаши': (False, ['Металл']),
#  'Планетарный механизм': (False, ['Да']),
#  'Тип миксера': (False, ['Планетарный']),
#  'Режимы работы': (False, ['Импульсный режим']),
#  'Вращающаяся чаша': (False, ['Нет']),
#  'Количество скоростей': (False, ['750*285*200']),
#  'Турборежим': (False, ['Нет']),
#  'Объем чаши, л': (True, ['0.4']),
#  'Насадки приборов для измельчения продуктов': (False,
#   ['Венчик', 'Для замешивания теста']),
#  'Функциональные особенности': (False, ['Плавное изменение скорости']),
#  'Конструктивные особенности': (False,
#   ['Защитная крышка', 'Прорезиненные ножки']),
#  'Мощность, Вт': (False, ['2х200']),
#  'Макс. мощность (при блокировке мотора), Вт': (True, ['2000']),
#  'Производительность, кг/мин': (True, ['2.5']),
#  'Индикация и сигналы': (False, ['Индикация включения']),
#  'Конструктивные особенности тепловых приборов': (False,
#   ['Антипригарное покрытие']),
#  'Количество в упаковке, шт.': (False, ['39447|1']),
#  'Назначение держателя для кухни': (False, ['для губки, мыла']),
#  'Высота, см': (False, ['R \xa0Длинная 250X\xa0высота 134CM']),
#  'Крепление держателя для кухни': (False, ['ручное (без крепления)']),
#  'Конструкция чайника': (False,
#   ['Индикатор уровня воды', 'Светоиндикатор работы', 'Фильтр от накипи']),
#  'Тип управления': (False, ['Механическое']),
#  'Внутреннее покрытие бака': (False, ['Эмаль']),
#  'Максимальная мощность, кВт': (False, ['0.7/1.3/2 кВт']),
#  'Размеры, мм (ШхГхВ)': (False, ['450x450x563']),
#  'Объем бака (номинальный), л': (False, ['50 л']),
#  'Макс. температура, °С': (False, ['до 75 °C']),
#  'Установка водонагревателя': (False, ['Вертикальная']),
#  'Форма бака': (False, ['Округлая']),
#  'Количество предметов': (True, ['6']),
#  'Система управления': (False, ['Независимая']),
#  'Количество температурных режимов': (False, ['от 120 до 200°C']),
#  'Дополнительные режимы': (False,
#   ['Автоматическое вращение насадки', 'Ионизация', 'Холодный воздух']),
#  'Предназначение': (False, ['Бытовое']),
#  'Диаметр насадки': (False, ['50 мм']),
#  'Насадки для приборов по уходу за волосами': (False, ['Круглая щетка']),
#  'Особенности фена, выпрямителя волос': (False,
#   ['Вращение шнура 360°', 'Защита от перегрева', 'Петля для подвешивания']),
#  'Макс. мощность, Вт': (False, ['1200 вт']),
#  'Программы приготовления': (False, ['Подогрев', 'Разморозка', 'Разогрев']),
#  'Направление открывания дверцы': (False, ['Навесная с открытием налево']),
#  'Макс. мощность СВЧ, Вт': (True, ['700']),
#  'Технология СВЧ': (False, ['С поворотным столом']),
#  'Открывание дверцы микроволновой печи': (False, ['Ручка']),
#  'Макс. мощность гриля, Вт': (False, [' ']),
#  'Диаметр поворотного стола, см': (False, ['245 РјРј']),
#  'Расположение': (False, ['Отдельностоящая']),
#  'Глубина, см': (False, ['30.5-42.5']),
#  'Режимы работы микроволновой печи': (False, ['С грилем', 'Соло']),
#  'Управление': (False, ['Механическое']),
#  'Внутреннее покрытие микроволновой печи': (False, ['Эмалевое']),
#  'Особенности микроволновой печи': (False, ['Таймер', 'Часы']),
#  'Макс. уровень шума, дБ': (False,
#   ['46/53/68 на 1-2-3-й ступенях соответственно']),
#  'Время мойки при обычной программе, мин': (True, ['60']),
#  'Доп. принадлежности ПММ': (False, ['Корзина для столовых приборов']),
#  'Инверторный двигатель': (False, ['Нет']),
#  'Размер (ДхШхВ), см': (False, ['44.8х81.5х55']),
#  'Вид посудомоечной машины': (False, ['Узкая (45 см)']),
#  'Вместимость, комплектов': (True, ['14']),
#  'Класс энергопотребления': (False, ['A++']),
#  'Класс мойки': (False, ['A']),
#  'Класс сушки': (False, ['A+']),
#  'Количество программ': (True, ['6']),
#  'Программы мойки': (False,
#   ['90 минут',
#    'Быстрая',
#    'Деликатная/стекло',
#    'Интенсивная',
#    'Стандартная',
#    'Экономичная']),
#  'Расход воды за цикл, л': (True, ['10']),
#  'Расход энергии за цикл, кВт': (False, ['0. 75']),
#  'Отложенный старт, ч': (False, ['Нет']),
#  'Индикация': (False,
#   ['Наличие ополаскивателя', 'Наличие соли', 'Неисправность']),
#  'Тип сушки': (False, ['Конденсационная']),
#  'Функционал посудомоечной машины': (False,
#   ['Быстрая мойка',
#    'Возможность добавления посуды после запуска',
#    'Деликатная мойка',
#    'Интенсивная мойка',
#    'Использование средств 3-в-1',
#    'Отсрочка запуска',
#    'Половинная загрузка']),
#  'Особенности посудомоечной машины': (False, ['Поддон для столовых приборов']),
#  'Назначение чехла для мебели': (False, ['для стула']),
#  'Стиль': (False, ['Повседневное', 'Праздничное', 'Спорт']),
#  'Вид сумки': (False, ['шоппер']),
#  'Формат А4': (False, ['вмещает']),
#  'Высота ручек, см': (False, ['40 см']),
#  'Длина плечевого ремня, см': (False, ['130 см']),
#  'Форма поставки матраса': (False, ['В рулоне']),
#  'Количество пружин на спальное место': (True, ['512']),
#  'Комната': (False, ['Спальня']),
#  'Минимальная жесткость': (False, ['Мягкий']),
#  'Максимальная жесткость': (False, ['Полужесткий']),
#  'Вид пружинного блока': (False, ['Независимые пружины']),
#  'Конструкция матраса': (False, ['Независимые пружины']),
#  'Вид матраса': (False, ['Анатомический']),
#  'Вид': (False, ['Двусторонний с разной жесткостью']),
#  'Макс. вес на спальное место, кг': (True, ['120']),
#  'Особенности матраса': (False, ['Эффект памяти']),
#  'Информация о размерах': (False, ['Маломерят на размер']),
#  'Высота подошвы, см': (False, ['Полиуретан']),
#  'Серия в одежде и обуви': (False, ['Фламинго']),
#  'Максимальная температура': (False, ['25,0']),
#  'Минимальная температура': (False, ['0,0']),
#  'Вид соуса': (False, ['Терияки']),
#  'Степень остроты': (False, ['Неострый']),
#  'Назначение масла/соуса': (False, ['Для морепродуктов', 'Для мяса']),
#  'Название вкуса': (False, ['Crema']),
#  'Степень обжарки': (False, ['Средняя']),
#  'Интенсивность вкуса': (False, ['Мягкий']),
#  'Способ приготовления кофе': (False,
#   ['В чашке', 'Капельная кофеварка', 'Турка', 'Френч-пресс']),
#  'Степень помола': (False, ['Средний']),
#  'Состав кофе': (False, ['Арабика/Робуста']),
#  'Вид шоколада': (False, ['Темный']),
#  'Содержания какао, %': (True, ['33']),
#  'Не содержит': (False, ['Без сахара']),
#  'Особенности напитков, продуктов питания': (False,
#   ['Биопродукт', 'Диетический продукт']),
#  'Вид лапши': (False, ['Рамен']),
#  'Амортизация': (False, ['нет']),
#  'Класс тренажера': (False, ['Домашний']),
#  'Питание тренажера': (False, ['Сеть 220 Вольт']),
#  'Особенности тренажеров': (False, ['Транспортировочные ролики']),
#  'Измерительные датчики': (False, ['Дистанция']),
#  'Российский размер': (False, ['56-182']),
#  'Рост': (False, ['165-170']),
#  'Тип упаковки одежды': (False, ['Пакет']),
#  'Инструкция по уходу': (False, ['бережная стирка при 30 градусах']),
#  'Рост модели на фото': (False, ['173 см']),
#  'Размер на модели': (False, ['50-52']),
#  'Рисунок': (False, ['Однотонный']),
#  'Цель': (False, ['Красота и здоровье', 'Набор мышечной массы']),
#  'Вид протеина': (False, ['Сывороточный']),
#  'Форма выпуска спортивного питания': (False, ['Порошок']),
#  'Энергетическая ценность: ккал в 1 порции': (False, ['188-200']),
#  'Белок: грамм в 1 порции': (False, ['3-3.5']),
#  'Жиры: грамм в 1 порции': (False, ['1.5-2']),
#  'Углеводы: грамм в 1 порции': (False, ['27.5-29']),
#  'Формат (типоразмер) элементов питания': (False,
#   ['Батареи/аккумуляторы тип AA']),
#  'Макс. световой поток, Люмен': (True, ['12000']),
#  'Кол-во светодиодов': (True, ['37']),
#  'Макс. время работы от батарей, ч': (True, ['12']),
#  'Степень защиты от влаги и пыли': (False, ['IP44']),
#  'Оттенок света': (False, ['Холодный белый']),
#  'Дальность освещения, м': (True, ['2000']),
#  'Комплектация элементом питания': (False, ['Не входит в комплект']),
#  'Комплектация зарядным устройством': (False,
#   ['Не комплектуется зарядным устройством']),
#  'Особенности фонаря': (False, ['Регулировка угла наклона']),
#  'Кол-во режимов': (True, ['4']),
#  'Назначение сноуборда': (False, ['Универсальный']),
#  'Жесткость': (False, ['Средняя']),
#  'Тип крепления сноуборда': (False, ['Классические']),
#  'Модельный год': (False, ['2020-21']),
#  'Число отделений, шт': (True, ['1']),
#  'Назначение боксёрских перчаток': (False, ['Тренировочные']),
#  'Тип застёжки': (False, ['Липучка']),
#  'Вес перчатки, oz (унций)': (True, ['6']),
#  'Вид спорта': (False, ['Футбол']),
#  'Длина рукава': (False, ['Длинный']),
#  'Модель': (False, ['прямая', 'свободная модель']),
#  'Длина изделия, см': (False, ['45-65']),
#  'Декоративные элементы': (False, ['Воротник', 'Разрезы']),
#  'Количество слоев': (False, ['2 слоя']),
#  'Система': (False, ['T4']),
#  'Количество пар в упаковке': (False, ['3 пары']),
#  'Защита от влаги': (False, ['Нет']),
#  'Конструкция наушников': (False, ['Вкладыши']),
#  'True Wireless': (False, ['false']),
#  'Крепление наушников': (False, ['В ушной раковине']),
#  'Спортивные': (False, ['Нет']),
#  'Способ передачи звука': (False, ['Динамики']),
#  'Складные': (False, ['false']),
#  'Управление наушниками': (False, ['Кнопочное']),
#  'Мин. частота, Гц': (False, ['200\xa0Гц']),
#  'Макс. частота, Гц': (False, ['20 000\xa0Гц']),
#  'Подключение': (False, ['Проводное']),
#  'Импеданс, Ом': (False, ['4+4']),
#  'Акустическое оформление': (False, ['Закрытое']),
#  'Диаметр динамика, мм': (True, ['40']),
#  'Разъем': (False, ['3.5 мм']),
#  'Длина кабеля, см': (False, ['1.3 м']),
#  'Опции управления': (False, ['Регулировка громкости']),
#  'Материал амбушюров': (False, ['Силикон']),
#  'Шумоподавление': (False, ['Пассивное']),
#  'Наличие микрофона': (False, ['Да']),
#  'Крепление': (False, ['Подвесное']),
#  'Высота, мм': (False, ['58.928\xa0мм']),
#  'Длина, мм': (False, ['160/100']),
#  'Ширина, мм': (False, ['245.11\xa0мм']),
#  'Степень защиты': (False, ['IP20']),
#  'Защищенность': (False, ['Без защиты']),
#  'Форма': (False, ['Нестандартная']),
#  'Напряжение питания, В': (False, ['220-240В']),
#  'Гарантия': (False, ['18 месяцев']),
#  'Тип крепления': (False, ['Планка']),
#  'Сертификат': (False, ['ЯНАО']),
#  'Вид шапки': (False, ['Бини']),
#  'Материал подклада/внутренней отделки': (False, ['Флис']),
#  'Световой поток, Лм': (False, ['8 000']),
#  'Диаметр воздуховода, мм': (False, ['150 см']),
#  'Вентиляция': (False, ['Приточно-вытяжная']),
#  'Форма воздуховода': (False, ['Круг']),
#  'Вес с упаковкой, г': (True, ['997']),
#  'Установка вентиляции': (False, ['Канальный']),
#  'Вид комплектующего для вентиляции': (False, ['Гибкий воздуховод']),
#  'Количество фаз электростанции': (False, ['Одна']),
#  'Шаг зубьев (TPI)': (True, ['7']),
#  'Форма рукояти': (False, ['Г-образная']),
#  'Длина лезвия, мм': (True, ['9']),
#  'Количество в комплекте, шт.': (True, ['1']),
#  'Усилие, Н': (True, ['50']),
#  'Назначение мебельной фурнитуры': (False, ['Для основания кровати']),
#  'Макс. нагрузка, кг': (False, ['до 150 кг']),
#  'Угол подъема, °': (True, ['110']),
#  'Вид ключа': (False, ['Рожковый']),
#  'Крыло': (False, ['Правое']),
#  'Покрытие': (False, ['Матовое']),
#  'Отверстия под смеситель': (False, ['Без отверстий']),
#  'Толщина стенок, мм': (False, ['1,5']),
#  'Клапан-автомат': (False, ['Нет']),
#  'Форма мойки': (False, ['Прямоугольник']),
#  'Установка': (False, ['Накладная']),
#  'Минимальный размер тумбы': (False, ['80 см']),
#  'Число основных чаш': (True, ['1']),
#  'Диаметр слива, мм': (True, ['45']),
#  'Год выпуска': (False, ['12/1/1998']),
#  'Количество страниц': (False, ['Печатная книга']),
#  'Тип книги': (False, ['Печатная книга']),
#  'Формат издания': (False, ['140x210']),
#  'Автор на обложке': (False, ['Блеквуд Даниэлла']),
#  'Издательство': (False, ['ИГ "Весь"']),
#  'ISBN': (False, ['978-5-98995-104-8, 978-0-7494-7057-9']),
#  'Автор': (False, ['Блеквуд Даниэлла']),
#  'Тип обложки': (False, ['Твердый переплет']),
#  'Язык издания': (False, ['Русский']),
#  'Комментарий': (False, ['Книга-комикс.']),
#  'Основной жанр книги': (False, ['Комиксы']),
#  'Тираж': (False, ['Печатная книга']),
#  'Оригинальное название': (False,
#   ['Coaching Presence: Building Consciousness and Awareness in Coaching Interventions']),
#  'Установка бассейна': (False, ['Наземный']),
#  'Фильтр водяного насоса': (False, ['Картриджный']),
#  'Особенности и комплектация бассейнов': (False, ['Лестница', 'Фильтр']),
#  'Объем бассейна, л': (True, ['6478']),
#  'Время установки, мин': (True, ['45']),
#  'Надувное дно': (False, ['Нет']),
#  'Вид бассейна': (False, ['Каркасный']),
#  'Форма бассейна': (False, ['Прямоугольник']),
#  'Объем, Л': (False, ['4,5 л']),
#  'Антипригарное покрытие': (False, ['Да']),
#  'Кол-во внутренних отделений': (True, ['1']),
#  'Объем главного отделения, л': (False, ['30 л']),
#  'Специальные отделения': (False,
#   ['Боковой карман для бутылки воды',
#    'Отделение для аксессуаров',
#    'Отделение-органайзер']),
#  'Вид запчасти': (False, ['Кнопки']),
#  'Толщина наматрасника, см': (False, ['30 см']),
#  'Непромокаемый наматрасник': (False, ['Да']),
#  'Крепление наматрасника': (False, ['с резинкой по периметру']),
#  'Назначение спецодежды': (False,
#   ['Для работников производства', 'Для слесарных работ']),
#  'Индекс жесткости': (True, ['110.0']),
#  'Назначение горных лыж': (False, ['Универсальные']),
#  'Серия': (False, ['Книжка в тетрадке']),
#  'Иллюстратор': (False, ['Цветкова Анастасия']),
#  'Партномер (артикул производителя)': (False, ['A07577S']),
#  'Переводчик': (False, ['Лейк Ирина']),
#  'Спальность': (False, ['Евро']),
#  'Для кого': (False,
#   ['Бабушка',
#    'Брат',
#    'Девочка',
#    'Девушка',
#    'Дедушка',
#    'Дочь',
#    'Жена',
#    'Жених',
#    'Женщина',
#    'Коллега',
#    'Любимая',
#    'Любимый',
#    'Малыш',
#    'Мальчик',
#    'Мама',
#    'Молодой человек',
#    'Муж',
#    'Мужчина',
#    'Невеста',
#    'Папа',
#    'Папа и дедушка',
#    'Победитель/Участник',
#    'Подруга',
#    'Ребенок',
#    'Родственники',
#    'Руководитель',
#    'Сестра',
#    'Сын',
#    'Универсально']),
#  'Количество фломастеров, шт': (True, ['12']),
#  'Количество заводских упаковок': (False, ['й']),
#  'Форма наконечника.': (False, ['Круглая']),
#  'Вид фломастера': (False, ['Стираемый']),
#  'Тип основы': (False, ['Водная']),
#  'Крепление бейджа': (False, ['Без крепления']),
#  'Марка ТС': (False, ['Citroen']),
#  'Вид техники': (False,
#   ['Авиатехника',
#    'Внедорожники',
#    'Водная техника',
#    'Грузовые автомобили и автобусы',
#    'Квадроциклы',
#    'Коммерческий транспорт',
#    'Легковые автомобили',
#    'Мопеды',
#    'Мотоциклы',
#    'Погрузчики',
#    'Скутеры',
#    'Снегоходы',
#    'Спецтехника',
#    'Стационарные установки']),
#  'Область применения': (False, ['Универсальная применяемость']),
#  'Форма выпуска': (False, ['Спрей']),
#  'Альтернативные артикулы товара': (False, ['A-210-CITROEN-Copper Gold']),
#  'Особенности пледа и покрывала': (False, ['Стёганный']),
#  'Тип датчика': (False, ['Датчик коленвала']),
#  'OEM-номер': (False,
#   ['237314M500; 237314M502; 237314M505; 237314M506; 237314M50A; 237314M50B; 237314M560; 237314M56C; 237315M000; 237315M001; 237315M005; 2373195F0B; 2373195F0D']),
#  'Талия': (False, ['Средняя']),
#  'Форма бутылочки/соски': (False, ['Ортодонтическая']),
#  'Особенности бутылочек и сосок': (False,
#   ['Для новорожденных',
#    'Не содержит Бисфенол A',
#    'С вентиляционной системой',
#    'С футляром']),
#  'Макс. давление, бар': (True, ['20']),
#  'Тип используемого кофе': (False, ['Молотый']),
#  'Кол-во приготовляемых чашек кофе, шт': (True, ['3']),
#  'Приготовление напитка': (False, ['Подогрев чашек']),
#  'Конструкция кофеварок/кофемашин': (False, ['Отсек для шнура']),
#  'Сабвуфер': (False, ['Нет']),
#  'Версия HDMI': (False, ['HDMI 1.4']),
#  'Доп. режимы телевизора': (False, ['Гостиничный режим']),
#  'Запись эфира': (False, ['PVR', 'Time Shift']),
#  'Встроенный медиаплеер': (False, ['Да']),
#  'Управление телевизором': (False, ['Пульт ДУ']),
#  'Изогнутый экран': (False, ['Нет']),
#  'Интерфейсы': (False,
#   ['3.5 мм',
#    'CI+',
#    'D-Sub (VGA)',
#    'HDMI',
#    'RJ-45 (Ethernet)',
#    'S/PDIF',
#    'USB',
#    'Композитный',
#    'Компонентный']),
#  'Технология HDR': (False, ['Нет']),
#  'Диагональ экрана, см': (True, ['190']),
#  'Диагональ экрана, дюймы': (False, ['5"']),
#  'Технология матрицы ТВ': (False, ['VA']),
#  'Тип подсветки': (False, ['Direct LED']),
#  'Стандарт разрешения': (False, ['HD']),
#  'ТВ-тюнер': (False, ['DVB-C', 'DVB-T', 'DVB-T2', 'NICAM', 'PAL', 'SECAM']),
#  'Размер без подставки (ШxВxГ), мм': (False, ['737 x 438 x 74']),
#  'Количество разъемов USB': (True, ['1']),
#  'Разрешение': (False, ['1280×720 HD']),
#  'Интерьерный телевизор': (False, ['Нет']),
#  'Smart TV': (False, ['Нет']),
#  'Частота обновления': (False, ['60 Гц']),
#  'Мощность аудиосистемы, Вт': (True, ['30']),
#  'Число портов HDMI': (True, ['1']),
#  'Стандарт крепления VESA': (False, ['100x100 мм']),
#  'Диаметр колес, дюймы': (False, ['28-29']),
#  'Вид велосипеда': (False, ['Городской']),
#  'Материал рамы': (False, ['Алюминиевый сплав']),
#  'Форма поставки': (False, ['В разобранном виде']),
#  'Размер рамы, дюймы': (False, ['Универсальный']),
#  'Вид ухода': (False, ['Уход за шерстью и кожей']),
#  'Возраст ребенка': (False, ['От 5 лет']),
#  'Число цветов, шт': (False, ['Унисекс']),
#  'Ось (AXIS)': (True, ['60']),
#  'Цилиндр (CYL)': (False, ['']),
#  'Стиль украшения': (False, ['Повседневный']),
#  'Размер изделия': (False, ['Безразмерный']),
#  'Вставка': (False, ['Стразы']),
#  'Вид замка': (False, ['Без замка']),
#  'Возраст украшения': (False, ['Современное']),
#  'Вид пюре': (False, ['Фруктовое']),
#  'Вид фруктов': (False, ['Черника']),
#  'Возраст в продуктах питания': (False, ['С 8 месяцев']),
#  'Тип мотора': (False, ['AC']),
#  'Тип бумаги в книге': (False, ['Офсетная']),
#  'Количество рулонов клейкой ленты, шт': (True, ['6']),
#  'Вид клейкой ленты': (False, ['Односторонняя']),
#  'Толщина, мкм': (False, ['40 мкм']),
#  'Вид шерсти': (False, ['Альпака', 'Меринос']),
#  'Вкусовой акцент (вкус)': (False, ['Клубника']),
#  'Количество порций': (False, ['30-60']),
#  'Плотность плетения': (False, ['40 ден']),
#  'Эквивалентная мощность лампы накаливания, Вт': (False, ['60 Вт']),
#  'Свет': (False, ['Теплый белый']),
#  'Температура света, К': (False, ['3000/4200/6500']),
#  'Диммируемость': (False, ['Нет']),
#  'Форма лампочки': (False, ['Шар']),
#  'Тип колбы': (False, ['G95']),
#  'Место применения': (False,
#   ['Для административных учреждений',
#    'Для гаража',
#    'Для гостиниц',
#    'Для дачи и загородного дома',
#    'Для дома',
#    'Для кафе и ресторана',
#    'Для киностудии',
#    'Для магазина',
#    'Для медицинских учреждений',
#    'Для музея и выставочного зала',
#    'Для образовательных учреждений',
#    'Для предприятий и складов',
#    'Для спортивных объектов',
#    'Для театра',
#    'Для фотостудии']),
#  'Голосовой помощник': (False, ['Нет']),
#  'Управление со смартфона': (False, ['Нет']),
#  'Индекс цветопередачи, Ra': (False, ['80-89 (класс 1В)']),
#  'Технология': (False, ['Светодиодная']),
#  'Вид LED лампы': (False, ['SMD']),
#  'Назначение лампы': (False,
#   ['Для витрин',
#    'Для дач и загородных домов',
#    'Для декоративной подсветки',
#    'Для люстр и светильников',
#    'Для предприятий, складов, гаражей',
#    'Для фото',
#    'Общего назначения']),
#  'Угол рассеивания, °': (True, ['70']),
#  'Комплектация лампочками': (False, ['Нет']),
#  'Форма ковра': (False, ['Прямоугольник']),
#  'Ширина, м': (False, ['0.5�']),
#  'Высота ворса, мм': (True, ['3']),
#  'Стиль дизайна': (False, ['Лофт', 'Современный']),
#  'Основа ковра': (False, ['Без основы']),
#  'Цвет тонера/чернил': (False, ['Пурпурный (magenta)']),
#  'Цветность': (False, ['Цветной']),
#  'Тип расходного материала для печати': (False, ['Чернила']),
#  'Ресурс': (False, ['7500 страниц']),
#  'Количество цветов': (True, ['1']),
#  'Емкость': (False, ['Стандартная']),
#  'Оригинальность расходника': (False, ['оригинал']),
#  'Количество, шт': (False, ['90x420mm']),
#  'Назначение средства от насекомых/грызунов': (False,
#   ['Уничтожение насекомых']),
#  'Форма выпуска средств от вредителей': (False, ['Концентрат суспензии']),
#  'Вид вредителя': (False, ['Клоп', 'Таракан']),
#  'Гипоаллергенно': (False, ['Да']),
#  'Название принта': (False, ['ГОБЕЛЕНОВАЯ 45Х45 "АРИСТОКРАТ АГНЕССА"']),
#  'Браслет/ремешок': (False, ['Пластик']),
#  'Тип часов': (False, ['Кварцевые']),
#  'Диаметр корпуса, мм': (False, ['8,5']),
#  'Водонепроницаемость': (False, ['10 Bar']),
#  'Функции часов': (False,
#   ['Автоматический календарь',
#    'Будильник',
#    'Второй часовой пояс',
#    'День недели',
#    'Месяц',
#    'Секундомер',
#    'Таймер']),
#  'Стекло': (False, ['Пластик']),
#  'Тип индикации': (False, ['Арабские цифры']),
#  'Ширина ремешка, мм': (False, ['20 ATM']),
#  'Тип батареи': (False, ['CR2032']),
#  'Длина подола': (False, ['средняя длина']),
#  'Вид крепления штор': (False, ['Зажимы']),
#  'Расположение блока управления': (False, ['Справа']),
#  'Монтаж без сверления': (False, ['Да']),
#  'Светопроницаемость': (False, ['День ночь']),
#  'С дозатором': (False, ['Да']),
#  'Назначение моющего, чистящего средства': (False,
#   ['Для ковров', 'Для мебели', 'Для обуви']),
#  'Тип загрузки': (False, ['Фронтальная']),
#  'Количество листов, шт': (False, ['40 шт.']),
#  'Вес маховика, кг': (True, ['12']),
#  'Количество уровней нагрузки': (False, [' бесступенчатая система']),
#  'Регулировка нагрузки': (False, ['Ручная']),
#  'Тренируемые группы мышц': (False, ['Ноги', 'Пресс']),
#  'Обхват шеи максимальный, cм': (True, ['56']),
#  'Максимальный вес пользователя, кг': (True, ['120']),
#  'Дисплей': (False, ['LCD']),
#  'Макс. угол наклона полотна, %': (False, ['не меняется']),
#  'Максимальная скорость, км/ч': (True, ['18']),
#  'Длина бегового полотна, см': (True, ['107']),
#  'Ширина бегового полотна, см': (True, ['40']),
#  'Система нагрузки беговой дорожки': (False, ['Электрическая']),
#  'Тип питания': (False, ['От сети']),
#  'Класс инструмента': (False, ['Полупрофессиональный']),
#  'Диаметр опорного диска, мм': (False, ['30\xa0мм']),
#  'Длина шнура питания, м': (False, ['Без цоколя']),
#  'Макс. обороты холостого хода, об/мин': (True, ['5000']),
#  'Плавный пуск': (False, ['Нет']),
#  'Работа с направляющей шиной': (False, ['Да']),
#  'Глубина пропила под 90°, мм': (True, ['60']),
#  'Для работы по металлу': (False, ['Нет']),
#  'Погружная пила': (False, ['Нет']),
#  'Глубина пропила под 45°, мм': (True, ['30']),
#  'Диаметр диска, см': (True, ['21']),
#  'Глубина реза/выборки, мм': (False, ['металл/ дерево 10/100 мм']),
#  'Тип двигателя': (False, ['Электродвигатель']),
#  'Глубина пропила в дереве, мм': (False, ['65\xa0мм']),
#  'Высота голенища, см': (False, ['для размера 42: 32 см']),
#  'Температурный режим': (False, ['от 10 до -20']),
#  'Ортопедический': (False, ['Нет']),
#  'Тип пронации': (False, ['Нейтральная']),
#  'Материал оправы': (False, ['Металл']),
#  'Поляризация': (False, ['Да']),
#  'Цвет линзы': (False, ['Серый']),
#  'Категория защиты линзы': (False, ['3 (18–8% светопропускания)']),
#  'Ширина линзы, мм': (True, ['53']),
#  'Размер заушника, мм': (True, ['145']),
#  'Размер моста на переносице, мм': (True, ['20']),
#  'Форма очков': (False, ['Прямоугольные']),
#  'Материал линзы': (False, ['Поликарбонат']),
#  'Цвет оправы': (False, ['Темно-серый']),
#  'Материал спортивных поясов и манжет': (False, ['Натуральная кожа']),
#  'Размер': (False, ['Универсальный']),
#  'Длина товара в упаковке, мм': (True, ['80']),
#  'Вид обоев': (False, ['Виниловые']),
#  'Количество рулонов': (True, ['1']),
#  'Основа обоев': (False, ['Бумага с клеевым покрытием']),
#  'Покрытие обоев': (False, ['Винил']),
#  'Особенности обоев': (False, ['Водостойкие', 'Моющиеся']),
#  'Высота сиденья, см': (True, ['45']),
#  'Особенности изделия': (False, ['Выраженный финал', 'Звуковые эффекты']),
#  'Тип пиротехники': (False, ['Парковые']),
#  'Калибр, дюймы': (False, ['0,8"']),
#  'Класс опасности пиротехнического изделия': (False, ['III']),
#  'Диаметр заряда, мм': (True, ['70']),
#  'Высота подъема, м': (True, ['3']),
#  'Количество эффектов': (True, ['7']),
#  'Радиус безопасной зоны, м': (False, ['Более 20']),
#  'Число зарядов': (True, ['49']),
#  'Время работы, с': (True, ['60']),
#  'Радиус действия, м': (False,
#   ['до 5 км (зависит от местности и других условий)']),
#  'Время работы, мин': (True, ['30']),
#  'Количество батареек пульта': (True, ['1']),
#  'Число каналов связи': (True, ['9']),
#  'Питание радиоуправляемой модели': (False, ['Сменный аккумулятор']),
#  'Типоразмер батареек': (False, ['AA']),
#  'Типоразмер батареек пульта': (False, ['AA']),
#  'Управление радиоуправляемой моделью': (False, ['Пульт Д/У']),
#  'Питание пульта': (False, ['Сменная батарея']),
#  'Масштаб радиоуправляемой игрушки': (False, ['1/14']),
#  'Вид транспорта': (False, ['Масштабные модели']),
#  'Вид зеркала': (False, ['Настенное']),
#  'Конструкция зеркала': (False, ['Одностороннее']),
#  'Размер, мм': (False, ['51х30х5']),
#  'Вид водного спорта': (False, ['Дайвинг', 'Плавание', 'Фридайвинг']),
#  'Длина стопы, см': (False, ['17.0-17,5']),
#  'Тематика': (False, ['Другое']),
#  'Стандарты связи': (False,
#   ['2G',
#    '3G',
#    '4G',
#    'EDGE',
#    'GSM 1800',
#    'GSM 1900',
#    'GSM 850',
#    'GSM 850/1800/1900',
#    'GSM 850/900/1800/1900',
#    'GSM 900',
#    'GSM 900/1800',
#    'GSM 900/1800/1900',
#    'HSDPA',
#    'HSPA+',
#    'LTE',
#    'LTE 1800',
#    'LTE 2600',
#    'LTE 800',
#    'UMTS 2100',
#    'UMTS 900',
#    'WCDMA']),
#  'Размещение': (False, ['Уличная']),
#  'Направленность антенны': (False, ['Направленная']),
#  'Вид антенны': (False, ['Внешняя']),
#  'Коэффициент усиления антенны, dBi': (True, ['3']),
#  'Индикаторы': (False, ['Нагрев']),
#  'Вертикальное отпаривание': (False, ['Да']),
#  'Свойства подошвы': (False, ['Антипригарное']),
#  'Беспроводное использование': (False, ['Нет']),
#  'Объем резервуара для воды, мл': (False, ['2500 мл']),
#  'Подача пара, г/мин': (False, ['до 90 г/мин']),
#  'Паровой удар, г/мин': (True, ['430']),
#  'Покрытие подошвы': (False, ['Керамическое']),
#  'Особенности утюга, отпаривателя': (False,
#   ['Противокапельная система', 'Функция самоочистки']),
#  'Циферблат': (False, ['Аналоговый']),
#  'Стиль часов': (False, ['повседневные']),
#  'Особенности часов': (False, ['Винтовая задняя крышка']),
#  'Вид обложки': (False, ['для автодокументов']),
#  'Материал полотенцесушителя': (False, ['Сталь']),
#  'Наличие полок': (False, ['Нет']),
#  'Форма полотенцесушителя': (False, ['Нестандартная']),
#  'Вариант подключения': (False, ['Боковое левое', 'Боковое правое']),
#  'Вид браслета': (False, ['на запястье']),
#  'Модель браслета': (False, ['из камней']),
#  'Тип вставки': (False, ['Натуральный камень']),
#  'Тип анкера': (False, ['С гайкой']),
#  'Форма головки анкера': (False, ['Гайка']),
#  'Резьба': (False, ['M12']),
#  'Головка': (False, ['Шестигранная']),
#  'Длина стельки, см': (False, ['23,5']),
#  'Ширина корешка, мм': (True, ['15']),
#  'Вместимость папки, листов': (False, ['350 листов']),
#  'Толщина обложки, мм': (False, ['2 мм']),
#  'Вид папки': (False, ['Папка-регистратор']),
#  'Фиксация документов': (False, ['Арочный механизм']),
#  'Количество, штук': (True, ['4']),
#  'Расположение сиденья': (False, ['Передние сиденья']),
#  'Покрытие корпуса': (False, ['Матовое']),
#  'С ножками': (False, ['Нет']),
#  'Высота ножек, мм': (True, ['50']),
#  'Подъемный механизм': (False, ['Да']),
#  'Расположение изголовья': (False, ['Сверху']),
#  'Ширина спального места, см': (True, ['140']),
#  'Длина спального места, см': (True, ['200']),
#  'Макс. высота матраса, см': (True, ['30']),
#  'Высота изголовья, см': (True, ['121']),
#  'Матрас в комплекте': (False, ['Нет']),
#  'Высота изножья, см': (True, ['30']),
#  'Ящики для белья': (False, ['Да']),
#  'Вид основания': (False, ['Ортопедические ламели']),
#  'Назначение (помещение)': (False, ['Для дачи', 'Для дома']),
#  'Исполнение': (False, ['Деревянное']),
#  'Материал обивки': (False, ['Велюр искусственный']),
#  'Модель шейного украшения': (False, ['На цепочке']),
#  'Степень газирования': (False, ['Сильногазированная']),
#  'Вкус (лимонад)': (False, ['Ягоды']),
#  'Вес одной шт., г': (True, ['10']),
#  'Количество режимов': (False, ['39447|1']),
#  'Длина рабочей части, мм': (False, ['13.8\xa0см']),
#  'Размер крючка, N': (False, ['12/0']),
#  'Вид крючка': (False, ['Одинарный']),
#  'Абажур в комплекте': (False, ['Да']),
#  'Вид  детского средства': (False, ['Пенка']),
#  'Допуски OEM': (False, ['Нет']),
#  'Вязкость по SAE': (False, ['5W-40']),
#  'Вид масла': (False, ['Синтетическое']),
#  'Классификация по API': (False, ['SN', 'SN PLUS', 'SP']),
#  'Двигатель': (False, ['Бензин']),
#  'ACEA': (False, ['A3', 'B3', 'B4']),
#  'Ширина/диаметр, см': (True, ['33']),
#  'Вид чая': (False, ['Травяной']),
#  'Ферментация': (False, ['Ферментированный']),
#  'Свойства чая': (False, ['Бодрящий', 'Восстанавливающий', 'Очищающий']),
#  'Содержит': (False, ['Минеральные вещества']),
#  'Форма чая': (False, ['Гранулированный']),
#  'Сорт чая': (False, ['Иван-чай']),
#  'Длина ремешка, мм': (True, ['220']),
#  'Макс. ток, А': (False, ['6А']),
#  'Возрастная группа': (False, ['Взрослые (SR)']),
#  'Уровень подготовки': (False, ['Продвинутый']),
#  'Материалы внутреннего ботинка': (False, ['Капровелюр']),
#  'Материалы внешнего ботинка': (False, ['Полимерный материал']),
#  'Материал лезвия': (False, ['Нержавеющая сталь']),
#  'Позиция игрока': (False, ['Полевой игрок']),
#  'Особенности ключницы': (False, ['С дверцей', 'С крючками']),
#  'Декоративный элемент': (False, ['Принт']),
#  'Количество крючков, шт': (True, ['1']),
#  'Число полотен': (True, ['1']),
#  'Основа картины': (False, ['Холст']),
#  'Выкладка/вышивка': (False, ['Полная']),
#  'Форма страз': (False, ['Квадратная']),
#  'Наполнитель': (False, ['Винилискожа', 'Изолон', 'Текстиль']),
#  'Диаметр, см': (False, ['10.10, 5,11, 5,14']),
#  'Степень водо-пылезащиты': (False, ['IP44']),
#  'Вид розетки': (False, ['Евровилка']),
#  'Глубина, мм': (True, ['90']),
#  'Кол-во постов': (True, ['1']),
#  'Ширина товара в упаковке, мм': (True, ['103']),
#  'Высота товара в упаковке, мм': (True, ['440']),
#  'Электроустановочные особенности': (False,
#   ['Заземление', 'Защитные шторки', 'Крышка']),
#  'Тип зажима проводов': (False, ['Винтовой']),
#  'Материал рамки': (False, ['Пластик']),
#  'Модель светодиода': (False, ['Samsung LH351D']),
#  'Механизм зонта': (False, ['Полный автомат']),
#  'Конструкция зонта': (False, ['3 сложения']),
#  'Высота каблука, см': (False, ['Низкий']),
#  'Тип направляющих для мебели': (False, ['Шариковые']),
#  'Сложность головоломки': (True, ['2']),
#  'Принцип игры': (False, ['Перемещение сегментов']),
#  'Вид головоломки': (False, ['Головоломки Рубика']),
#  'Назначение чистящего средства для ванной и туалета': (False,
#   ['Для унитаза']),
#  'Технология производства': (False, ['Сублимированный']),
#  'Без кофеина': (False, ['Нет']),
#  'Количество упаковок, шт': (True, ['10']),
#  'Тип фиксатора БДСМ': (False, ['Наручники']),
#  'Длина кабеля питания, м': (True, ['2']),
#  'Электробезопасность': (False,
#   ['OTP (защита от перегрева)', 'SCP (защита от короткого замыкания)']),
#  'Входное напряжение, В': (False, ['12-24']),
#  'Вид розеток': (False, ['Евровилка']),
#  'Количество розеток, шт': (False, ['0, 0, 0, 0, 0, 0, 0']),
#  'Номинальный ток, А': (False, ['16 А']),
#  'Макс. нагрузка, Вт': (True, ['3500']),
#  'Стандарт защиты': (False, ['IP20']),
#  'Материал ручки': (False, ['Пластик']),
#  'Количество спиц': (True, ['8']),
#  'Длина в сложенном виде, см': (True, ['95']),
#  'Диаметр купола, см': (True, ['69']),
#  'Антишторм': (False, ['Да']),
#  'Материал купола': (False, ['Полиэстер']),
#  'Кол-во в комплекте, шт': (True, ['1']),
#  'Количество нитей': (True, ['4']),
#  'Размотка, м': (True, ['135']),
#  'Разрывная нагрузка, кг': (True, ['6.03']),
#  'Ширина пильного полотна, мм': (True, ['19']),
#  'Шаг зубьев': (False, ['2/3"']),
#  'Совместимый инструмент': (False, ['Пила ленточная']),
#  'Назначение полотна': (False, ['Для металла']),
#  'Вид планшета для рисования': (False, ['Магнитный']),
#  'Уровень сложности набора': (True, ['3']),
#  'Тип краски в наборе': (False, ['Акрил']),
#  'Особенности картин по номерам': (False, ['Без смешивания красок']),
#  'Ориентация картины': (False, ['Вертикальная']),
#  'Форма тарелки': (False, ['Круг']),
#  'Особенности одноразовой посуды': (False,
#   ['Без рисунка', 'Подходит для горячего']),
#  'Материал одноразовой посуды': (False, ['Пластик']),
#  'Место для выращивания': (False, ['Улица']),
#  'Регион выращивания': (False, ['Для всех регионов']),
#  'Вид посадочного материала': (False, ['Тыквы']),
#  'Сорт семян': (False, ['Тыква крупноплодная Россиянка']),
#  'Материал деки': (False, ['Пластик']),
#  'Количество колес': (True, ['2']),
#  'Материал колес': (False, ['Полиуретан']),
#  'Назначение самоката': (False, ['Городской']),
#  'Длина деки, см': (False, ['Sprite Deluxe LED']),
#  'Диаметр переднего колеса, мм': (True, ['200']),
#  'Подшипники': (False, ['ABEC 7']),
#  'Тормоз самоката': (False, ['Ножной']),
#  'Особенности самоката': (False, ['Регулируемый руль', 'Светящиеся колеса']),
#  'Конструкция самоката': (False, ['Складной']),
#  'Ширина деки, см': (True, ['40']),
#  'Диаметр заднего колеса, мм': (True, ['200']),
#  'Подходит для': (False, ['Lenovo']),
#  'Вид запчасти ноутбука/планшета': (False, ['Клавиатура']),
#  'Вид термостата': (False, ['Электронный']),
#  'Управление обогревателем': (False, ['Пульт ДУ']),
#  'Вид обогревателя': (False, ['Конвекционный']),
#  'Макс. площадь помещения, кв.м': (True, ['25']),
#  'Особенности климатической техники': (False,
#   ['Имитация пламени',
#    'Пульт ДУ',
#    'Режим работы без нагрева',
#    'Таймер',
#    'Термостат']),
#  'Тип нагревательного элемента': (False, ['ТЭН']),
#  'Макс. давление, Бар': (True, ['16']),
#  'Входная резьба': (False, ['1/2"']),
#  'Расположение резьбы': (False, ['Внешняя', 'Внутренняя']),
#  'Выходная резьба': (False, ['1/2"']),
#  'Высота платформы, см': (False, ['1.5 см']),
#  'Длина щетки, см': (False, ['600\xa0мм']),
#  'Назначение удобрения': (False, ['Универсальное']),
#  'Гарантия на товар, мес.': (False, ['0,5 месяцев']),
#  'Параметры модели на фото': (False, ['102-82-118']),
#  'Тип антипригарного покрытия': (False, ['Xylan']),
#  'Вид блюда': (False,
#   ['Блины', 'Жаркое', 'Мясо', 'Овощи', 'Плов', 'Птица', 'Рыба']),
#  'Толщина дна, мм': (True, ['5']),
#  'Форма сковороды': (False, ['Круг']),
#  'Высота стенки, см': (True, ['9']),
#  'Вид маски': (False, ['Кремовая']),
#  'Материал подкладки/внутренней отделки': (False, ['Замша']),
#  'Материал фурнитуры': (False, ['Металл']),
#  'Ширина оттиска, мм': (True, ['18']),
#  'Модель штампа': (False, ['Trodat 5435']),
#  'Длина оттиска, мм': (True, ['47']),
#  'Размер основного шрифта, мм': (False, ['3 мм']),
#  'Число строк': (True, ['2']),
#  'Комплектация штемпельной продукции': (False, ['Сменная подушка']),
#  'Вид датера/штампа': (False, ['Самонаборный']),
#  'Вид гриля': (False, ['Гриль']),
#  'Назначение гриля': (False, ['Для дома']),
#  'Вид рабочей поверхности': (False, ['Гриль']),
#  'Расположение нагревательного элемента': (False, ['Сверху и снизу']),
#  'Материал рабочей поверхности': (False, ['Алюминий']),
#  'Датчики': (False, ['Термостат']),
#  'Нагревательный элемент': (False, ['Закрытый']),
#  'Съемные панели': (False, ['Да']),
#  'Вид пастели': (False, ['Масляная']),
#  'Совместимость с фотокамерами': (False, ['Eken', 'GoPro', 'SJCAM', 'Xiaomi']),
#  'Вид застежки': (False, ['Молния']),
#  'Тип молнии': (True, ['3']),
#  'Вид цветных линз': (False, ['Тонирующие']),
#  'Вид мозаики': (False, ['Классическая']),
#  'Тип стоматологического средства': (False,
#   ['Ортодонтический воск для брекетов']),
#  'Цвет ниток': (False, ['Однотонный']),
#  'Предмет вышивки': (False, ['Картина']),
#  'Размер канвы, каунт': (False, ['14 Aida']),
#  'Макс. глубина сверления, мм': (True, ['39']),
#  'Патрон/шпиндель/крепление': (False, ['Резьба 1 1/4"']),
#  'Диаметр сверл, мм': (True, ['4.7']),
#  'Пол животного': (False, ['Мужской']),
#  'Материал подклада': (False, ['Флис']),
#  'Обхват шеи, см': (False, ['28-42']),
#  'Обхват груди животного, см': (False, ['64-70']),
#  'Длина спины, см': (False, ['26-27']),
#  'Место крепления штор': (False,
#   ['В проем', 'На потолок', 'На раму', 'На створку', 'На стену']),
#  'Изгиб ресниц': (False, ['L']),
#  'Длина ресниц, мм': (False, ['6-13']),
#  'Толщина ресниц, мм': (False, ['0.085+']),
#  'Тип волокна ресниц': (False, ['Глянцевые']),
#  'Вид батареи звонка': (False, ['AAA']),
#  'Количество мелодий': (True, ['20']),
#  'Питание звонка': (False, ['От батареи']),
#  'Класс защиты': (False, ['IP44']),
#  'Громкость звонка, дБ': (True, ['50']),
#  'Число батарей звонка, шт.': (True, ['1']),
#  'Особенности штекера/кабеля': (False, ['Одностороннее подключение кабеля']),
#  'Особенности шапки': (False, ['двухслойная']),
#  'Тип аккумулятора': (False, ['Li-ion']),
#  'Список совместимых устройств': (False,
#   ['Lenovo Ideapad L340-15IRH, L340-17IRH']),
#  'Напряжение, В': (False, ['220/380']),
#  'Емкость, мА•ч': (False, ['30Ahx1 ChargerX1']),
#  'Ширина плиты, см': (True, ['50']),
#  'Глубина плиты, см': (False, ['60 см']),
#  'Тип установки': (False, ['Независимая']),
#  'Количество конфорок': (True, ['4']),
#  'Тип конфорок': (False, ['Комбинированные']),
#  'Материал решеток': (False, ['Сталь']),
#  'Объем духовки, л': (False, ['Нет']),
#  'Внутреннее покрытие': (False, ['Эмаль']),
#  'Тип духовки': (False, ['Электрический']),
#  'Количество стекол дверцы духовки': (True, ['2']),
#  'Очистка духовки': (False, ['Традиционная']),
#  'Особенности духовки, плиты': (False, ['Ящик для посуды']),
#  'Потребляемая мощность, Вт': (False, ['5.8 Вт']),
#  'Тип панели (плиты)': (False, ['Комбинированная']),
#  'Совместимость': (False, ['Android; IOS; Windows']),
#  'Количество выходных разъемов': (True, ['4']),
#  'Внешняя оболочка кабеля': (False, ['ПВХ (поливинилхлорид)']),
#  'Материал проводника': (False, ['Медь']),
#  'Коннектор 1': (False, ['Apple Lightning']),
#  'Коннектор 2': (False, ['USB 2.0 Type-A']),
#  'Тип коннектора 1': (False, ['Штекер (male)']),
#  'Тип коннектора 2': (False, ['Штекер (male)']),
#  'Прокладывание кабеля': (False, ['Внутреннее (для помещений)']),
#  'Версия интерфейса': (False, ['USB 2.0']),
#  'Сохранность книги': (False, ['Хорошая']),
#  'Назначение посадочного материала': (False, ['Для огорода']),
#  'Количество элементов, шт': (False, ['Нет']),
#  'Материал покрытия': (False, ['Текстиль']),
#  'Вид гигиенических прокладок': (False, ['Дневные']),
#  'Вид фитиля': (False, ['хлопковый']),
#  'Материал подсвечника': (False, ['Стекло']),
#  'Подарочная упаковка в комплекте': (False, ['Нет']),
#  'Состав свечи': (False, ['Соевый воск']),
#  'Крышка в комплекте': (False, ['Да']),
#  'Время горения, ч': (False, ['до 18']),
#  'В подсвечнике': (False, ['Да']),
#  'Солнцезащитная косметика': (False, ['Нет']),
#  'Вид ароматизатора': (False, ['Аэрозоль']),
#  'Максимальная толщина двери, мм': (True, ['60']),
#  'Тип дверной ручки': (False, ['На розетке']),
#  'Минимальная толщина двери, мм': (True, ['35']),
#  'С узором': (False, ['Нет']),
#  'Вид заготовки для бижутерии': (False, ['Застежка']),
#  'Количество фигурок': (False, ['Элемент миниатюры']),
#  'Совместим с LEGO': (False, ['true']),
#  'Количество деталей конструктора': (False, ['от 500 до 1000 шт']),
#  'Тематика конструкторов': (False, ['Принцессы']),
#  'Особенности конструктора': (False, ['Блочный', 'Сборная модель']),
#  'Длина модели, см': (True, ['25']),
#  'Вид ткани': (False, ['Принтованная']),
#  'Тип накопителя': (False, ['HDD']),
#  'Размер корпуса': (False, ['Midi Tower']),
#  'Модель процессора': (False, ['Intel Core i5']),
#  'Частота процессора, ГГц': (True, ['2']),
#  'Число ядер процессора': (True, ['8']),
#  'Модель графического процессора': (False, ['GeForce GTX 1050 Ti']),
#  'Количество HDD': (True, ['1']),
#  'Чипсет': (False, ['Intel H610']),
#  'Мощность блока питания, Вт': (True, ['700']),
#  'Оперативная память': (False, ['16 ГБ']),
#  'Тип памяти': (False, ['DDR4']),
#  'Возможность расширения RAM, до': (False, ['64 ГБ']),
#  'Форм-фактор RAM': (False, ['DIMM']),
#  'Бренд процессора': (False, ['Intel']),
#  'Бренд графического процессора': (False, ['NVIDIA']),
#  'Оптический привод': (False, ['Отсутствует']),
#  'Версия Windows': (False, ['Windows 10 Pro']),
#  'Тип видеокарты': (False, ['Дискретная']),
#  'Видеопамять': (False, ['4 ГБ']),
#  'Конфигурация': (False,
#   ['Игровой ПК ARENA 5037 (Intel Core i5-12400F/GeForce GTX 1050Ti 4 ГБ/16 ГБ DDR4/1000 ГБ HDD)']),
#  'Сетевая карта': (False, ['1000 Мбит/с (GE)']),
#  'Интерфейсы и разъемы': (False, ['3.5 мм', 'DVI', 'HDMI', 'RJ-45 Ethernet']),
#  'Процессор': (False, ['Intel Core i5-12400F']),
#  'Видеокарта': (False, ['NVIDIA GeForce GTX 1050 Ti (4 Гб)']),
#  'ОС (краткое название)': (False, ['Windows 10 Pro']),
#  'Общий объем HDD, ГБ': (True, ['1000']),
#  'Суммарный объем всех дисков, ГБ': (True, ['256']),
#  'Назначение материала': (False, ['Брючная', 'Костюмная']),
#  'Исполнение излива': (False, ['Поворотный']),
#  'Вид крепления смесителя': (False, ['На гайке']),
#  'Стандарт подводки шланга': (False, ['1/2" х 10 мм']),
#  'Запорный клапан смесителя': (False, ['Керамический картридж']),
#  'Материал лотка': (False, ['Пластик']),
#  'Реверс': (False, ['Нет']),
#  'Вид игрушки для животных': (False, ['Мягкая (текстильная)']),
#  'Место для игр': (False, ['Дом', 'Улица']),
#  'Особенности игрушки': (False, ['С запахом']),
#  'Назначение игрушки': (False,
#   ['Для борьбы со стрессом',
#    'Для отвлечения во время отсутствия хозяина',
#    'Для поддержания питомца в форме']),
#  'Количество игрушек в одной упаковке': (True, ['4']),
#  'Тип реза': (False, ['Сухой']),
#  ...}

# %%
num_attr = list(filter(lambda x: x[1][0], zip(uniq_attr.keys(),uniq_attr.values())))
num_attr
# Out:
# [('Максимальная продолжительность партии, мин.', (True, ['30'])),
#  ('Плотность наполнителя, г/м2', (True, ['300'])),
#  ('Количество предметов в комплекте', (True, ['1'])),
#  ('Расход, кг/м2', (True, ['0.35'])),
#  ('Рекомендуемое количество слоев', (True, ['2'])),
#  ('Срок годности в днях', (True, ['540'])),
#  ('Длина шампура, см', (True, ['75'])),
#  ('Количество шампуров, шт', (True, ['6'])),
#  ('Толщина, мм', (True, ['0.06'])),
#  ('Количество цветов, шт', (True, ['16'])),
#  ('Внутренний диаметр брашинга, мм', (True, ['18'])),
#  ('Оптическая сила', (True, ['+4.00'])),
#  ('Радиус кривизны', (True, ['8.5'])),
#  ('Влагосодержание, %', (True, ['55'])),
#  ('Количество внешних карманов, шт', (True, ['1'])),
#  ('Плотность ткани, г/кв.м', (True, ['1'])),
#  ('Количество насадок', (True, ['3'])),
#  ('Объем чаши, л', (True, ['0.4'])),
#  ('Макс. мощность (при блокировке мотора), Вт', (True, ['2000'])),
#  ('Производительность, кг/мин', (True, ['2.5'])),
#  ('Количество предметов', (True, ['6'])),
#  ('Макс. мощность СВЧ, Вт', (True, ['700'])),
#  ('Время мойки при обычной программе, мин', (True, ['60'])),
#  ('Вместимость, комплектов', (True, ['14'])),
#  ('Количество программ', (True, ['6'])),
#  ('Расход воды за цикл, л', (True, ['10'])),
#  ('Количество пружин на спальное место', (True, ['512'])),
#  ('Макс. вес на спальное место, кг', (True, ['120'])),
#  ('Содержания какао, %', (True, ['33'])),
#  ('Макс. световой поток, Люмен', (True, ['12000'])),
#  ('Кол-во светодиодов', (True, ['37'])),
#  ('Макс. время работы от батарей, ч', (True, ['12'])),
#  ('Дальность освещения, м', (True, ['2000'])),
#  ('Кол-во режимов', (True, ['4'])),
#  ('Число отделений, шт', (True, ['1'])),
#  ('Вес перчатки, oz (унций)', (True, ['6'])),
#  ('Диаметр динамика, мм', (True, ['40'])),
#  ('Вес с упаковкой, г', (True, ['997'])),
#  ('Шаг зубьев (TPI)', (True, ['7'])),
#  ('Длина лезвия, мм', (True, ['9'])),
#  ('Количество в комплекте, шт.', (True, ['1'])),
#  ('Усилие, Н', (True, ['50'])),
#  ('Угол подъема, °', (True, ['110'])),
#  ('Число основных чаш', (True, ['1'])),
#  ('Диаметр слива, мм', (True, ['45'])),
#  ('Объем бассейна, л', (True, ['6478'])),
#  ('Время установки, мин', (True, ['45'])),
#  ('Кол-во внутренних отделений', (True, ['1'])),
#  ('Индекс жесткости', (True, ['110.0'])),
#  ('Количество фломастеров, шт', (True, ['12'])),
#  ('Макс. давление, бар', (True, ['20'])),
#  ('Кол-во приготовляемых чашек кофе, шт', (True, ['3'])),
#  ('Диагональ экрана, см', (True, ['190'])),
#  ('Количество разъемов USB', (True, ['1'])),
#  ('Мощность аудиосистемы, Вт', (True, ['30'])),
#  ('Число портов HDMI', (True, ['1'])),
#  ('Ось (AXIS)', (True, ['60'])),
#  ('Количество рулонов клейкой ленты, шт', (True, ['6'])),
#  ('Угол рассеивания, °', (True, ['70'])),
#  ('Высота ворса, мм', (True, ['3'])),
#  ('Количество цветов', (True, ['1'])),
#  ('Вес маховика, кг', (True, ['12'])),
#  ('Обхват шеи максимальный, cм', (True, ['56'])),
#  ('Максимальный вес пользователя, кг', (True, ['120'])),
#  ('Максимальная скорость, км/ч', (True, ['18'])),
#  ('Длина бегового полотна, см', (True, ['107'])),
#  ('Ширина бегового полотна, см', (True, ['40'])),
#  ('Макс. обороты холостого хода, об/мин', (True, ['5000'])),
#  ('Глубина пропила под 90°, мм', (True, ['60'])),
#  ('Глубина пропила под 45°, мм', (True, ['30'])),
#  ('Диаметр диска, см', (True, ['21'])),
#  ('Ширина линзы, мм', (True, ['53'])),
#  ('Размер заушника, мм', (True, ['145'])),
#  ('Размер моста на переносице, мм', (True, ['20'])),
#  ('Длина товара в упаковке, мм', (True, ['80'])),
#  ('Количество рулонов', (True, ['1'])),
#  ('Высота сиденья, см', (True, ['45'])),
#  ('Диаметр заряда, мм', (True, ['70'])),
#  ('Высота подъема, м', (True, ['3'])),
#  ('Количество эффектов', (True, ['7'])),
#  ('Число зарядов', (True, ['49'])),
#  ('Время работы, с', (True, ['60'])),
#  ('Время работы, мин', (True, ['30'])),
#  ('Количество батареек пульта', (True, ['1'])),
#  ('Число каналов связи', (True, ['9'])),
#  ('Коэффициент усиления антенны, dBi', (True, ['3'])),
#  ('Паровой удар, г/мин', (True, ['430'])),
#  ('Ширина корешка, мм', (True, ['15'])),
#  ('Количество, штук', (True, ['4'])),
#  ('Высота ножек, мм', (True, ['50'])),
#  ('Ширина спального места, см', (True, ['140'])),
#  ('Длина спального места, см', (True, ['200'])),
#  ('Макс. высота матраса, см', (True, ['30'])),
#  ('Высота изголовья, см', (True, ['121'])),
#  ('Высота изножья, см', (True, ['30'])),
#  ('Вес одной шт., г', (True, ['10'])),
#  ('Ширина/диаметр, см', (True, ['33'])),
#  ('Длина ремешка, мм', (True, ['220'])),
#  ('Количество крючков, шт', (True, ['1'])),
#  ('Число полотен', (True, ['1'])),
#  ('Глубина, мм', (True, ['90'])),
#  ('Кол-во постов', (True, ['1'])),
#  ('Ширина товара в упаковке, мм', (True, ['103'])),
#  ('Высота товара в упаковке, мм', (True, ['440'])),
#  ('Сложность головоломки', (True, ['2'])),
#  ('Количество упаковок, шт', (True, ['10'])),
#  ('Длина кабеля питания, м', (True, ['2'])),
#  ('Макс. нагрузка, Вт', (True, ['3500'])),
#  ('Количество спиц', (True, ['8'])),
#  ('Длина в сложенном виде, см', (True, ['95'])),
#  ('Диаметр купола, см', (True, ['69'])),
#  ('Кол-во в комплекте, шт', (True, ['1'])),
#  ('Количество нитей', (True, ['4'])),
#  ('Размотка, м', (True, ['135'])),
#  ('Разрывная нагрузка, кг', (True, ['6.03'])),
#  ('Ширина пильного полотна, мм', (True, ['19'])),
#  ('Уровень сложности набора', (True, ['3'])),
#  ('Количество колес', (True, ['2'])),
#  ('Диаметр переднего колеса, мм', (True, ['200'])),
#  ('Ширина деки, см', (True, ['40'])),
#  ('Диаметр заднего колеса, мм', (True, ['200'])),
#  ('Макс. площадь помещения, кв.м', (True, ['25'])),
#  ('Макс. давление, Бар', (True, ['16'])),
#  ('Толщина дна, мм', (True, ['5'])),
#  ('Высота стенки, см', (True, ['9'])),
#  ('Ширина оттиска, мм', (True, ['18'])),
#  ('Длина оттиска, мм', (True, ['47'])),
#  ('Число строк', (True, ['2'])),
#  ('Тип молнии', (True, ['3'])),
#  ('Макс. глубина сверления, мм', (True, ['39'])),
#  ('Диаметр сверл, мм', (True, ['4.7'])),
#  ('Количество мелодий', (True, ['20'])),
#  ('Громкость звонка, дБ', (True, ['50'])),
#  ('Число батарей звонка, шт.', (True, ['1'])),
#  ('Ширина плиты, см', (True, ['50'])),
#  ('Количество конфорок', (True, ['4'])),
#  ('Количество стекол дверцы духовки', (True, ['2'])),
#  ('Количество выходных разъемов', (True, ['4'])),
#  ('Максимальная толщина двери, мм', (True, ['60'])),
#  ('Минимальная толщина двери, мм', (True, ['35'])),
#  ('Длина модели, см', (True, ['25'])),
#  ('Частота процессора, ГГц', (True, ['2'])),
#  ('Число ядер процессора', (True, ['8'])),
#  ('Количество HDD', (True, ['1'])),
#  ('Мощность блока питания, Вт', (True, ['700'])),
#  ('Общий объем HDD, ГБ', (True, ['1000'])),
#  ('Суммарный объем всех дисков, ГБ', (True, ['256'])),
#  ('Количество игрушек в одной упаковке', (True, ['4'])),
#  ('Количество зубьев, шт.', (True, ['35'])),
#  ('Минимальная длина стрижки, мм', (True, ['3'])),
#  ('Максимальная длина стрижки, мм', (True, ['12'])),
#  ('Ширина ножа, мм', (True, ['46'])),
#  ('Шаг винта', (True, ['8'])),
#  ('Количество лопастей гребного винта', (True, ['3'])),
#  ('Количество режимов работы', (True, ['11'])),
#  ('Количество тостов', (True, ['2'])),
#  ('Общая ширина, мм', (True, ['141'])),
#  ('Число слоев наполнителя', (True, ['2'])),
#  ('Ширина в плечах, см', (True, ['80.0'])),
#  ('Ширина в ногах, см', (True, ['50.0'])),
#  ('Длина в свернутом состоянии, см', (True, ['40'])),
#  ('Ширина в свернутом состоянии, см', (True, ['25'])),
#  ('Толщина в свернутом состоянии, см', (True, ['25'])),
#  ('Точность измерения, г', (True, ['5'])),
#  ('Внешний диаметр, мм', (True, ['11'])),
#  ('Внутренний диаметр, мм', (True, ['78.6'])),
#  ('Макс. рабочая температура, °С', (True, ['65'])),
#  ('Макс. напор, м', (True, ['8'])),
#  ('Скорость чтения, Мб/с', (True, ['128'])),
#  ('Скорость записи, Мб/с', (True, ['64'])),
#  ('Диаметр крючка, мм', (True, ['5'])),
#  ('Длина карниза, см', (True, ['144'])),
#  ('Макс. нагрузка на полку, кг', (True, ['30'])),
#  ('Количество клавиш клавиатуры', (True, ['104'])),
#  ('Количество полос', (True, ['2'])),
#  ('Диаметр основного круга, мм', (True, ['42'])),
#  ('Количество клавиш', (True, ['1'])),
#  ('Длина поводка, м', (True, ['3'])),
#  ('Кол-во циклов заряд-разряд', (True, ['800'])),
#  ('Теплопроводность, Вт/(м⋅К)', (True, ['12.8'])),
#  ('Число жил', (True, ['8'])),
#  ('Сечение жилы, кв.мм', (True, ['1'])),
#  ('Белки, г/100 г', (True, ['0'])),
#  ('Жиры, г/100 г', (True, ['0'])),
#  ('Углеводы, г/100 г', (True, ['96'])),
#  ('Количество встроенной памяти, ГБ', (True, ['64'])),
#  ('Количество полюсов', (True, ['1'])),
#  ('Число пакетиков', (True, ['25'])),
#  ('Диаметр жилы, мм', (True, ['0.57'])),
#  ('Количество инструментов в наборе, шт.', (True, ['82'])),
#  ('Макс. заглубление, м', (True, ['1.4'])),
#  ('Мин. заглубление, м', (True, ['0.6'])),
#  ('Ширина профиля окна, мм', (True, ['70'])),
#  ('Количество камер', (True, ['2'])),
#  ('Количество створок', (True, ['1'])),
#  ('Скорость вышивания, ст./мин', (True, ['400'])),
#  ('Макс. высота подъема лапки, мм', (True, ['9'])),
#  ('Площадь рулона, м2', (True, ['0.9'])),
#  ('Максимальное давление газа, мбар', (True, ['13'])),
#  ('Максимальное давление воды (бар)', (True, ['7.5'])),
#  ('Диаметр спиц, мм', (True, ['4.5'])),
#  ('Площадь действия, м²', (True, ['30'])),
#  ('Минимальная влажность, %', (True, ['75'])),
#  ('Максимальная влажность, %', (True, ['75'])),
#  ('Индекс нагрузки', (True, ['110'])),
#  ('Ширина профиля, мм', (True, ['235'])),
#  ('Высота профиля, %', (True, ['65'])),
#  ('Мин. высота сиденья, см', (True, ['43'])),
#  ('Ширина сиденья, см', (True, ['42'])),
#  ('Высота спинки, см', (True, ['29'])),
#  ('Ширина спинки, см', (True, ['42'])),
#  ('Макс. высота сиденья, см', (True, ['53'])),
#  ('Минимальная высота, см', (True, ['99'])),
#  ('Максимальная высота, см', (True, ['109'])),
#  ('Толщина столешницы, мм', (True, ['15'])),
#  ('Высота подставки, см', (True, ['19.5'])),
#  ('Количество основных камер', (True, ['3'])),
#  ('Работа в режиме ожидания, ч', (True, ['547.8'])),
#  ('Кол-во крепежных отверстий', (True, ['5'])),
#  ('Диаметр расположения отверстий (PCD)', (True, ['108'])),
#  ('Длина трубы, м', (True, ['0.5'])),
#  ('Шаг резьбы, мм', (True, ['2.5'])),
#  ('Кол-во уровней положения основания', (True, ['1'])),
#  ('Количество капсул в упаковке', (True, ['10'])),
#  ('Содержание арабики, %', (True, ['100'])),
#  ('Количество ручек, шт', (True, ['1'])),
#  ('Количество экспериментов в наборе', (True, ['1'])),
#  ('Вес в собранном состоянии, кг', (True, ['9.2'])),
#  ('Минимальный диаметр, мм', (True, ['5'])),
#  ('Форм-фактор M.2', (True, ['2280'])),
#  ('Макс. выходной ток', (True, ['2.1'])),
#  ('Влажность древесины, не более (%)', (True, ['10'])),
#  ('Мин. температура применения, C', (True, ['5'])),
#  ('Макс. температура применения, C', (True, ['35'])),
#  ('Толщина лезвия, мм', (True, ['34'])),
#  ('Макс. длина лезвия, см', (True, ['15.8'])),
#  ('Количество ножей', (True, ['1'])),
#  ('Макс температура воды, °С', (True, ['50'])),
#  ('Длина шланга, м', (True, ['20'])),
#  ('Макс. обороты, об./мин', (True, ['32000'])),
#  ('Количество двигателей, шт', (True, ['1'])),
#  ('С какого месяца можно давать лакомство', (True, ['3'])),
#  ('Диаметр батута, см', (True, ['180'])),
#  ('Высота от пола до основания батута, см', (True, ['46'])),
#  ('Высота защитной сетки, см', (True, ['150'])),
#  ('Кол-во пружин, шт', (True, ['96'])),
#  ('Высота зеркала, см', (True, ['33'])),
#  ('Ширина зеркала, см', (True, ['35'])),
#  ('Количество карандашей, шт', (True, ['4'])),
#  ('Длина столешницы, см', (True, ['65'])),
#  ('Длина столешницы в разложенном виде, см', (True, ['159'])),
#  ('Ширина столешницы, см', (True, ['65'])),
#  ('Диаметр центр. отверстия, мм', (True, ['67'])),
#  ('Вылет, мм', (True, ['15'])),
#  ('Количество маркеров, шт', (True, ['262'])),
#  ('Толщина, см', (True, ['0.4'])),
#  ('Макс. частота обновления, Гц', (True, ['60'])),
#  ('Диаметр крепежа, мм', (True, ['6.3'])),
#  ('Длина крепежа, мм', (True, ['160'])),
#  ('Кол-во розеток', (True, ['1'])),
#  ('Площадь обогрева, кв.м', (True, ['11'])),
#  ('Макс. сопротивление, Ом', (True, ['718.5'])),
#  ('Количество динамиков', (True, ['3'])),
#  ('Количество ножек', (True, ['6'])),
#  ('Количество двигателей', (True, ['1'])),
#  ('Мин. высота над электрической плитой, см', (True, ['65'])),
#  ('Мин. высота над газовой плитой, см', (True, ['75'])),
#  ('Мощность подсветки, Вт', (True, ['4'])),
#  ('Количество ламп освещения вытяжки, шт', (True, ['1'])),
#  ('Количество жировых фильтров, шт.', (True, ['1'])),
#  ('Длина ленты, м', (True, ['57'])),
#  ('Количество отводов', (True, ['2'])),
#  ('Количество подгузников в одной упаковке', (True, ['44'])),
#  ('Число секций', (True, ['24'])),
#  ('Рекомендуемая площадь, м²', (True, ['22'])),
#  ('Рабочее давление, атм', (True, ['16'])),
#  ('Ширина рамы, см', (True, ['0'])),
#  ('Показатель мощности (kBTU)', (True, ['12'])),
#  ('Уровень шума внешнего блока, дБ', (True, ['54'])),
#  ('Вес внешнего блока, кг', (True, ['20.2'])),
#  ('Вес внутреннего блока, кг', (True, ['8'])),
#  ('Мощность в режиме охлаждения, Вт', (True, ['3550'])),
#  ('Охлаждающая способность, BTU', (True, ['9000'])),
#  ('Число дверей', (True, ['1'])),
#  ('Высота первой шторы, см', (True, ['270'])),
#  ('Ширина первой шторы, см', (True, ['200'])),
#  ('Глубина зажима, мм', (True, ['50'])),
#  ('Ширина зажима, мм', (True, ['65'])),
#  ('Максимальный пусковой ток, А', (True, ['2500'])),
#  ('Макс. емкость аккумулятора, А•ч', (True, ['2'])),
#  ('Максимальный ток заряда, А', (True, ['2'])),
#  ('Количество кнопок', (True, ['6'])),
#  ('Макс. диаметр конфорки, см', (True, ['15'])),
#  ('Мин. температура, °С', (True, ['0'])),
#  ('Количество программ/режимов', (True, ['3'])),
#  ('Длина спального места в разложенном виде, см', (True, ['190'])),
#  ('Ширина спального места в разложенном виде, см', (True, ['68'])),
#  ('Количество SSD', (True, ['1'])),
#  ('Минимальная высота/длина, см', (True, ['50'])),
#  ('Количество секций, шт', (True, ['5'])),
#  ('Грузоподъемность, кг', (True, ['80'])),
#  ('Диаметр лопастей, см', (True, ['40'])),
#  ('Изменяемый объем, л', (True, ['33'])),
#  ('Количество входов', (True, ['1'])),
#  ('Высота второй шторы, см', (True, ['270'])),
#  ('Ширина второй шторы, см', (True, ['200'])),
#  ('Ширина крепления шторы, см', (True, ['144'])),
#  ('Количество упаковок, шт.', (True, ['1'])),
#  ('Общее количество капсул/таблеток', (True, ['12'])),
#  ('Макс. диаметр отверстия в стали, мм', (True, ['10'])),
#  ('Макс. диаметр отверстия в дереве, мм', (True, ['10'])),
#  ('Макс. обороты на 2ой скорости, об./мин', (True, ['4000'])),
#  ('Макс. диаметр отверстия в бетоне, мм', (True, ['10'])),
#  ('Мин. диаметр патрона, мм', (True, ['1.5'])),
#  ('Время работы в режиме разговора, ч', (True, ['44.2'])),
#  ('Количество таблеток/капсул в одной упаковке, шт', (True, ['60'])),
#  ('Общая максимальная нагрузка, кг', (True, ['408'])),
#  ('Общее количество, шт', (True, ['1000'])),
#  ('Толщина стекла, мм', (True, ['6'])),
#  ('Пассажировместимость, чел.', (True, ['2'])),
#  ('Грузоподъемность лодки, кг', (True, ['250'])),
#  ('Чувствительность, дБ', (True, ['80'])),
#  ('Время зарядки аккумулятора, мин', (True, ['210'])),
#  ('Число дополнительных чаш', (True, ['0'])),
#  ('Теплоотдача, Вт', (True, ['2136'])),
#  ('Толщина дверцы, мм', (True, ['3'])),
#  ('Количество в одной упаковке, шт', (True, ['1'])),
#  ('Количество контактов', (True, ['17'])),
#  ('Макс. сечение кабеля, мм²', (True, ['6'])),
#  ('Диаметр отверстия, мм', (True, ['5'])),
#  ('Уровень шума, дБ (А)', (True, ['24'])),
#  ('Номинальная отключающая способность, кA', (True, ['4.5'])),
#  ('Количество модулей', (True, ['3'])),
#  ('Количество лакомств в одной упаковке', (True, ['3'])),
#  ('Обхват шеи минимальный, см', (True, ['34'])),
#  ('Ширина ошейника, мм', (True, ['20'])),
#  ('Длина ошейника общая, см', (True, ['44'])),
#  ('Рабочая длина, см', (True, ['500'])),
#  ('Давление пара, Бар', (True, ['6.5'])),
#  ('Мин. сечение кабеля, мм²', (True, ['4'])),
#  ('Макс. сила тока, А', (True, ['16'])),
#  ('Число полок', (True, ['1'])),
#  ('Длина лапы, см', (True, ['6.5'])),
#  ('Ширина лапы, см', (True, ['5.1'])),
#  ('Длина рукава, см', (True, ['50'])),
#  ('Оптическая сила (диоптрии)', (True, ['0.00'])),
#  ('Высота штанги, см', (True, ['40'])),
#  ('Длина шланга, см', (True, ['150'])),
#  ('Количество потребителей', (True, ['1596'])),
#  ('Длина гирлянды, м', (True, ['10'])),
#  ('Количество камер, шт.', (True, ['1'])),
#  ('Число пикселей матрицы, Мпикс', (True, ['20'])),
#  ('Угол обзора по диагонали, °', (True, ['140'])),
#  ('Длина лезвия, см', (True, ['16'])),
#  ('Количество инструментов', (True, ['1'])),
#  ('Толщина обуха, мм', (True, ['2.5'])),
#  ('Общая длина, см', (True, ['27'])),
#  ('Минимальный момент затяжки, Н·м', (True, ['20'])),
#  ('Зазор между электродами, мм', (True, ['1.1'])),
#  ('Максимальный момент затяжки, Н·м', (True, ['25'])),
#  ('Число боковых электродов', (True, ['1'])),
#  ('Длина резьбы, мм', (True, ['35'])),
#  ('Активная мощность, Вт', (True, ['480'])),
#  ('Время переключения на батарею, мс', (True, ['4'])),
#  ('Мин. рабочая температура, °С', (True, ['0'])),
#  ('Количество фото, шт', (True, ['2'])),
#  ('Количество форм трансформации', (True, ['2'])),
#  ('Коэффициент мощности', (True, ['90'])),
#  ('Макс. тепловая мощность, кВт', (True, ['7'])),
#  ('Диаметр столбика, см', (True, ['10'])),
#  ('Длина столбика, см', (True, ['24'])),
#  ('Диаметр подключения сифона, см', (True, ['4.6'])),
#  ('Класс подшипников (ABEC)', (True, ['7'])),
#  ('Время непрерывной работы, мин', (True, ['20'])),
#  ('Разрывная нагрузка, lb', (True, ['2'])),
#  ('Диаметр, #PE', (True, ['0.1'])),
#  ('Мощность, л.с.', (True, ['2.4'])),
#  ('Мин. высота среза травы, см', (True, ['0.5'])),
#  ('Макс. высота среза травы, см', (True, ['15'])),
#  ('Объем травосборника, л', (True, ['45'])),
#  ('Ширина обработки, см', (True, ['33'])),
#  ('Объем двигателя, куб.см', (True, ['51.7'])),
#  ('Объем топливного бака, л', (True, ['4.2'])),
#  ('Количество рядов', (True, ['1'])),
#  ('Гарантия на внутренний бак, мес.', (True, ['36'])),
#  ('Тактовая частота, МГц', (True, ['4266'])),
#  ('RAS to CAS Delay (tRCD), тактов', (True, ['23'])),
#  ('Row Precharge Delay (tRP), тактов', (True, ['23'])),
#  ('Количество модулей в комплекте', (True, ['4'])),
#  ('Пропускная способность, Мб/с', (True, ['34100'])),
#  ('CAS Latency (CL), тактов', (True, ['19'])),
#  ('Размер карабина вертлюга, мм', (True, ['18'])),
#  ('Размер застежки', (True, ['00'])),
#  ('Количество компрессоров', (True, ['1'])),
#  ('Общий объем, л', (True, ['97'])),
#  ('Общий объем холодильной камеры, л', (True, ['87'])),
#  ('Количество полок на двери', (True, ['4'])),
#  ('Годовое потребление, кВт ч/год', (True, ['342'])),
#  ('Ширина ленты, мм', (True, ['13'])),
#  ('Реальный угол зрения, °', (True, ['7.2'])),
#  ('Минимальная дистанция фокусировки, м', (True, ['3'])),
#  ('Сумеречное число', (True, ['20.5'])),
#  ('Рабочая частота, Гц', (True, ['50'])),
#  ('Мин. радиус изгиба кабеля, мм', (True, ['35'])),
#  ('Число предметов, шт', (True, ['4'])),
#  ('Ширина режущей части, мм', (True, ['12'])),
#  ('Диаметр шланга, мм', (True, ['19'])),
#  ('Дальность полива, м', (True, ['0'])),
#  ('Количество режимов нагрева', (True, ['3'])),
#  ('Число портов USB Type-C', (True, ['1'])),
#  ('Число портов USB Type-A  3.2 Gen 1', (True, ['2'])),
#  ('Кол-во элементов аккумулятора', (True, ['4'])),
#  ('Число портов DisplayPort', (True, ['1'])),
#  ('Макс. ширина ТВ, см', (True, ['200'])),
#  ('Количество каналов, шт.', (True, ['4'])),
#  ('Номинальная выходная мощность на канал, Вт', (True, ['30'])),
#  ('Макс. выходная мощность на канал, Вт', (True, ['50'])),
#  ('Количество ядер', (True, ['8'])),
#  ('Макс. нагрузка на полку ТВ, кг', (True, ['30'])),
#  ('Макс. высота ТВ, см', (True, ['100'])),
#  ('Макс. диагональ экрана ТВ, дюймы', (True, ['80'])),
#  ('Диаметр нижнего яруса, см', (True, ['60'])),
#  ('Время работы от аккумулятора, дни', (True, ['5'])),
#  ('Количество программ стирки', (True, ['11'])),
#  ('Максимальная скорость отжима, об./мин.', (True, ['1200'])),
#  ('Встроенная память, ГБ', (True, ['32'])),
#  ('Количество капель', (True, ['2'])),
#  ('Общая длина, мм', (True, ['169'])),
#  ('Начальная скорость, м/с', (True, ['120'])),
#  ('Ёмкость магазина, шт', (True, ['13'])),
#  ('Объем пылесборника, мл', (True, ['250'])),
#  ('Сила всасывания, Па', (True, ['1000'])),
#  ('Время работы в режиме ожидания, ч', (True, ['40'])),
#  ('Объем встроенной памяти, ГБ', (True, ['128'])),
#  ('Диаметр колеса, мм', (True, ['100'])),
#  ('Диаметр оси колеса, мм', (True, ['20'])),
#  ('Время зарядки аккумулятора, ч', (True, ['8'])),
#  ('Температура срабатывания, C', (True, ['85'])),
#  ('Объем буферной памяти, Мб', (True, ['256'])),
#  ('Количество аккумуляторов в комплекте', (True, ['1'])),
#  ('Число портов USB 2.0', (True, ['2'])),
#  ('Количество светодиодов на метр', (True, ['60'])),
#  ('Высота чаши, см', (True, ['36'])),
#  ('Ширина зева гаечного ключа, мм', (True, ['16'])),
#  ('Толщина профиля, мм', (True, ['9'])),
#  ('Высота профиля, мм', (True, ['45'])),
#  ('Мощность всасывания, Вт', (True, ['400'])),
#  ('Число портов USB Type-A 3.2 Gen 2', (True, ['2'])),
#  ('Число портов Thunderbolt', (True, ['2'])),
#  ('Число управляемых устройств, шт.', (True, ['1'])),
#  ('Мощность варочной панели, Вт', (True, ['7200'])),
#  ('Количество двухконтурных конфорок', (True, ['1'])),
#  ('Макс. время работы (музыка),  ч', (True, ['20'])),
#  ('Макс. время работы (видео),  ч', (True, ['4'])),
#  ('Встроенная память,  ГБ', (True, ['512'])),
#  ('Минимальная освещенность, люкс', (True, ['0.0005'])),
#  ('Производительность, л/ч', (True, ['0.35'])),
#  ('Макс. расстояние от стены, мм', (True, ['430'])),
#  ('Мин. расстояние от стены, мм', (True, ['59'])),
#  ('Количество динамиков ВЧ', (True, ['1'])),
#  ('Количество колонок в комплекте', (True, ['1'])),
#  ('Длина пластин, мм', (True, ['100'])),
#  ('Количество PCI-E x16', (True, ['2'])),
#  ('Количество PCI-E x1', (True, ['2'])),
#  ('Количество разъемов M.2', (True, ['2'])),
#  ('Количество слотов RAM', (True, ['4'])),
#  ('Макс. поддерживаемая частота RAM', (True, ['4600'])),
#  ('Кол-во внутренних разъемов SATA 6 Гбит/с', (True, ['6'])),
#  ('Макс. частота графического процессора (Boost), МГц', (True, ['2535'])),
#  ('Частота графического процессора, МГц', (True, ['2520'])),
#  ('Кол-во занимаемых слотов', (True, ['3.75'])),
#  ('Количество вентиляторов', (True, ['3'])),
#  ('Число универсальных процессоров', (True, ['16384'])),
#  ('Количество поддерживаемых мониторов', (True, ['3'])),
#  ('Число текстурных блоков', (True, ['512'])),
#  ('Кол-во выходов HDMI', (True, ['1'])),
#  ('Число блоков растеризации', (True, ['176'])),
#  ('Версия шейдеров', (True, ['6.0'])),
#  ('Кол-во выходов Display Port', (True, ['3'])),
#  ('Рекомендуемая мощность БП, Вт', (True, ['1000'])),
#  ('Макс. время работы, дни', (True, ['45'])),
#  ('Количество микрофонов', (True, ['4'])),
#  ('Макс. время записи, часов', (True, ['30'])),
#  ('Площадь, кв.м', (True, ['20'])),
#  ('Размер под ключ, мм', (True, ['13'])),
#  ('Высота доски, см', (True, ['12'])),
#  ('Максимальная ширина створки, м', (True, ['6'])),
#  ('Максимальный вес ворот, кг', (True, ['1300'])),
#  ('Максимальный вес створки, кг', (True, ['1500'])),
#  ('Площадь листа, м2', (True, ['12.6'])),
#  ('Длина клеевого стержня, мм', (True, ['200'])),
#  ('Количество пеленок в одной упаковке, шт', (True, ['5'])),
#  ('Мин. диаметр хомута, мм', (True, ['1'])),
#  ('Длина хомута, мм', (True, ['500'])),
#  ('Макс. увеличение, крат', (True, ['100'])),
#  ('Площадь в упаковке, м2', (True, ['0.75'])),
#  ('Плотность, кг/м3', (True, ['510'])),
#  ('Макс. вертикальная нагрузка на фаркоп, кг', (True, ['75'])),
#  ('Мин. сварочный ток, А', (True, ['10'])),
#  ('Макс. диаметр электрода, мм', (True, ['4'])),
#  ('Макс. частота колебаний, кол./мин', (True, ['11000'])),
#  ('Время работы на одном заряде, ч', (True, ['40'])),
#  ('Количество звеньев', (True, ['52'])),
#  ('Макс. ширина распила, мм', (True, ['300'])),
#  ('Угол отвода, °', (True, ['180'])),
#  ('Размер головки, мм', (True, ['32'])),
#  ('Глубина встраивания, см', (True, ['48'])),
#  ('Минимальная плотность бумаги, г/м2', (True, ['60'])),
#  ('Максимальная плотность бумаги, г/м2', (True, ['105'])),
#  ('Выходной лоток, листов', (True, ['50'])),
#  ('Максимальная ширина чека/этикетки, мм', (True, ['18'])),
#  ('Минимальное давление воды (бар)', (True, ['1'])),
#  ('Мин. поддерживаемая температура, °C', (True, ['16'])),
#  ('Макс. поддерживаемая температура, °C', (True, ['30'])),
#  ('Макс. тест, граммы', (True, ['100'])),
#  ('Кол-во, шт', (True, ['1'])),
#  ('Макс. выходной ток, А', (True, ['8.5'])),
#  ('Макс. выходная мощность, Вт', (True, ['5'])),
#  ('Макс. входное напряжение, В', (True, ['24'])),
#  ('Мин. входное напряжение, В', (True, ['12'])),
#  ('Диаметр бурения, мм', (True, ['150'])),
#  ('Разрядность калькулятора', (True, ['12'])),
#  ('Мощность массажера, Вт', (True, ['5'])),
#  ('Доп. слоты RAM памяти', (True, ['1'])),
#  ('Нагрузка на фрикцион, кг', (True, ['25'])),
#  ('Диаметр катушки, мм', (True, ['30'])),
#  ('Количество бритвенных головок', (True, ['2'])),
#  ('Общий объем морозильной камеры, л', (True, ['10'])),
#  ('Автономное сохранение холода, ч', (True, ['17'])),
#  ('Количество подключаемых устройств', (True, ['10'])),
#  ('Количество антенн', (True, ['4'])),
#  ('Количество LAN портов', (True, ['2'])),
#  ('Количество WAN портов', (True, ['5'])),
#  ('Количество трехконтурных конфорок', (True, ['1'])),
#  ('Количество веток, шт', (True, ['39'])),
#  ('Количество ярусов елки', (True, ['7'])),
#  ('Время приготовления, мин', (True, ['7'])),
#  ('Размер мяча', (True, ['5'])),
#  ('Ширина ски-стопа, мм', (True, ['75'])),
#  ('Максимальный рост пользователя, см', (True, ['185'])),
#  ('Минимальный рост пользователя, см', (True, ['100'])),
#  ('Количество ребер жесткости', (True, ['6'])),
#  ('Количество этикеток, шт', (True, ['1000'])),
#  ('Длина большей стороны, мм', (True, ['43'])),
#  ('Длина меньшей стороны, мм', (True, ['25'])),
#  ('Светопропускаемость, %', (True, ['5'])),
#  ('Мин. тест, граммы', (True, ['10.5'])),
#  ('Количество массажных роликов', (True, ['12'])),
#  ('Транспортная длина, см', (True, ['20'])),
#  ('Максимальный расход, м3/ч', (True, ['1.5'])),
#  ('Номинальный расход, м3/ч', (True, ['10'])),
#  ('Глубина пропила в стали, мм', (True, ['6'])),
#  ('Глубина пропила в алюминии (легких сплавах), мм', (True, ['12'])),
#  ('Количество рулонов в упаковке, шт', (True, ['6'])),
#  ('Толщина коврика, мм', (True, ['8'])),
#  ('Площадь, дм²', (True, ['150'])),
#  ('Размер набора, см', (True, ['27.5'])),
#  ('Сила сцепления, кг', (True, ['2'])),
#  ('Количество бегунков', (True, ['1'])),
#  ('Количество персон, шт', (True, ['18'])),
#  ('Объем бутылки, л', (True, ['0.25'])),
#  ('Макс. темп. снаружи, +°С', (True, ['80'])),
#  ('Радиус приема сигнала датчика, м', (True, ['30'])),
#  ('Макс. число датчиков, шт.', (True, ['3'])),
#  ('Межцентровое расстояние, мм', (True, ['0'])),
#  ('Содержание спирта, %', (True, ['64'])),
#  ('Полная выходная мощность звука, Вт', (True, ['250'])),
#  ('Количество батарей, шт', (True, ['1'])),
#  ('Длина шага, см', (True, ['66'])),
#  ('Ток утечки, мА', (True, ['30'])),
#  ('Макс. ширина пакета, см', (True, ['28'])),
#  ('Степень вакуума, бар', (True, ['0.95'])),
#  ('Толщина гидрокостюма, мм', (True, ['5'])),
#  ('Интенсивность привода ворот, %', (True, ['30'])),
#  ('Шаг гвоздя, мм', (True, ['10'])),
#  ('Расход воздуха, л/мин', (True, ['133'])),
#  ('Рабочее давление, бар', (True, ['3'])),
#  ('Диаметр сопла, мм', (True, ['0.7'])),
#  ('Объем бака, мл', (True, ['600'])),
#  ('Толщина тормозного диска, мм', (True, ['12'])),
#  ('Пробивная способность, листов', (True, ['25'])),
#  ('Дальность полета, м', (True, ['8000'])),
#  ('Расход топлива, гр/ч', (True, ['150'])),
#  ('Диаметр конфорки, мм', (True, ['63'])),
#  ('Количество конфорок горелки, шт', (True, ['1'])),
#  ('Ширина ламели, см', (True, ['2.5'])),
#  ('Число степеней очистки', (True, ['5'])),
#  ('MTBF, кликов', (True, ['10000000'])),
#  ('Количество точек запирания', (True, ['1'])),
#  ('Загрузка белья для сушки, кг', (True, ['9'])),
#  ('Количество программ сушки', (True, ['14'])),
#  ('Количество карт', (True, ['78'])),
#  ('Длина ворса, мм', (True, ['12'])),
#  ('Ход вилки, мм', (True, ['100'])),
#  ('Толщина круга, мм', (True, ['16'])),
#  ('Скорость', (True, ['90'])),
#  ('Контроль', (True, ['60'])),
#  ('Срок потребления', (True, ['360'])),
#  ('Количество панелей', (True, ['18'])),
#  ('Ширина рабочей части, см', (True, ['10'])),
#  ('Тест, кг', (True, ['2500'])),
#  ('Количество краников', (True, ['2'])),
#  ('Емкость резервуара холодной воды, л', (True, ['1'])),
#  ('Емкость резервуара горячей воды, л', (True, ['1'])),
#  ('Диаметр шарика, мм', (True, ['5'])),
#  ('Число зубьев', (True, ['9'])),
#  ('Длина шатуна, мм', (True, ['170'])),
#  ('Уровень шума при отжиме, дБ', (True, ['64'])),
#  ('Мощность передатчика, dBm', (True, ['33'])),
#  ('Количество одновременно работающих диапазонов', (True, ['1'])),
#  ('Количество вводов', (True, ['4'])),
#  ('Вес шасси, кг', (True, ['5'])),
#  ('Диаметр передних колес, см', (True, ['10'])),
#  ('Диаметр задних колес, см', (True, ['12'])),
#  ('Вес коляски, кг', (True, ['14.9'])),
#  ('Ширина прогулочного блока/люльки, см', (True, ['31.5'])),
#  ('Длина прогулочного блока, см', (True, ['79'])),
#  ('Длина люльки, см', (True, ['79'])),
#  ('Ширина прогулочного блока, см', (True, ['39'])),
#  ('Ширина люльки, см', (True, ['39'])),
#  ('Макс. ширина шасси, см', (True, ['60'])),
#  ('Вес люльки, кг', (True, ['5'])),
#  ('Вес прогулочного блока, кг', (True, ['5.4'])),
#  ('Толщина, мкр', (True, ['120'])),
#  ('Производительность л/час', (True, ['2006'])),
#  ('Число подключаемых камер', (True, ['2'])),
#  ('Число подключаемых вызывных панелей', (True, ['1'])),
#  ('Число подключаемых мониторов', (True, ['4'])),
#  ('Угол обзора по вертикали, °', (True, ['120'])),
#  ('Сохраняет тепло до, ч', (True, ['24'])),
#  ('Сохраняет холод до, ч', (True, ['6'])),
#  ('Диаметр колонны, мм', (True, ['76'])),
#  ('Ширина пластин, мм', (True, ['15'])),
#  ('Число перевозимых лыж', (True, ['4'])),
#  ('Число перевозимых сноубордов', (True, ['2'])),
#  ('Число перевозимых велосипедов', (True, ['2'])),
#  ('Класс линолеума', (True, ['23'])),
#  ('Количество конфорок с двойным рядом пламени', (True, ['1'])),
#  ('Макс. частота оперативной памяти, МГц', (True, ['4800'])),
#  ('Базовая частота, ГГц', (True, ['3.3'])),
#  ('Турбо-частота, ГГц', (True, ['3.7'])),
#  ('Количество потоков', (True, ['4'])),
#  ('Жирность, %', (True, ['33'])),
#  ('Условный проход, мм', (True, ['12'])),
#  ('Количество ламелей, шт', (True, ['2'])),
#  ('Количество отсеков 2.5"', (True, ['4'])),
#  ('Макс. длина видеокарты, мм', (True, ['280'])),
#  ('Макс. высота процессорного кулера, мм', (True, ['200'])),
#  ('Время схватывания, мин', (True, ['15'])),
#  ('Время полного высыхания, ч', (True, ['24'])),
#  ('Cодержание уксусной кислоты, %', (True, ['5'])),
#  ('Длина зонда, м', (True, ['5'])),
#  ('Количество ручек', (True, ['5'])),
#  ('Пиковая яркость, лм', (True, ['2500'])),
#  ('Длина рукоятки, см', (True, ['144'])),
#  ('Внутренний диаметр шланга, мм', (True, ['63'])),
#  ('Год экзамена ЕГЭ, ОГЭ', (True, ['2024'])),
#  ('Количество вариантов для ЕГЭ, ОГЭ, ВПР', (True, ['15'])),
#  ('Толщина губки', (True, ['2.1'])),
#  ('Количество USB портов', (True, ['2'])),
#  ('Количество элементов питания, шт.', (True, ['2'])),
#  ('Количество наволочек в комплекте', (True, ['1'])),
#  ('Active to Precharge Delay (tRAS), тактов', (True, ['32'])),
#  ('Емкость аккумулятора,  мАч', (True, ['2250'])),
#  ('Диаметр трубки, мм', (True, ['10'])),
#  ('Количество мест', (True, ['1'])),
#  ('Дальность выброса снега, м', (True, ['11'])),
#  ('Содержание кофеина мг/100 мл', (True, ['30'])),
#  ('Ростовка беговых лыж, см', (True, ['190'])),
#  ('Кол-во слотов для карт памяти', (True, ['2'])),
#  ('Эффективное количество пикселей, Мпикс', (True, ['45.7'])),
#  ('Макс. диагональ проекции, дюймов', (True, ['12'])),
#  ('Мин. диагональ проекции, дюймов', (True, ['0.89'])),
#  ('Минимальное проекционное расстояние, м', (True, ['0.5'])),
#  ('Максимальное проекционное расстояние, м', (True, ['4'])),
#  ('Мощность лампы, Вт', (True, ['24'])),
#  ('Макс. время работы лампы, ч', (True, ['30000'])),
#  ('Световой поток ANSI, лм', (True, ['2300'])),
#  ('Отношение сигнал/шум, дБ', (True, ['114'])),
#  ('Ход шлифплатформы, мм', (True, ['1'])),
#  ('В коробке, шт', (True, ['5'])),
#  ('Кол-во кв.метров в коробке', (True, ['1.8'])),
#  ('Производительность, кг/сутки', (True, ['15'])),
#  ('Диаметр трубы прицела, мм', (True, ['25.4'])),
#  ('Цена поправки (1 щелчка) на 100 метрах, МОА,MIL,MRAD', (True, ['0.25'])),
#  ('Теплоотдача, Вт/ч', (True, ['439'])),
#  ('Кол-во контактов шлейфа/разъема', (True, ['45'])),
#  ('Высота полотна, мм', (True, ['2200'])),
#  ('Ширина полотна, мм', (True, ['900'])),
#  ('Общая толщина двери, мм', (True, ['59'])),
#  ('Макс. температура нагрева, °C', (True, ['500'])),
#  ('Встроенная память,  МБ', (True, ['32768'])),
#  ('Максимальная производительность, л/ч', (True, ['3'])),
#  ('Дальность связи, м', (True, ['1000'])),
#  ('Расстояние срабатывания метки, м', (True, ['1000'])),
#  ('Количество ячеек, шт', (True, ['1'])),
#  ('Максимальная ширина ламинирования, мм', (True, ['260'])),
#  ('Скорость видеосъемки FullHD, кадр/с', (True, ['30'])),
#  ('Число регулировок наклона спинки', (True, ['5'])),
#  ('Число регулировок по высоте', (True, ['9'])),
#  ('Число регулировок подножки по высоте', (True, ['3'])),
#  ('Высота от пола до столешницы в верхнем положении, см', (True, ['84'])),
#  ('Внутренняя ширина сиденья, см', (True, ['27'])),
#  ('Макс. давление воды в контуре отопления, бар', (True, ['3'])),
#  ('Отапливаемая площадь, кв. м', (True, ['75'])),
#  ('Количество комнат палатки', (True, ['1'])),
#  ('Уровень шума при стирке, дБ', (True, ['53'])),
#  ('Длина, пог. м', (True, ['3'])),
#  ('Размер режущего полотна, см', (True, ['42'])),
#  ('Мин. рост ребенка, см', (True, ['110'])),
#  ('Макс. рост ребенка, см', (True, ['140'])),
#  ('Диаметр лески, мм', (True, ['1.4'])),
#  ('Диаметр насадки, мм', (True, ['6'])),
#  ('Кратность окуляра', (True, ['10'])),
#  ('Макс. расстояние между отверстиями по высоте, мм', (True, ['100'])),
#  ('Макс. расстояние между отверстиями по ширине, мм', (True, ['200'])),
#  ('Мин. расстояние между отверстиями по ширине, мм', (True, ['75'])),
#  ('Регулируемая длина/высота, мм', (True, ['510'])),
#  ('Мин. расстояние между отверстиями по высоте, мм', (True, ['75'])),
#  ('Цифровой зум, кратность', (True, ['4'])),
#  ('Время работы батареи, ч', (True, ['10'])),
#  ('Длина лодки, см', (True, ['295'])),
#  ('Количество сидений', (True, ['2'])),
#  ('Количество воздушных отсеков', (True, ['3'])),
#  ('Ширина лодки, см', (True, ['137'])),
#  ('Диаметр борта, см', (True, ['43'])),
#  ('Длина кокпита (внутренняя), см', (True, ['215'])),
#  ('Ширина кокпита (внутренняя), см', (True, ['55'])),
#  ('Количество предметов в пенале', (True, ['1'])),
#  ('Длинная сторона, см', (True, ['600'])),
#  ('Короткая сторона, см', (True, ['500'])),
#  ('Пропускная способность, л/с', (True, ['0.80002'])),
#  ('Количество предметов в наборе', (True, ['1'])),
#  ('Макс. крутящий момент, Нм', (True, ['180'])),
#  ('Глубина погружения, м', (True, ['7'])),
#  ('Скорость открывания, м/мин', (True, ['9.6'])),
#  ('Макс. диаметр хомута, мм', (True, ['152'])),
#  ('Количество мест в палатке', (True, ['3'])),
#  ('Разрежение, мбар', (True, ['180'])),
#  ('Полная мощность, кВА', (True, ['8.1'])),
#  ('Макс. потребляемый ток, А', (True, ['35.2'])),
#  ('Напряжение холостого хода, В', (True, ['72'])),
#  ('Напряжение дуги, В', (True, ['27.6'])),
#  ('Количество зубцов, шт.', (True, ['9'])),
#  ('Количество поверхностей', (True, ['1'])),
#  ('Номер', (True, ['120'])),
#  ('Скорость печати, мм/сек', (True, ['60'])),
#  ('Производительность, куб. м/ч', (True, ['11.7'])),
#  ('Количество лепестков диафрагмы', (True, ['9'])),
#  ('Мин. фокусное расстояние, мм', (True, ['50'])),
#  ('Макс. фокусное расстояние, мм', (True, ['50'])),
#  ('Число оптических элементов', (True, ['11'])),
#  ('Число групп оптических элементов', (True, ['8'])),
#  ('Количество бутылок, шт', (True, ['126'])),
#  ('Толщина ленты, мкм', (True, ['160'])),
#  ('Длина пояса, см', (True, ['130'])),
#  ('Ширина лопаты, см', (True, ['22'])),
#  ('Пусковой ток, А', (True, ['850'])),
#  ('Макс. нагрузка на один снаряд, кг', (True, ['150'])),
#  ('Объем ресивера, л', (True, ['24'])),
#  ('Ширина/диаметр формы, см', (True, ['10'])),
#  ('Емкость, Вт•ч', (True, ['44'])),
#  ('Макс. диаметр проволоки, мм', (True, ['4'])),
#  ('Вес одной шт., кг', (True, ['1'])),
#  ('Версия PCI Express', (True, ['3.0'])),
#  ('Количество разъемов питания для вентилятора', (True, ['3'])),
#  ('Высота тюля, см', (True, ['270'])),
#  ('Ширина тюля, см', (True, ['450'])),
#  ('Ростовка горных лыж, см', (True, ['152'])),
#  ('Пятка, мм', (True, ['112.0'])),
#  ('Носок, мм', (True, ['301.0'])),
#  ('Талия, мм', (True, ['252.0'])),
#  ('Количество ярусов', (True, ['1'])),
#  ('Максимальная ширина шва, мм', (True, ['6'])),
#  ('Минимальная ширина шва, мм', (True, ['1'])),
#  ('Максимальное давление, атм (кг/см2)', (True, ['8'])),
#  ('Длина путей, см', (True, ['45'])),
#  ('Макс. взлетный вес, г', (True, ['300'])),
#  ('Угол поворота/наклона, град.', (True, ['180'])),
#  ('Высота стойки, см', (True, ['152'])),
#  ('Ширина основания, см', (True, ['171'])),
#  ('Угол открывания, °', (True, ['180'])),
#  ('Макс. воздушный поток, л/мин', (True, ['550'])),
#  ('Вес ракетки без струны, г', (True, ['215'])),
#  ('Размер ручки', (True, ['06'])),
#  ('Длина ракетки, см', (True, ['58'])),
#  ('Номер иглы', (True, ['80'])),
#  ('Кол-во разъемов Molex', (True, ['3'])),
#  ('Кол-во разъемов SATA', (True, ['6'])),
#  ('Количество PCI-E x4', (True, ['3'])),
#  ('Количество поддонов, шт.', (True, ['5'])),
#  ('Объем резервуара, мл', (True, ['1200'])),
#  ('Размер труб каркаса, мм', (True, ['38'])),
#  ('Глубина основания, см', (True, ['122'])),
#  ('Размер головки ракетки, кв. дюймов', (True, ['101'])),
#  ('Баланс ракетки, см', (True, ['32'])),
#  ('Макс. скорость печати (ч/б), стр/мин', (True, ['20'])),
#  ('Макс. скорость печати (цв.), стр/мин', (True, ['20'])),
#  ('Макс. скорость печати фото, секунд', (True, ['69'])),
#  ('Выход первой страницы, с', (True, ['8.50'])),
#  ('Мин. температура эксплуатации, С°', (True, ['-55'])),
#  ('Диаметр до усадки, мм', (True, ['9'])),
#  ('Сечение поводка, мм', (True, ['0.3'])),
#  ('Кол-во спицевых отверстий', (True, ['32'])),
#  ('Количество копий, шт.', (True, ['99'])),
#  ('Минимальный вес ребёнка, кг', (True, ['8'])),
#  ('Максимальный вес ребёнка, кг', (True, ['20'])),
#  ('Объем бачка, л', (True, ['0.8'])),
#  ('Максимальная вязкость материала, DIN', (True, ['30'])),
#  ('Высота подхвата, см', (True, ['23'])),
#  ('Высота подъема, см', (True, ['34.700000000000003'])),
#  ('Количество конфорок с тройным рядом пламени', (True, ['1'])),
#  ('Толщина игрового поля, мм', (True, ['4'])),
#  ('Высота теннисного стола, мм', (True, ['760'])),
#  ('Объем одной бутылки, мл', (True, ['1000'])),
#  ('Число ступеней, шт', (True, ['4'])),
#  ('Макс. рабочая высота, м', (True, ['2.65'])),
#  ('Макс. рабочая нагрузка, кг', (True, ['2162'])),
#  ('Погрешность стабилизации, %', (True, ['8'])),
#  ('Диаметр посадочного места для дисков и замков, мм', (True, ['26'])),
#  ('Длина грифа, см', (True, ['110'])),
#  ('Время сохранения температуры, ч', (True, ['3'])),
#  ('Жесткость колес (А)', (True, ['82'])),
#  ('Вылет ригелей, мм', (True, ['21'])),
#  ('Высота рабочего стола, мм', (True, ['100'])),
#  ('Длина рабочего стола, мм', (True, ['100'])),
#  ('Ширина рабочего стола, мм', (True, ['80'])),
#  ('Длина антенны, см', (True, ['104'])),
#  ('Радиус действия, км', (True, ['20'])),
#  ('Длина кабеля 1, м', (True, ['100'])),
#  ('Количество карт в колоде', (True, ['54'])),
#  ('Длина рабочего полотна ножниц, дюймы', (True, ['8.0'])),
#  ('Время работы от аккумулятора, ч.', (True, ['2'])),
#  ('Рабочая площадь, кв. м', (True, ['1'])),
#  ('Мин. температура охлаждения воды, °С', (True, ['15'])),
#  ('Макс. температура нагрева воды, °С', (True, ['85'])),
#  ('Производительность нагрева, л/ч', (True, ['5'])),
#  ('Мощность охлаждения, Вт', (True, ['90'])),
#  ('Производительность охлаждения, л/ч', (True, ['1'])),
#  ('Число лезвий в станке', (True, ['5'])),
#  ('Диаметр глобуса, см', (True, ['10.6'])),
#  ('Максимальный вес груза, кг', (True, ['25'])),
#  ('Длина кисти, мм', (True, ['290'])),
#  ('Макс. глубина обнаружения стали, мм', (True, ['12'])),
#  ('Макс. глубина обнаружения меди, мм', (True, ['19'])),
#  ('Макс. глубина обнаружения эл.проводки, мм', (True, ['12'])),
#  ('Расход воздуха, м3/час', (True, ['750'])),
#  ('Ширина кисти, мм', (True, ['230'])),
#  ('Ширина отделения для тоста, см', (True, ['2.5'])),
#  ('Длина отделения для тоста, см', (True, ['13.5'])),
#  ('Число степеней обжаривания', (True, ['6'])),
#  ('Год в календарях', (True, ['2024'])),
#  ('Номинальная мощность, Вт', (True, ['220'])),
#  ('Емкость резервуара для зерен, г', (True, ['200'])),
#  ('Диаметр горшка, см', (True, ['12'])),
#  ('Время непрерывной работы, ч', (True, ['10'])),
#  ('Уровень шума, дБ', (True, ['57'])),
#  ('Выходной ток, А', (True, ['28'])),
#  ('Рабочий объем, см3', (True, ['420'])),
#  ('Время работы на полном баке, ч', (True, ['14'])),
#  ('Количество уровней высоты', (True, ['2'])),
#  ('Толщина стенки, мм', (True, ['2.5'])),
#  ('Общее количество салфеток, шт', (True, ['50'])),
#  ('Расход топлива, л/ч', (True, ['0.4'])),
#  ('Диаметр вентилятора, мм', (True, ['92'])),
#  ('Макс. воздушный поток, CFM', (True, ['59.46'])),
#  ('Диаметр отверстия под свечу, см', (True, ['7'])),
#  ('Количество свечей', (True, ['1'])),
#  ('Температура замерзания, °С', (True, ['-40'])),
#  ('Намотка за оборот ручки, см', (True, ['85'])),
#  ('Время работы, ч', (True, ['50'])),
#  ('Количество PCI-E x8', (True, ['3'])),
#  ('Кол-во гантелей, шт', (True, ['4'])),
#  ('Диаметр перекладины, мм', (True, ['34'])),
#  ('Длина перекладины, см', (True, ['119'])),
#  ('Количество точек крепления турника', (True, ['4'])),
#  ('Мин. давление струи, кПа', (True, ['200'])),
#  ('Макс. давление струи, кПа', (True, ['760'])),
#  ('Емкость контейнера для воды, мл', (True, ['650'])),
#  ('Количество уровней', (True, ['2'])),
#  ('Максимальный вес животного, кг', (True, ['10'])),
#  ('Вес товара без упаковки, кг', (True, ['8.65'])),
#  ('Диаметр рабочей части вибронаконечника, мм', (True, ['35'])),
#  ('Длина рабочего основания, мм', (True, ['480'])),
#  ('Длина вала, м', (True, ['2'])),
#  ('Площадь полива, м²', (True, ['80'])),
#  ('Кол-во подключаемых трубок', (True, ['1'])),
#  ('Число трубок в комплекте', (True, ['2'])),
#  ('Наружный диаметр шланга, мм', (True, ['63'])),
#  ('Число молний', (True, ['0'])),
#  ('Производительность, л/час', (True, ['120'])),
#  ('Размер лезвий', (True, ['263'])),
#  ('Ширина задней оси, см', (True, ['60'])),
#  ('Ширина передней оси, см', (True, ['40'])),
#  ('Количество цветов, шт.', (True, ['49'])),
#  ('Ширина рабочей части, мм', (True, ['75'])),
#  ('Диаметр насоса, мм', (True, ['100'])),
#  ('Количество лезвий', (True, ['8'])),
#  ('Мощность лодочного мотора, л.с.', (True, ['1.5'])),
#  ('Класс износостойкости', (True, ['33'])),
#  ('Время нагрева, мин', (True, ['5'])),
#  ('Количество топперов в уп.', (True, ['1'])),
#  ('Длина сушильной поверхности , м', (True, ['6'])),
#  ('Количество насадок на швабру', (True, ['1'])),
#  ('Время работы, ч.', (True, ['2'])),
#  ('Минимальный ток заряда, А', (True, ['2'])),
#  ('Количество разъемов USB 3.1', (True, ['1'])),
#  ('Кол-во встроенных игр', (True, ['15000'])),
#  ('Дальность измерения, м', (True, ['40'])),
#  ('Количество лучей', (True, ['3'])),
#  ('Площадь покрытия, м2', (True, ['4.5'])),
#  ('Количество удочек/спиннингов, шт', (True, ['1'])),
#  ('Диаметр грифа, мм', (True, ['30'])),
#  ('Макс. вес готового изделия, г', (True, ['1500'])),
#  ('Число предметов в наборе, шт', (True, ['1'])),
#  ('Количество слотов расширения', (True, ['4'])),
#  ('Макс. длина реза, мм', (True, ['400'])),
#  ('Макс. толщина плитки, мм', (True, ['12'])),
#  ('Длина нити шовного материала, см', (True, ['1000'])),
#  ('Длина рулона, м', (True, ['1350'])),
#  ('Диаметр пластика, мм', (True, ['1.75'])),
#  ('Ширина загрузочного отверстия, мм', (True, ['220'])),
#  ('Уровень секретности', (True, ['3'])),
#  ('Объем корзины, л', (True, ['12'])),
#  ('Количество листов за один раз, шт', (True, ['8'])),
#  ('Мин. угол выноса, градусов', (True, ['0'])),
#  ('Макс. угол выноса, градусов', (True, ['0'])),
#  ('Макс. высота, м', (True, ['2.65'])),
#  ('Длина рукояти, см', (True, ['42'])),
#  ('Длина режущей части, мм', (True, ['250'])),
#  ('Индекс жесткость клюшки', (True, ['40'])),
#  ('Резервуар для сока, л', (True, ['1'])),
#  ('Резервуар для мякоти, л', (True, ['1.3'])),
#  ('Макс. энергия удара, Дж', (True, ['4.8'])),
#  ('Диаметр отвода, мм', (True, ['20'])),
#  ('Мин. диагональ, дюймы', (True, ['6'])),
#  ('Длина стола с подголовником, см', (True, ['190'])),
#  ('Ширина стола, см', (True, ['71'])),
#  ('Количество секций массажного стола', (True, ['2'])),
#  ('Максимальный вес двери, кг', (True, ['75'])),
#  ('Длина прогулочного блока/люльки, см', (True, ['83'])),
#  ('Количество инструментов, шт', (True, ['14'])),
#  ('Скорость потока воды, куб.м/ч', (True, ['20'])),
#  ('Макс. диаметр зажима, мм', (True, ['10'])),
#  ('Мин. диаметр зажима, мм', (True, ['1'])),
#  ('Ширина колодки, мм', (True, ['80'])),
#  ('Количество клипс', (True, ['4'])),
#  ('Высыхание слоя 2 мм, ч', (True, ['8'])),
#  ('Число мелодий', (True, ['3'])),
#  ('Пропускная способность, м³/ч', (True, ['1.25'])),
#  ('Количество матриц', (True, ['1'])),
#  ('Скорость воздушного потока, м/с', (True, ['90'])),
#  ('Максимальная скорость мяча, км/ч', (True, ['144'])),
#  ('Максимальная скорострельность, мяч/мин', (True, ['70'])),
#  ('Минимальная скорострельность, мяч/мин', (True, ['40'])),
#  ('Количество метательных головок', (True, ['2'])),
#  ('Количество двигателей метальной головки', (True, ['1'])),
#  ('Емкость (число мячей)', (True, ['110'])),
#  ('Время полной зарядки, часов', (True, ['5'])),
#  ('Преодолеваемый подъем, °', (True, ['30'])),
#  ('Максимальная чувствительность ISO', (True, ['6400'])),
#  ('Минимальная чувствительность ISO', (True, ['125'])),
#  ('Максимальная выдержка, сек', (True, ['4'])),
#  ('Минимальная выдержка, сек', (True, ['0.00025'])),
#  ('Мин. ширина ворот, см', (True, ['180'])),
#  ('Высота заграждения, см', (True, ['84'])),
#  ('Макс. ширина ворот, см', (True, ['180'])),
#  ('Расход природного газа, м³/ч', (True, ['2'])),
#  ('Диаметр дымохода, мм', (True, ['110'])),
#  ('Мин. длина раздвижного карниза, см', (True, ['100'])),
#  ('Макс. длина раздвижного карниза, см', (True, ['200'])),
#  ('Количество горшков', (True, ['1'])),
#  ('Максимальная загрузка, кг', (True, ['8'])),
#  ('Ширина поддона, см', (True, ['32'])),
#  ('Длина поддона, см', (True, ['32'])),
#  ('Высота поддона, см', (True, ['3'])),
#  ('Глубина обработки, см', (True, ['33'])),
#  ('Макс. количество порций', (True, ['2'])),
#  ('Срок службы, мес', (True, ['3'])),
#  ('Толщина внешнего листа стали, мм', (True, ['1.2'])),
#  ('Вертикальные ребра жесткости, шт', (True, ['3'])),
#  ('Горизонтальные ребра жесткости, шт', (True, ['9'])),
#  ('Количество растений, шт', (True, ['80'])),
#  ('Разрывная нагрузка, кгс', (True, ['1100'])),
#  ('Масса, кг', (True, ['0.5'])),
#  ('Длина иглы, мм', (True, ['38'])),
#  ('Диаметр иглы, мм', (True, ['0.7'])),
#  ('Мин. длина выноса, мм', (True, ['32'])),
#  ('Макс. длина выноса, мм', (True, ['32'])),
#  ('Макс. рассеиваемая мощность, Вт', (True, ['220'])),
#  ('Высота держателя, см', (True, ['43'])),
#  ('Минимальная высота холста, см', (True, ['40'])),
#  ('Макс. ток потребления, А', (True, ['5.5'])),
#  ('Количество каналов', (True, ['199'])),
#  ('Дальность действия, м', (True, ['10'])),
#  ('Вес, кг/м', (True, ['1'])),
#  ('Минимальный пусковой ток, А', (True, ['1500'])),
#  ('Погрешность, °С', (True, ['1'])),
#  ('Макс. диаметр завинчиваемых шурупов, мм', (True, ['10'])),
#  ('Макс. время работы,  ч', (True, ['72'])),
#  ...]

# %%
import re
from natasha import (
    Doc,
    Segmenter,
    MorphVocab,
    NewsEmbedding,
    NewsMorphTagger
)

# Инициализация компонентов Natasha
segmenter = Segmenter()
morph_vocab = MorphVocab()
news_embeddings = NewsEmbedding()
morph_tagger = NewsMorphTagger(news_embeddings)

def preprocess_text(text):
    # Удаляем цифры и пунктуацию, приводим к нижнему регистру
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = text.strip().lower()

    # Создаем документ для обработки Natasha
    doc = Doc(text)
    doc.segment(segmenter)  # Разбиваем на токены
    doc.tag_morph(morph_tagger)  # Морфологический анализ

    # Лемматизация с помощью MorphVocab
    normalized_words = []
    for token in doc.tokens:
        token.lemmatize(morph_vocab)  # Лемматизация
        normalized_words.append(token.lemma)  # Добавляем лемму в список

    # Объединяем леммы обратно в строку
    processed_text = ' '.join(normalized_words)

    return processed_text

# %%
from sentence_transformers import SentenceTransformer, util
import torch
model = SentenceTransformer('sergeyzh/rubert-tiny-turbo')

sentences = list(map(lambda x: x[0], num_attr)) #num_attr #['товар цвет', ]
preproc_sentences = list(map(lambda x: preprocess_text(x), sentences))
embeddings = model.encode(preproc_sentences)
print(preproc_sentences)
# Out:
# ['максимальный продолжительность партия мина', 'плотность наполнитель гм', 'количество предмет в комплект', 'расход кгм', 'рекомендовать количество слой', 'срок годность в день', 'длина шампур см', 'количество шампуров шт', 'толщина мм', 'количество цвет шт', 'внутренний диаметр брашинг мм', 'оптический сила', 'радиус кривизна', 'влагосодержание', 'количество внешний карман шт', 'плотность ткань гквма', 'количество насадка', 'объем чаша л', 'макс мощность при блокировка мотор вт', 'производительность кгмин', 'количество предмет', 'макс мощность свч вт', 'время мойка при обычный программа мина', 'вместимость комплект', 'количество программа', 'расход вода за цикл л', 'количество пружина на спальный место', 'макс вес на спальный место кг', 'содержание какао', 'макс световой поток люмен', 'колвый светодиод', 'макс время работа от батарея ч', 'дальность освещение м', 'колвый режим', 'число отделение шт', 'вес перчатка oz унция', 'диаметр динамика мм', 'вес с упаковка г', 'шаг зуб tpi', 'длина лезвие мм', 'количество в комплект шт', 'усилие н', 'угол подъем', 'число основный чаша', 'диаметр слив мм', 'объем бассейн л', 'время установка мина', 'колвый внутренний отделение', 'индекс жесткость', 'количество фломастеров шт', 'макс давление бар', 'колвый приготовлять чашка кофе шт', 'диагональ экран см', 'количество разъем usb', 'мощность аудиосистема вт', 'число порт hdmi', 'ось axis', 'количество рулон клейкий лента шт', 'угол рассеивание', 'высота ворс мм', 'количество цвет', 'вес маховик кг', 'обхват шея максимальный c м', 'максимальный вес пользователь кг', 'максимальный скорость кмч', 'длина беговой полотно см', 'ширина беговой полотно см', 'макс оборот холостой ход обмин', 'глубина пропил под мм', 'глубина пропил под мм', 'диаметр диск см', 'ширина линза мм', 'размер заушник мм', 'размер мост на переносица мм', 'длина товар в упаковка мм', 'количество рулон', 'высота сидение см', 'диаметр заряд мм', 'высота подъем м', 'количество эффект', 'число заряд', 'время работа с', 'время работа мина', 'количество батарейка пульт', 'число канал связь', 'коэффициент усиление антенна dbi', 'паровой удар гмин', 'ширина корешок мм', 'количество штука', 'высота ножка мм', 'ширина спальный место см', 'длина спальный место см', 'макс высота матрас см', 'высота изголовье см', 'высота изножие см', 'вес один шт г', 'ширинадиаметр см', 'длина ремешок мм', 'количество крючок шт', 'число полотно', 'глубина мм', 'колвый пост', 'ширина товар в упаковка мм', 'высота товар в упаковка мм', 'сложность головоломка', 'количество упаковка шт', 'длина кабель питание м', 'макс нагрузка вт', 'количество спица', 'длина в сложить вид смотреть', 'диаметр купол см', 'колво в комплект шт', 'количество нить', 'размотка м', 'разрывный нагрузка кг', 'ширина пильный полотно мм', 'уровень сложность набор', 'количество колесо', 'диаметр передний колесо мм', 'ширина дек см', 'диаметр задний колесо мм', 'макс площадь помещение квм', 'макс давление бар', 'толщина дно мм', 'высота стенка см', 'ширина оттиск мм', 'длина оттиск мм', 'число строка', 'тип молния', 'макс глубина сверление мм', 'диаметр сверло мм', 'количество мелодия', 'громкость звонок дб', 'число батарея звонок шт', 'ширина плита см', 'количество конфорка', 'количество стекло дверца духовка', 'количество выходной разъем', 'максимальный толщина дверь мм', 'минимальный толщина дверь мм', 'длина модель см', 'частота процессор ггц', 'число ядро процессор', 'количество hdd', 'мощность блок питание вт', 'общий объем hdd гб', 'суммарный объем весь диск гб', 'количество игрушка в один упаковка', 'количество зубьев шт', 'минимальный длина стрижка мм', 'максимальный длина стрижка мм', 'ширина нож мм', 'шаг винт', 'количество лопасть гребной винт', 'количество режим работа', 'количество тост', 'общий ширина мм', 'число слой наполнитель', 'ширина в плечо см', 'ширина в нога см', 'длина в свернутый состояние смотреть', 'ширина в свернутый состояние смотреть', 'толщина в свернутый состояние смотреть', 'точность измерение г', 'вне ...

# %%
embeddings[0].shape
# Out:
# (312,)

# %%
def embeddings_to_torch(embeddings):
    return [torch.from_numpy(emb).unsqueeze(0) for emb in embeddings]

# %%
def clastarize(sentences, torch_embeddings, threshold=0.9):
    distribution = dict()
    clast_lst = []
    already_in = []
    clast_index = -1
    for i in range(len(sentences)):
        if i in already_in:
            continue
        already_in.append(i)
        clast_index += 1
        clast = []
        distribution[sentences[i]] = clast_index
        clast.append((sentences[i], 1.0))
        emb_i = torch_embeddings[i]
        for j in range(i + 1, len(sentences)):
            if j in already_in:
                continue
            emb_j = torch_embeddings[j]
            cos_sim = torch.cosine_similarity(emb_i, emb_j)
            if cos_sim > threshold:
                clast.append((sentences[j], cos_sim))
                distribution[sentences[j]] = clast_index
                already_in.append(j)
        clast_lst.append(clast)
    return clast_lst, distribution

# %%
torch_embeddings = embeddings_to_torch(embeddings)
num_clast_lst, num_clast_distribution = clastarize(sentences, torch_embeddings)
print(len(num_clast_lst))
# Out:
# 696

# %%
for clast in num_clast_lst:
    print(f"clast main: {clast[0][0]}")
    print(f"clasts: {clast[1:]}")
    print("\n")
# Out:
# clast main: Максимальная продолжительность партии, мин.
# clasts: [('Длительность, мин', tensor([0.9105]))]
#
#
# clast main: Плотность наполнителя, г/м2
# clasts: [('Плотность, кг/м3', tensor([0.9092])), ('Плотность, г/см3', tensor([0.9178]))]
#
#
# clast main: Количество предметов в комплекте
# clasts: [('Количество предметов', tensor([0.9375])), ('Количество в комплекте, шт.', tensor([0.9615])), ('Кол-во в комплекте, шт', tensor([0.9152])), ('Количество инструментов в наборе, шт.', tensor([0.9225])), ('Количество модулей в комплекте', tensor([0.9189])), ('Число предметов, шт', tensor([0.9268])), ('Количество колонок в комплекте', tensor([0.9378])), ('Количество наволочек в комплекте', tensor([0.9521])), ('Количество предметов в наборе', tensor([0.9632])), ('Число предметов в наборе, шт', tensor([0.9515])), ('Число пейджеров в комплекте, шт.', tensor([0.9091])), ('Количество фишек в наборе', tensor([0.9011])), ('Общее количество пакетов, шт', tensor([0.9136]))]
#
#
# clast main: Расход, кг/м2
# clasts: [('Масса, кг', tensor([0.9085])), ('Вес, кг/м', tensor([0.9153]))]
#
#
# clast main: Рекомендуемое количество слоев
# clasts: [('Число слоев наполнителя', tensor([0.9121])), ('Количество слоев деки', tensor([0.9426]))]
#
#
# clast main: Срок годности в днях
# clasts: []
#
#
# clast main: Длина шампура, см
# clasts: [('Количество шампуров, шт', tensor([0.9120]))]
#
#
# clast main: Толщина, мм
# clasts: [('Ширина корешка, мм', tensor([0.9126])), ('Ширина/диаметр, см', tensor([0.9035])), ('Глубина, мм', tensor([0.9028])), ('Толщина дна, мм', tensor([0.9410])), ('Ширина оттиска, мм', tensor([0.9165])), ('Внешний диаметр, мм', tensor([0.9062])), ('Толщина столешницы, мм', tensor([0.9435])), ('Толщина лезвия, мм', tensor([0.9296])), ('Толщина, см', tensor([0.9846])), ('Толщина стекла, мм', tensor([0.9337])), ('Толщина дверцы, мм', tensor([0.9848])), ('Толщина обуха, мм', tensor([0.9646])), ('Ширина режущей части, мм', tensor([0.9012])), ('Толщина профиля, мм', tensor([0.9503])), ('Толщина коврика, мм', tensor([0.9371])), ('Толщина гидрокостюма, мм', tensor([0.9284])), ('Толщина круга, мм', tensor([0.9648])), ('Толщина, мкр', tensor([0.9663])), ('Толщина губки', tensor([0.9010])), ('Толщина ленты, мкм', tensor([0.9480])), ('Толщина игрового поля, мм', tensor([0.9096])), ('Толщина стенки, мм', tensor([0.9533])), ('Макс. толщина плитки, мм', tensor([0.9114])), ('Толщина внешнего листа стали, мм', tensor([0.9141])), ('Толщина защитного слоя, мм', tensor([0.9285])), ('Толщина нитей, мм', tensor([0.9183])), ('Толщина изоляции, мм', tensor([0.9221])), ('Толщина колес, мм', tensor([0.9061])), ('Ширина шва, мм', tensor([0.9046])), ('Толщина подкладки, мм', tensor([0.9488])), ('Ширина строгания, мм', tensor([0.9242])), ('Глубина строгания, мм', tensor([0.9008])), ('Диаметр 2, см', tensor([0.9072])), ('Толщина внутреннего листа стали, мм', tensor([0.9081])), ('Максимальная толщина материала, мм', tensor([0.9290])), ('Толщина матрицы, мкм', tensor([0.9243])), ('Диаметр 2, мм', tensor([0.9152])), ('Макс. толщина материала, мм', tensor([0.9510]))]
#
#
# clast main: Количество цветов, шт
# clasts: [('Количество цветов', tensor([0.9713])), ('Количество цветов, шт.', tensor([1.])), ('Количество оттенков в наборе', tensor([0.9070])), ('Количество лучей, шт', tensor([0.9014]))]
#
#
# clast main: Внутренний диаметр брашинга, мм
# clasts: [('Внутренний диаметр, мм', tensor([0.9530])), ('Внутренний диаметр шланга, мм', tensor([0.9235])), ('Ширина кокпита (внутренняя), см', tensor([0.9031]))]
#
#
# clast main: Оптическая сила
# clasts: [('Оптическая сила (диоптрии)', tensor([0.9326]))]
#
#
# clast main: Радиус кривизны
# clasts: [('Радиус действия, км', tensor([0.9065]))]
#
#
# clast main: Влагосодержание, %
# clasts: []
#
#
# clast main: Количество внешних карманов, шт
# clasts: [('Количество внутренних карманов, шт', tensor([0.9659]))]
#
#
# clast main: Плотность ткани, г/кв.м
# clasts: []
#
#
# clast main: Количество насадок
# clasts: [('Количество, штук', tensor([0.9136])), ('Количество створок', tensor([0.9048])), ('Общее количество, шт', tensor([0.9029])), ('Количество инструментов', tensor([0.9037])), ('Количество поддонов, шт.', tensor([0.9171])), ('Количество насадок на швабру', tensor([0.9308])), ('Количество инструментов, шт', tensor([0.9071])), ('Ширина насадки, см', tensor([0.9075])), ('Количество палок, шт', tensor([0.9143])), ('Количество установок длины', tensor([0.9060])), ('Количество на поддоне, шт', tensor([0.9218]))]
#
#
# clast main: Объем чаши, л
# clasts: [('Объем бутылки, л', tensor([0.9361])), ('Размер чаши, см', tensor([0.9452]))]
#
#
# clast main: Макс. мощность (при блокировке мотора), Вт
# clasts: []
#
#
# clast main: Производительность, кг/мин
# clasts: [('Производительность, л/ч', tensor([0.9278])), ('Производительность л/час', tensor([0.9340])), ('Производительность, кг/сутки', tensor([0.9715])), ('Производительность, куб. м/ч', tensor([0.9180])), ('Производительность, л/час', tensor([0.9340])), ('Производительность, г/мин', tensor([0.9503])), ('Производительность, м²/ч', tensor([0.9565])), ('Производительность, кг/ч', tensor([0.9828]))]
#
#
# clast main: Макс. мощность СВЧ, Вт
# clasts: [('Макс. тепловая мощность, кВт', tensor([0.9033])), ('Макс. выходная мощность, Вт', tensor([0.9043])), ('Номинальная мощность, Вт', tensor([0.9020])), ('Макс. рассеиваемая мощность, Вт', tensor([0.9365])), ('Мин. мощность, Вт', tensor([0.9045])), ('Общая мощность, Вт', tensor([0.9015])), ('Мощность, мТл', tensor([0.9107]))]
#
#
# clast main: Время мойки при обычной программе, мин
# clasts: []
#
#
# clast main: Вместимость, комплектов
# clasts: []
#
#
# clast main: Количество программ
# clasts: [('Количество программ/режимов', tensor([0.9599])), ('Количество программ сушки', tensor([0.9417]))]
#
#
# clast main: Расход воды за цикл, л
# clasts: []
#
#
# clast main: Количество пружин на спальное место
# clasts: []
#
#
# clast main: Макс. вес на спальное место, кг
# clasts: []
#
#
# clast main: Содержания какао, %
# clasts: []
#
#
# clast main: Макс. световой поток, Люмен
# clasts: [('Световой поток ANSI, лм', tensor([0.9247]))]
#
#
# clast main: Кол-во светодиодов
# clasts: [('Количество светодиодов на метр', tensor([0.9020]))]
#
#
# clast main: Макс. время работы от батарей, ч
# clasts: [('Время работы от аккумулятора, дни', tensor([0.9068])), ('Время работы батареи, ч', tensor([0.9657])), ('Время работы от аккумулятора, ч.', tensor([0.9375])), ('Макс. время работы,  ч', tensor([0.9203])), ('Время работы от батареи, ч', tensor([0.9707]))]
#
#
# clast main: Дальность освещения, м
# clasts: [('Дальность действия, м', tensor([0.9089])), ('Дальность луча, м', tensor([0.9399]))]
#
#
# clast main: Кол-во режимов
# clasts: [('Кол-во постов', tensor([0.9287])), ('Кол-во, шт', tensor([0.9003]))]
#
#
# clast main: Число отделений, шт
# clasts: [('Число секций', tensor([0.9328])), ('Количество секций, шт', tensor([0.9540])), ('Количество персон, шт', tensor([0.9058])), ('Количество отсеков 2.5"', tensor([0.9171])), ('Количество ячеек, шт', tensor([0.9024])), ('Количество ячеек, шт.', tensor([0.9024])), ('Количество секций весла', tensor([0.9077])), ('Число излучателей, шт.', tensor([0.9001]))]
#
#
# clast main: Вес перчатки, oz (унций)
# clasts: []
#
#
# clast main: Диаметр динамика, мм
# clasts: [('Диаметр отвода, мм', tensor([0.9001])), ('Диаметр древка, мм', tensor([0.9019])), ('Диаметр хвата, мм', tensor([0.9042]))]
#
#
# clast main: Вес с упаковкой, г
# clasts: [('Вес товара без упаковки, кг', tensor([0.9029])), ('Вес одной упаковки, г', tensor([0.9509]))]
#
#
# clast main: Шаг зубьев (TPI)
# clasts: [('Число зубьев', tensor([0.9034]))]
#
#
# clast main: Длина лезвия, мм
# clasts: [('Длина оттиска, мм', tensor([0.9035])), ('Макс. длина лезвия, см', tensor([0.9599])), ('Длина лезвия, см', tensor([0.9890])), ('Длина резьбы, мм', tensor([0.9221])), ('Размер лезвий', tensor([0.9401])), ('Количество лезвий', tensor([0.9149])), ('Длина режущей части, мм', tensor([0.9072])), ('Длина лопасти, см', tensor([0.9085])), ('Расстояние между лезвиями, мм', tensor([0.9201]))]
#
#
# clast main: Усилие, Н
# clasts: [('Усилие, т', tensor([0.9688]))]
#
#
# clast main: Угол подъема, °
# clasts: [('Высота подъема, м', tensor([0.9081])), ('Высота подъема, см', tensor([0.9059]))]
#
#
# clast main: Число основных чаш
# clasts: []
#
#
# clast main: Диаметр слива, мм
# clasts: [('Диаметр сверл, мм', tensor([0.9128])), ('Диаметр спиц, мм', tensor([0.9107])), ('Диаметр сопла, мм', tensor([0.9029])), ('Диаметр сварки, мм', tensor([0.9015]))]
#
#
# clast main: Объем бассейна, л
# clasts: []
#
#
# clast main: Время установки, мин
# clasts: [('Время работы, мин', tensor([0.9321])), ('Время приготовления, мин', tensor([0.9194])), ('Время схватывания, мин', tensor([0.9351])), ('Время нагрева, мин', tensor([0.9192])), ('Макс. установка таймера, мин', tensor([0.9235]))]
#
#
# clast main: Кол-во внутренних отделений
# clasts: []
#
#
# clast main: Индекс жесткости
# clasts: [('Индекс нагрузки', tensor([0.9240])), ('Индекс жесткость клюшки', tensor([0.9231]))]
#
#
# clast main: Количество фломастеров, шт
# clasts: [('Количество ламелей, шт', tensor([0.9023]))]
#
#
# clast main: Макс. давление, бар
# clasts: [('Макс. давление, Бар', tensor([1.0000])), ('Максимальное давление воды (бар)', tensor([0.9366])), ('Давление пара, Бар', tensor([0.9380])), ('Рабочее давление, бар', tensor([0.9446])), ('Давление на разрыв, бар', tensor([0.9475]))]
#
#
# clast main: Кол-во приготовляемых чашек кофе, шт
# clasts: [('Кол-во приготовляемых чашек кофе', tensor([0.9914]))]
#
#
# clast main: Диагональ экрана, см
# clasts: [('Макс. диагональ экрана ТВ, дюймы', tensor([0.9409]))]
#
#
# clast main: Количество разъемов USB
# clasts: [('Количество разъемов M.2', tensor([0.9436])), ('Количество разъемов USB 3.1', tensor([1.]))]
#
#
# clast main: Мощность аудиосистемы, Вт
# clasts: []
#
#
# clast main: Число портов HDMI
# clasts: [('Число портов DisplayPort', tensor([0.9074])), ('Число портов Thunderbolt', tensor([0.9143])), ('Количество портов FXS', tensor([0.9060]))]
#
#
# clast main: Ось (AXIS)
# clasts: []
#
#
# clast main: Количество рулонов клейкой ленты, шт
# clasts: [('Количество рулонов', tensor([0.9213])), ('Количество рулонов в упаковке, шт', tensor([0.9330]))]
#
#
# clast main: Угол рассеивания, °
# clasts: [('Угол отвода, °', tensor([0.9304])), ('Угол открывания, °', tensor([0.9250]))]
#
#
# clast main: Высота ворса, мм
# clasts: [('Высота ножек, мм', tensor([0.9139])), ('Высота изголовья, см', tensor([0.9195])), ('Высота изножья, см', tensor([0.9078])), ('Максимальная высота, см', tensor([0.9053])), ('Высота подставки, см', tensor([0.9203])), ('Макс. высота ТВ, см', tensor([0.9143])), ('Высота профиля, мм', tensor([0.9102])), ('Длина ворса, мм', tensor([0.9214])), ('Высота полотна, мм', tensor([0.9026])), ('Высота подхвата, см', tensor([0.9184])), ('Макс. высота, м', tensor([0.9088])), ('Высота заграждения, см', tensor([0.9038])), ('Высота поддона, см', tensor([0.9183])), ('Высота держателя, см', tensor([0.9197])), ('Высота изделия, мм', tensor([0.9222])), ('Мин. высота потолков, м', tensor([0.9022])), ('Высота среза, мм', tensor([0.9447])), ('Макс. высота, см', tensor([0.9217])), ('Регулировка высоты, см', tensor([0.9029])), ('Высота ножки, мм', tensor([0.9139]))]
#
#
# clast main: Вес маховика, кг
# clasts: []
#
#
# clast main: Обхват шеи максимальный, cм
# clasts: []
#
#
# clast main: Максимальный вес пользователя, кг
# clasts: [('Общая максимальная нагрузка, кг', tensor([0.9110])), ('Максимальный вес створки, кг', tensor([0.9224])), ('Максимальный вес ребёнка, кг', tensor([0.9033])), ('Максимальный вес груза, кг', tensor([0.9098])), ('Максимальная загрузка, кг', tensor([0.9260])), ('Макс нагрузка, кг', tensor([0.9020])), ('Максимальное усилие, кг', tensor([0.9188])), ('Максимальное количество пользователей', tensor([0.9073]))]
#
#
# clast main: Максимальная скорость, км/ч
# clasts: [('Макс. обороты на 2ой скорости, об./мин', tensor([0.9114])), ('Максимальная скорость отжима, об./мин.', tensor([0.9054])), ('Скорость', tensor([0.9218])), ('Максимальная скорость мяча, км/ч', tensor([0.9531])), ('Макс. обороты на 3ой скорости, об./мин', tensor([0.9114]))]
#
#
# clast main: Длина бегового полотна, см
# clasts: [('Ширина бегового полотна, см', tensor([0.9716]))]
#
#
# clast main: Макс. обороты холостого хода, об/мин
# clasts: [('Макс. обороты, об./мин', tensor([0.9397])), ('Макс. число оборотов, об/мин', tensor([0.9257]))]
#
#
# clast main: Глубина пропила под 90°, мм
# clasts: [('Глубина пропила под 45°, мм', tensor([1.0000])), ('Глубина зажима, мм', tensor([0.9057])), ('Глубина пропила в стали, мм', tensor([0.9285])), ('Глубина погружения, м', tensor([0.9056])), ('Глубина основания, см', tensor([0.9046])), ('Глубина загиба, мм', tensor([0.9381])), ('Глубина фальца, мм', tensor([0.9104]))]
#
#
# clast main: Диаметр диска, см
# clasts: [('Диаметр столбика, см', tensor([0.9061])), ('Диаметр пластинки, см', tensor([0.9328])), ('Диаметр поддона, см', tensor([0.9042]))]
#
#
# clast main: Ширина линзы, мм
# clasts: [('Ширина деки, см', tensor([0.9015])), ('Общая ширина, мм', tensor([0.9018])), ('Ширина зажима, мм', tensor([0.9057])), ('Ширина ленты, мм', tensor([0.9275])), ('Ширина люльки, см', tensor([0.9203])), ('Ширина пластин, мм', tensor([0.9053])), ('Ширина полотна, мм', tensor([0.9011])), ('Ширина основания, см', tensor([0.9027])), ('Ширина поддона, см', tensor([0.9005])), ('Ширина подголовника, см', tensor([0.9062])), ('Макс. ширина ленты, мм', tensor([0.9021]))]
#
#
# clast main: Размер заушника, мм
# clasts: [('Размер под ключ, мм', tensor([0.9015])), ('Размер головки, мм', tensor([0.9387])), ('Диаметр насадки, мм', tensor([0.9091]))]
#
#
# clast main: Размер моста на переносице, мм
# clasts: []
#
#
# clast main: Длина товара в упаковке, мм
# clasts: [('Ширина товара в упаковке, мм', tensor([0.9740])), ('Высота товара в упаковке, мм', tensor([0.9439])), ('Площадь в упаковке, м2', tensor([0.9093]))]
#
#
# clast main: Высота сиденья, см
# clasts: [('Мин. высота сиденья, см', tensor([0.9713])), ('Ширина сиденья, см', tensor([0.9270])), ('Макс. высота сиденья, см', tensor([0.9705])), ('Высота стойки, см', tensor([0.9109]))]
#
#
# clast main: Диаметр заряда, мм
# clasts: []
#
#
# clast main: Количество эффектов
# clasts: []
#
#
# clast main: Число зарядов
# clasts: [('Количество батарей, шт', tensor([0.9181])), ('Напряжение заряда, В', tensor([0.9090])), ('Масса заряда, кг', tensor([0.9100]))]
#
#
# clast main: Время работы, с
# clasts: [('Время работы в режиме разговора, ч', tensor([0.9056])), ('Время непрерывной работы, ч', tensor([0.9005])), ('Время работы, ч', tensor([0.9695])), ('Время работы, ч.', tensor([0.9695]))]
#
#
# clast main: Количество батареек пульта
# clasts: []
#
#
# clast main: Число каналов связи
# clasts: [('Количество контактов', tensor([0.9211])), ('Количество каналов, шт.', tensor([0.9292])), ('Количество каналов', tensor([0.9397])), ('Число каналов, шт', tensor([0.9396]))]
#
#
# clast main: Коэффициент усиления антенны, dBi
# clasts: []
#
#
# clast main: Паровой удар, г/мин
# clasts: []
#
#
# clast main: Ширина спального места, см
# clasts: [('Длина спального места, см', tensor([0.9701])), ('Ширина спального места в разложенном виде, см', tensor([0.9118]))]
#
#
# clast main: Макс. высота матраса, см
# clasts: []
#
#
# clast main: Вес одной шт., г
# clasts: [('Вес одной шт., кг', tensor([0.9841])), ('Вес одной палки, г', tensor([0.9362]))]
#
#
# clast main: Длина ремешка, мм
# clasts: [('Длина крепежа, мм', tensor([0.9189])), ('Ширина ошейника, мм', tensor([0.9021])), ('Длина рукоятки, см', tensor([0.9119])), ('Длина кисти, мм', tensor([0.9011])), ('Длина рукояти, см', tensor([0.9087])), ('Длина ремня, см', tensor([0.9147])), ('Длина ручки, мм', tensor([0.9203])), ('Длина шнека, см', tensor([0.9075])), ('Длина волокна, мм', tensor([0.9062])), ('Длина зажима, см', tensor([0.9059]))]
#
#
# clast main: Количество крючков, шт
# clasts: [('Количество ручек, шт', tensor([0.9210])), ('Количество маркеров, шт', tensor([0.9005]))]
#
#
# clast main: Число полотен
# clasts: [('Ширина полотна, см', tensor([0.9063]))]
#
#
# clast main: Сложность головоломки
# clasts: []
#
#
# clast main: Количество упаковок, шт
# clasts: [('Количество игрушек в одной упаковке', tensor([0.9029])), ('Число пакетиков', tensor([0.9332])), ('Количество подгузников в одной упаковке', tensor([0.9249])), ('Количество упаковок, шт.', tensor([1.])), ('Количество в одной упаковке, шт', tensor([0.9716])), ('Количество пеленок в одной упаковке, шт', tensor([0.9146])), ('Количество этикеток, шт', tensor([0.9382])), ('Количество бутылок, шт', tensor([0.9196])), ('Количество копий, шт.', tensor([0.9108])), ('Количество удочек/спиннингов, шт', tensor([0.9006])), ('Количество кондитерских мешков, шт', tensor([0.9058])), ('Количество пакетов в одном рулоне, шт', tensor([0.9110])), ('Количество емкостей, шт', tensor([0.9352])), ('Количество дизайнов, шт.', tensor([0.9009])), ('Количество емкостей, шт.', tensor([0.9352]))]
#
#
# clast main: Длина кабеля питания, м
# clasts: [('Длина кабеля 1, м', tensor([0.9416]))]
#
#
# clast main: Макс. нагрузка, Вт
# clasts: [('Макс. напор, м', tensor([0.9441])), ('Макс. нагрузка на полку, кг', tensor([0.9199])), ('Макс. нагрузка на полку ТВ, кг', tensor([0.9097])), ('Макс. рабочая нагрузка, кг', tensor([0.9512])), ('Мощность нагрузки, Вт', tensor([0.9342]))]
#
#
# clast main: Количество спиц
# clasts: [('Количество конфорок', tensor([0.9110])), ('Количество тостов', tensor([0.9014])), ('Количество рядов', tensor([0.9133])), ('Количество PCI-E x16', tensor([0.9104])), ('Количество PCI-E x1', tensor([0.9104])), ('Количество звеньев', tensor([0.9023])), ('Количество мест', tensor([0.9044])), ('Количество PCI-E x4', tensor([0.9104])), ('Количество свечей', tensor([0.9274])), ('Количество PCI-E x8', tensor([0.9104])), ('Количество тактов', tensor([0.9065])), ('Количество сопел', tensor([0.9190])), ('Количество пинцетов', tensor([0.9343])), ('Количество человек', tensor([0.9026])), ('Количество петель', tensor([0.9012]))]
#
#
# clast main: Длина в сложенном виде, см
# clasts: [('Длина в свернутом состоянии, см', tensor([0.9535])), ('Ширина в свернутом состоянии, см', tensor([0.9139])), ('Длина столешницы в разложенном виде, см', tensor([0.9198])), ('Длинная сторона, см', tensor([0.9125]))]
#
#
# clast main: Диаметр купола, см
# clasts: []
#
#
# clast main: Количество нитей
# clasts: [('Длина нити шовного материала, см', tensor([0.9000])), ('Количество нитей в плетении', tensor([0.9403]))]
#
#
# clast main: Размотка, м
# clasts: [('Ростовка, см', tensor([0.9051]))]
#
#
# clast main: Разрывная нагрузка, кг
# clasts: [('Грузоподъемность, кг', tensor([0.9164])), ('Разрывная нагрузка, lb', tensor([0.9402])), ('Нагрузка на фрикцион, кг', tensor([0.9205])), ('Разрывная нагрузка, кгс', tensor([0.9916])), ('Сила схватывания, кг/м2', tensor([0.9088]))]
#
#
# clast main: Ширина пильного полотна, мм
# clasts: [('Ширина плиты, см', tensor([0.9145])), ('Ширина профиля, мм', tensor([0.9060])), ('Размер режущего полотна, см', tensor([0.9070])), ('Ширина паза, мм', tensor([0.9062]))]
#
#
# clast main: Уровень сложности набора
# clasts: []
#
#
# clast main: Количество колес
# clasts: [('Диаметр колеса, мм', tensor([0.9231])), ('Жесткость колес (А)', tensor([0.9061])), ('Количество колес тачки', tensor([0.9623])), ('Ширина колеса, мм', tensor([0.9254]))]
#
#
# clast main: Диаметр переднего колеса, мм
# clasts: [('Диаметр заднего колеса, мм', tensor([0.9741])), ('Диаметр оси колеса, мм', tensor([0.9446])), ('Диаметр передних колес, см', tensor([0.9527])), ('Диаметр задних колес, см', tensor([0.9266])), ('Ширина задней оси, см', tensor([0.9045])), ('Ширина передней оси, см', tensor([0.9178]))]
#
#
# clast main: Макс. площадь помещения, кв.м
# clasts: [('Площадь, кв.м', tensor([0.9279])), ('Рабочая площадь, кв. м', tensor([0.9029])), ('Площадь, м²', tensor([0.9095]))]
#
#
# clast main: Высота стенки, см
# clasts: [('Высота спинки, см', tensor([0.9051])), ('Высота штанги, см', tensor([0.9152])), ('Высота доски, см', tensor([0.9057])), ('Высота полотна, см', tensor([0.9020])), ('Макс. высота фасада, мм', tensor([0.9003]))]
#
#
# clast main: Число строк
# clasts: []
#
#
# clast main: Тип молнии
# clasts: [('Число молний', tensor([0.9473]))]
#
#
# clast main: Макс. глубина сверления, мм
# clasts: [('Глубина встраивания, см', tensor([0.9122])), ('Макс. глубина обнаружения стали, мм', tensor([0.9494])), ('Макс. глубина обнаружения меди, мм', tensor([0.9242])), ('Макс. глубина обнаружения эл.проводки, мм', tensor([0.9153])), ('Макс. глубина уплотнения, мм', tensor([0.9556])), ('Макс. глубина сканирования', tensor([0.9270])), ('Глубина бурения, см', tensor([0.9081])), ('Макс. глубина обнаружения, см', tensor([0.9500]))]
#
#
# clast main: Количество мелодий
# clasts: [('Число мелодий', tensor([0.9895]))]
#
#
# clast main: Громкость звонка, дБ
# clasts: [('Громкость, дБ', tensor([0.9321]))]
#
#
# clast main: Число батарей звонка, шт.
# clasts: []
#
#
# clast main: Количество стекол дверцы духовки
# clasts: []
#
#
# clast main: Количество выходных разъемов
# clasts: []
#
#
# clast main: Максимальная толщина двери, мм
# clasts: [('Минимальная толщина двери, мм', tensor([0.9133])), ('Максимальная ширина створки, м', tensor([0.9032])), ('Общая толщина двери, мм', tensor([0.9416])), ('Максимальный вес двери, кг', tensor([0.9082]))]
#
#
# clast main: Длина модели, см
# clasts: [('Рабочая длина, см', tensor([0.9000])), ('Общая длина, см', tensor([0.9151])), ('Длина шага, см', tensor([0.9055])), ('Длина, пог. м', tensor([0.9062])), ('Длина пояса, см', tensor([0.9054])), ('Длина поддона, см', tensor([0.9090]))]
#
#
# clast main: Частота процессора, ГГц
# clasts: [('Макс. частота графического процессора (Boost), МГц', tensor([0.9107])), ('Частота графического процессора, МГц', tensor([0.9351])), ('Частота процессора, МГц', tensor([0.9679]))]
#
#
# clast main: Число ядер процессора
# clasts: [('Количество ядер', tensor([0.9303])), ('Число универсальных процессоров', tensor([0.9068]))]
#
#
# clast main: Количество HDD
# clasts: [('Количество SSD', tensor([0.9213])), ('Количество диодов', tensor([0.9201]))]
#
#
# clast main: Мощность блока питания, Вт
# clasts: []
#
#
# clast main: Общий объем HDD, ГБ
# clasts: []
#
#
# clast main: Суммарный объем всех дисков, ГБ
# clasts: []
#
#
# clast main: Количество зубьев, шт.
# clasts: [('Количество зубцов, шт.', tensor([0.9892]))]
#
#
# clast main: Минимальная длина стрижки, мм
# clasts: [('Максимальная длина стрижки, мм', tensor([0.9136]))]
#
#
# clast main: Ширина ножа, мм
# clasts: [('Количество ножей', tensor([0.9115])), ('Диаметр ножа, см', tensor([0.9151]))]
#
#
# clast main: Шаг винта
# clasts: []
#
#
# clast main: Количество лопастей гребного винта
# clasts: []
#
#
# clast main: Количество режимов работы
# clasts: []
#
#
# clast main: Ширина в плечах, см
# clasts: []
#
#
# clast main: Ширина в ногах, см
# clasts: []
#
#
# clast main: Толщина в свернутом состоянии, см
# clasts: []
#
#
# clast main: Точность измерения, г
# clasts: [('Дальность измерения, м', tensor([0.9124])), ('Точность позиционирования, м', tensor([0.9347]))]
#
#
# clast main: Макс. рабочая температура, °С
# clasts: [('Макс. температура применения, C', tensor([0.9341])), ('Мин. рабочая температура, °С', tensor([0.9270])), ('Макс. поддерживаемая температура, °C', tensor([0.9193])), ('Макс. температура нагрева, °C', tensor([0.9377]))]
#
#
# clast main: Скорость чтения, Мб/с
# clasts: [('Скорость записи, Мб/с', tensor([0.9159]))]
#
#
# clast main: Диаметр крючка, мм
# clasts: [('Диаметр крепежа, мм', tensor([0.9186])), ('Диаметр катушки, мм', tensor([0.9057])), ('Диаметр конфорки, мм', tensor([0.9031])), ('Диаметр кольца, мм', tensor([0.9174])), ('Диаметр клеевого стержня, мм', tensor([0.9032]))]
#
#
# clast main: Длина карниза, см
# clasts: [('Мин. длина раздвижного карниза, см', tensor([0.9554])), ('Макс. длина раздвижного карниза, см', tensor([0.9523]))]
#
#
# clast main: Количество клавиш клавиатуры
# clasts: [('Количество клавиш', tensor([0.9506])), ('Число клавиш', tensor([0.9406])), ('Количество клавиш, шт.', tensor([0.9380]))]
#
#
# clast main: Количество полос
# clasts: []
#
#
# clast main: Диаметр основного круга, мм
# clasts: []
#
#
# clast main: Длина поводка, м
# clasts: [('Длина ленты, м', tensor([0.9186])), ('Длина столбика, см', tensor([0.9123])), ('Общая длина, мм', tensor([0.9099])), ('Длина путей, см', tensor([0.9137])), ('Сечение поводка, мм', tensor([0.9116])), ('Длина вала, м', tensor([0.9146])), ('Длина лески, м', tensor([0.9226])), ('Длина ствола', tensor([0.9048])), ('Длина троса/цепи, м', tensor([0.9079]))]
#
#
# clast main: Кол-во циклов заряд-разряд
# clasts: [('Кол-во слотов для зарядки', tensor([0.9032]))]
#
#
# clast main: Теплопроводность, Вт/(м⋅К)
# clasts: [('Теплоотдача, Вт', tensor([0.9253])), ('Теплоотдача, Вт/ч', tensor([0.9193])), ('Коэффициент теплопроводности, Вт/м°С', tensor([0.9347]))]
#
#
# clast main: Число жил
# clasts: []
#
#
# clast main: Сечение жилы, кв.мм
# clasts: []
#
#
# clast main: Белки, г/100 г
# clasts: []
#
#
# clast main: Жиры, г/100 г
# clasts: [('Жирность, %', tensor([0.9316]))]
#
#
# clast main: Углеводы, г/100 г
# clasts: []
#
#
# clast main: Количество встроенной памяти, ГБ
# clasts: [('Встроенная память, ГБ', tensor([0.9531])), ('Объем встроенной памяти, ГБ', tensor([0.9682])), ('Встроенная память,  ГБ', tensor([0.9531])), ('Встроенная память,  МБ', tensor([0.9281]))]
#
#
# clast main: Количество полюсов
# clasts: []
#
#
# clast main: Диаметр жилы, мм
# clasts: []
#
#
# clast main: Макс. заглубление, м
# clasts: [('Мин. заглубление, м', tensor([0.9364]))]
#
#
# clast main: Ширина профиля окна, мм
# clasts: []
#
#
# clast main: Количество камер
# clasts: [('Количество основных камер', tensor([0.9360])), ('Количество камер, шт.', tensor([0.9790])), ('Количество фото, шт', tensor([0.9108])), ('Число подключаемых камер', tensor([0.9441])), ('Объем перемалывающей камеры, мл', tensor([0.9026])), ('Объём камеры, л', tensor([0.9302]))]
#
#
# clast main: Скорость вышивания, ст./мин
# clasts: [('Макс. скорость печати (цв.), стр/мин', tensor([0.9047])), ('Скорость шитья, стежки/мин', tensor([0.9464]))]
#
#
# clast main: Макс. высота подъема лапки, мм
# clasts: []
#
#
# clast main: Площадь рулона, м2
# clasts: [('Длина рулона, м', tensor([0.9557])), ('Длина одного рулона, м', tensor([0.9299])), ('Расчетное количество рулонов', tensor([0.9017]))]
#
#
# clast main: Максимальное давление газа, мбар
# clasts: [('Минимальное давление газа, мбар', tensor([0.9106]))]
#
#
# clast main: Площадь действия, м²
# clasts: [('Рекомендуемая площадь, м²', tensor([0.9281])), ('Площадь, дм²', tensor([0.9134])), ('Площадь полива, м²', tensor([0.9427])), ('Площадь покрытия, м2', tensor([0.9067])), ('Полезная площадь, м2', tensor([0.9159])), ('Площадь застройки, м2', tensor([0.9155])), ('Оклеиваемая площадь, м²', tensor([0.9304]))]
#
#
# clast main: Минимальная влажность, %
# clasts: []
#
#
# clast main: Максимальная влажность, %
# clasts: []
#
#
# clast main: Высота профиля, %
# clasts: []
#
#
# clast main: Ширина спинки, см
# clasts: [('Ширина ски-стопа, мм', tensor([0.9212])), ('Ширина секции, см', tensor([0.9029]))]
#
#
# clast main: Минимальная высота, см
# clasts: [('Минимальная высота холста, см', tensor([0.9269]))]
#
#
# clast main: Работа в режиме ожидания, ч
# clasts: [('Время работы в режиме ожидания, ч', tensor([0.9893]))]
#
#
# clast main: Кол-во крепежных отверстий
# clasts: [('Кол-во спицевых отверстий', tensor([0.9403]))]
#
#
# clast main: Диаметр расположения отверстий (PCD)
# clasts: [('Диаметр центр. отверстия, мм', tensor([0.9152])), ('Диаметр отверстия, мм', tensor([0.9359]))]
#
#
# clast main: Длина трубы, м
# clasts: [('Длина шланга, м', tensor([0.9016])), ('Диаметр трубки, мм', tensor([0.9402])), ('Диаметр трубы прицела, мм', tensor([0.9010])), ('Размер труб каркаса, мм', tensor([0.9050])), ('Макс. диаметр трубы, мм', tensor([0.9303])), ('Длина трубки для плавания, см', tensor([0.9236]))]
#
#
# clast main: Шаг резьбы, мм
# clasts: [('Шаг гвоздя, мм', tensor([0.9277])), ('Шаг витка шнека, мм', tensor([0.9071]))]
#
#
# clast main: Кол-во уровней положения основания
# clasts: []
#
#
# clast main: Количество капсул в упаковке
# clasts: [('Общее количество капсул/таблеток', tensor([0.9194]))]
#
#
# clast main: Содержание арабики, %
# clasts: []
#
#
# clast main: Количество экспериментов в наборе
# clasts: []
#
#
# clast main: Вес в собранном состоянии, кг
# clasts: []
#
#
# clast main: Минимальный диаметр, мм
# clasts: [('Длина меньшей стороны, мм', tensor([0.9048])), ('Минимальная ширина шва, мм', tensor([0.9479]))]
#
#
# clast main: Форм-фактор M.2
# clasts: []
#
#
# clast main: Макс. выходной ток
# clasts: [('Макс. выходной ток, А', tensor([0.9916])), ('Выходной ток, А', tensor([0.9521])), ('Макс. выходное сопротивление, Ом', tensor([0.9207]))]
#
#
# clast main: Влажность древесины, не более (%)
# clasts: []
#
#
# clast main: Мин. температура применения, C
# clasts: [('Мин. температура, °С', tensor([0.9589])), ('Температура срабатывания, C', tensor([0.9123])), ('Мин. поддерживаемая температура, °C', tensor([0.9519])), ('Мин. температура эксплуатации, С°', tensor([0.9680])), ('Мин. температура нагрева, °С', tensor([0.9425]))]
#
#
# clast main: Макс температура воды, °С
# clasts: [('Мин. температура охлаждения воды, °С', tensor([0.9118])), ('Макс. температура нагрева воды, °С', tensor([0.9792])), ('Макс. температура воды на входе, °C', tensor([0.9474]))]
#
#
# clast main: Количество двигателей, шт
# clasts: [('Количество двигателей', tensor([0.9771])), ('Количество двигателей метальной головки', tensor([0.9305])), ('Количество моторов', tensor([0.9462]))]
#
#
# clast main: С какого месяца можно давать лакомство
# clasts: []
#
#
# clast main: Диаметр батута, см
# clasts: []
#
#
# clast main: Высота от пола до основания батута, см
# clasts: []
#
#
# clast main: Высота защитной сетки, см
# clasts: []
#
#
# clast main: Кол-во пружин, шт
# clasts: []
#
#
# clast main: Высота зеркала, см
# clasts: [('Ширина зеркала, см', tensor([0.9518]))]
#
#
# clast main: Количество карандашей, шт
# clasts: []
#
#
# clast main: Длина столешницы, см
# clasts: [('Ширина столешницы, см', tensor([0.9669])), ('Длина рабочего стола, мм', tensor([0.9167])), ('Длина стола с подголовником, см', tensor([0.9188])), ('Ширина стола, см', tensor([0.9129]))]
#
#
# clast main: Вылет, мм
# clasts: [('Дальность полета, м', tensor([0.9135])), ('Вылет ригелей, мм', tensor([0.9140])), ('Высота полета, м', tensor([0.9012]))]
#
#
# clast main: Макс. частота обновления, Гц
# clasts: []
#
#
# clast main: Кол-во розеток
# clasts: [('Количество розеток', tensor([0.9253]))]
#
#
# clast main: Площадь обогрева, кв.м
# clasts: [('Отапливаемая площадь, кв. м', tensor([0.9484]))]
#
#
# clast main: Макс. сопротивление, Ом
# clasts: []
#
#
# clast main: Количество динамиков
# clasts: [('Количество динамиков ВЧ', tensor([0.9875])), ('Количество динамиков НЧ', tensor([0.9685])), ('Количество динамиков СЧ/НЧ', tensor([0.9549]))]
#
#
# clast main: Количество ножек
# clasts: []
#
#
# clast main: Мин. высота над электрической плитой, см
# clasts: [('Мин. высота над газовой плитой, см', tensor([0.9322]))]
#
#
# clast main: Мощность подсветки, Вт
# clasts: [('Мощность лампы, Вт', tensor([0.9304]))]
#
#
# clast main: Количество ламп освещения вытяжки, шт
# clasts: [('Длина ламп, см', tensor([0.9048]))]
#
#
# clast main: Количество жировых фильтров, шт.
# clasts: [('Количество фильтров', tensor([0.9064]))]
#
#
# clast main: Количество отводов
# clasts: [('Количество вводов', tensor([0.9000])), ('Количество выходов', tensor([0.9113]))]
#
#
# clast main: Рабочее давление, атм
# clasts: []
#
#
# clast main: Ширина рамы, см
# clasts: [('Ширина обработки, см', tensor([0.9025])), ('Ширина ламели, см', tensor([0.9117])), ('Ширина вала, см', tensor([0.9236])), ('Ширина станка, м', tensor([0.9074])), ('Внешний размер рамы, см', tensor([0.9385]))]
#
#
# clast main: Показатель мощности (kBTU)
# clasts: []
#
#
# clast main: Уровень шума внешнего блока, дБ
# clasts: [('Уровень шума, дБ (А)', tensor([0.9434])), ('Уровень шума при отжиме, дБ', tensor([0.9223])), ('Уровень шума при стирке, дБ', tensor([0.9006])), ('Уровень шума, дБ', tensor([0.9501]))]
#
#
# clast main: Вес внешнего блока, кг
# clasts: [('Вес внутреннего блока, кг', tensor([0.9592])), ('Вес прогулочного блока, кг', tensor([0.9299]))]
#
#
# clast main: Мощность в режиме охлаждения, Вт
# clasts: [('Мощность охлаждения, Вт', tensor([0.9720])), ('Производительность охлаждения, л/ч', tensor([0.9126]))]
#
#
# clast main: Охлаждающая способность, BTU
# clasts: []
#
#
# clast main: Число дверей
# clasts: [('Количество входов', tensor([0.9000])), ('Количество полок на двери', tensor([0.9272])), ('Число комнат', tensor([0.9008]))]
#
#
# clast main: Высота первой шторы, см
# clasts: [('Ширина первой шторы, см', tensor([0.9516]))]
#
#
# clast main: Максимальный пусковой ток, А
# clasts: [('Максимальный ток заряда, А', tensor([0.9373])), ('Макс. сила тока, А', tensor([0.9022])), ('Пусковой ток, А', tensor([0.9341]))]
#
#
# clast main: Макс. емкость аккумулятора, А•ч
# clasts: [('Емкость аккумулятора,  мАч', tensor([0.9292])), ('Емкость аккумулятора, Втч', tensor([0.9507])), ('Объем аккумулятора, мл', tensor([0.9314]))]
#
#
# clast main: Количество кнопок
# clasts: [('Число кнопок вызова в комплекте, шт.', tensor([0.9035])), ('Количество программируемых кнопок', tensor([0.9474]))]
#
#
# clast main: Макс. диаметр конфорки, см
# clasts: [('Макс. ширина ТВ, см', tensor([0.9176]))]
#
#
# clast main: Длина спального места в разложенном виде, см
# clasts: []
#
#
# clast main: Минимальная высота/длина, см
# clasts: []
#
#
# clast main: Диаметр лопастей, см
# clasts: [('Ширина лапы, см', tensor([0.9077])), ('Диаметр лески, мм', tensor([0.9064])), ('Количество лопастей', tensor([0.9009]))]
#
#
# clast main: Изменяемый объем, л
# clasts: [('Объем дежи, л', tensor([0.9094]))]
#
#
# clast main: Высота второй шторы, см
# clasts: [('Ширина второй шторы, см', tensor([0.9585]))]
#
#
# clast main: Ширина крепления шторы, см
# clasts: [('Диаметр крышки, см', tensor([0.9047])), ('Ширина шнура, мм', tensor([0.9040]))]
#
#
# clast main: Макс. диаметр отверстия в стали, мм
# clasts: [('Макс. диаметр отверстия в дереве, мм', tensor([0.9016])), ('Макс. диаметр отверстия в бетоне, мм', tensor([0.9207])), ('Макс. расстояние между отверстиями по ширине, мм', tensor([0.9053])), ('Макс. диаметр проволоки, мм', tensor([0.9041])), ('Макс. диаметр зажима, мм', tensor([0.9015])), ('Макс. диаметр реза, мм', tensor([0.9007]))]
#
#
# clast main: Мин. диаметр патрона, мм
# clasts: [('Мин. диаметр хомута, мм', tensor([0.9054])), ('Мин. диаметр зажима, мм', tensor([0.9243]))]
#
#
# clast main: Количество таблеток/капсул в одной упаковке, шт
# clasts: []
#
#
# clast main: Пассажировместимость, чел.
# clasts: []
#
#
# clast main: Грузоподъемность лодки, кг
# clasts: []
#
#
# clast main: Чувствительность, дБ
# clasts: [('Чувствительность, мМЕ/мл', tensor([0.9234]))]
#
#
# clast main: Время зарядки аккумулятора, мин
# clasts: [('Время зарядки аккумулятора, ч', tensor([0.9509]))]
#
#
# clast main: Число дополнительных чаш
# clasts: []
#
#
# clast main: Макс. сечение кабеля, мм²
# clasts: [('Мин. сечение кабеля, мм²', tensor([0.9492]))]
#
#
# clast main: Номинальная отключающая способность, кA
# clasts: []
#
#
# clast main: Количество модулей
# clasts: []
#
#
# clast main: Количество лакомств в одной упаковке
# clasts: []
#
#
# clast main: Обхват шеи минимальный, см
# clasts: []
#
#
# clast main: Длина ошейника общая, см
# clasts: []
#
#
# clast main: Число полок
# clasts: []
#
#
# clast main: Длина лапы, см
# clasts: []
#
#
# clast main: Длина рукава, см
# clasts: []
#
#
# clast main: Длина шланга, см
# clasts: [('Диаметр шланга, мм', tensor([0.9571])), ('Наружный диаметр шланга, мм', tensor([0.9367]))]
#
#
# clast main: Количество потребителей
# clasts: []
#
#
# clast main: Длина гирлянды, м
# clasts: []
#
#
# clast main: Число пикселей матрицы, Мпикс
# clasts: [('Эффективное количество пикселей, Мпикс', tensor([0.9403])), ('Количество матриц', tensor([0.9168]))]
#
#
# clast main: Угол обзора по диагонали, °
# clasts: [('Угол обзора по вертикали, °', tensor([0.9490])), ('Угол обзора, °', tensor([0.9676]))]
#
#
# clast main: Минимальный момент затяжки, Н·м
# clasts: [('Максимальный момент затяжки, Н·м', tensor([0.9154]))]
#
#
# clast main: Зазор между электродами, мм
# clasts: []
#
#
# clast main: Число боковых электродов
# clasts: []
#
#
# clast main: Активная мощность, Вт
# clasts: [('Коэффициент мощности', tensor([0.9073])), ('Мощность, л.с.', tensor([0.9038])), ('Мощность всасывания, Вт', tensor([0.9073]))]
#
#
# clast main: Время переключения на батарею, мс
# clasts: []
#
#
# clast main: Количество форм трансформации
# clasts: []
#
#
# clast main: Диаметр подключения сифона, см
# clasts: []
#
#
# clast main: Класс подшипников (ABEC)
# clasts: []
#
#
# clast main: Время непрерывной работы, мин
# clasts: []
#
#
# clast main: Диаметр, #PE
# clasts: [('Диаметр пропеллеров, мм', tensor([0.9031]))]
#
#
# clast main: Мин. высота среза травы, см
# clasts: [('Макс. высота среза травы, см', tensor([0.9568]))]
#
#
# clast main: Объем травосборника, л
# clasts: [('Объем мусоросборника, л', tensor([0.9255]))]
#
#
# clast main: Объем двигателя, куб.см
# clasts: [('Объём лодочного двигателя, куб. см', tensor([0.9042]))]
#
#
# clast main: Объем топливного бака, л
# clasts: [('Объем бака, мл', tensor([0.9128])), ('Объем лодочного топливного бака, л', tensor([0.9444])), ('Объем бака для отходов, л', tensor([0.9029]))]
#
#
# clast main: Гарантия на внутренний бак, мес.
# clasts: []
#
#
# clast main: Тактовая частота, МГц
# clasts: [('Рабочая частота, Гц', tensor([0.9012])), ('Макс. частота оперативной памяти, МГц', tensor([0.9013])), ('Рабочая частота, МГц', tensor([0.9368]))]
#
#
# clast main: RAS to CAS Delay (tRCD), тактов
# clasts: [('Row Precharge Delay (tRP), тактов', tensor([0.9279])), ('CAS Latency (CL), тактов', tensor([0.9155])), ('Active to Precharge Delay (tRAS), тактов', tensor([0.9190]))]
#
#
# clast main: Пропускная способность, Мб/с
# clasts: [('Пропускная способность, л/с', tensor([0.9040]))]
#
#
# clast main: Размер карабина вертлюга, мм
# clasts: []
#
#
# clast main: Размер застежки
# clasts: []
#
#
# clast main: Количество компрессоров
# clasts: []
#
#
# clast main: Общий объем, л
# clasts: [('Объем ресивера, л', tensor([0.9102])), ('Объем бачка, л', tensor([0.9083])), ('Объем топки, л', tensor([0.9182])), ('Объем одной емкости, л', tensor([0.9022]))]
#
#
# clast main: Общий объем холодильной камеры, л
# clasts: [('Общий объем морозильной камеры, л', tensor([0.9774]))]
#
#
# clast main: Годовое потребление, кВт ч/год
# clasts: []
#
#
# clast main: Реальный угол зрения, °
# clasts: []
#
#
# clast main: Минимальная дистанция фокусировки, м
# clasts: [('Минимальное проекционное расстояние, м', tensor([0.9297])), ('Мин. фокусное расстояние, мм', tensor([0.9219])), ('Макс. фокусное расстояние, мм', tensor([0.9188]))]
#
#
# clast main: Сумеречное число
# clasts: []
#
#
# clast main: Мин. радиус изгиба кабеля, мм
# clasts: []
#
#
# clast main: Дальность полива, м
# clasts: [('Дальность связи, м', tensor([0.9261])), ('Дальность обнаружения, м', tensor([0.9267]))]
#
#
# clast main: Количество режимов нагрева
# clasts: []
#
#
# clast main: Число портов USB Type-C
# clasts: [('Число портов USB Type-A  3.2 Gen 1', tensor([0.9676])), ('Число портов USB 2.0', tensor([0.9828])), ('Число портов USB Type-A 3.2 Gen 2', tensor([0.9676])), ('Количество USB портов', tensor([0.9706]))]
#
#
# clast main: Кол-во элементов аккумулятора
# clasts: [('Количество аккумуляторов в комплекте', tensor([0.9076])), ('Кол-во батарей, шт', tensor([0.9136])), ('Кол-во аккумуляторов в комплекте', tensor([0.9547]))]
#
#
# clast main: Номинальная выходная мощность на канал, Вт
# clasts: [('Макс. выходная мощность на канал, Вт', tensor([0.9611])), ('Выходная мощность, Вт', tensor([0.9200]))]
#
#
# clast main: Диаметр нижнего яруса, см
# clasts: []
#
#
# clast main: Количество программ стирки
# clasts: []
#
#
# clast main: Количество капель
# clasts: []
#
#
# clast main: Начальная скорость, м/с
# clasts: [('Скорость открывания, м/мин', tensor([0.9100]))]
#
#
# clast main: Ёмкость магазина, шт
# clasts: []
#
#
# clast main: Объем пылесборника, мл
# clasts: [('Объем шприца, мл', tensor([0.9044]))]
#
#
# clast main: Сила всасывания, Па
# clasts: []
#
#
# clast main: Объем буферной памяти, Мб
# clasts: []
#
#
# clast main: Высота чаши, см
# clasts: []
#
#
# clast main: Ширина зева гаечного ключа, мм
# clasts: []
#
#
# clast main: Число управляемых устройств, шт.
# clasts: []
#
#
# clast main: Мощность варочной панели, Вт
# clasts: []
#
#
# clast main: Количество двухконтурных конфорок
# clasts: [('Количество трехконтурных конфорок', tensor([0.9271]))]
#
#
# clast main: Макс. время работы (музыка),  ч
# clasts: []
#
#
# clast main: Макс. время работы (видео),  ч
# clasts: []
#
#
# clast main: Минимальная освещенность, люкс
# clasts: []
#
#
# clast main: Макс. расстояние от стены, мм
# clasts: [('Мин. расстояние от стены, мм', tensor([0.9570])), ('Макс. расстояние между отверстиями по высоте, мм', tensor([0.9136]))]
#
#
# clast main: Длина пластин, мм
# clasts: [('Диаметр пластика, мм', tensor([0.9065])), ('Монтажная длина, мм', tensor([0.9027])), ('Макс. длина ленты, мм', tensor([0.9022]))]
#
#
# clast main: Количество слотов RAM
# clasts: [('Доп. слоты RAM памяти', tensor([0.9189]))]
#
#
# clast main: Макс. поддерживаемая частота RAM
# clasts: []
#
#
# clast main: Кол-во внутренних разъемов SATA 6 Гбит/с
# clasts: [('Кол-во разъемов SATA', tensor([0.9237]))]
#
#
# clast main: Кол-во занимаемых слотов
# clasts: []
#
#
# clast main: Количество вентиляторов
# clasts: [('Количество разъемов питания для вентилятора', tensor([0.9073])), ('Диаметр вентилятора, мм', tensor([0.9088]))]
#
#
# clast main: Количество поддерживаемых мониторов
# clasts: [('Число подключаемых мониторов', tensor([0.9419]))]
#
#
# clast main: Число текстурных блоков
# clasts: []
#
#
# clast main: Кол-во выходов HDMI
# clasts: []
#
#
# clast main: Число блоков растеризации
# clasts: []
#
#
# clast main: Версия шейдеров
# clasts: []
#
#
# clast main: Кол-во выходов Display Port
# clasts: []
#
#
# clast main: Рекомендуемая мощность БП, Вт
# clasts: []
#
#
# clast main: Макс. время работы, дни
# clasts: []
#
#
# clast main: Количество микрофонов
# clasts: []
#
#
# clast main: Макс. время записи, часов
# clasts: []
#
#
# clast main: Максимальный вес ворот, кг
# clasts: []
#
#
# clast main: Площадь листа, м2
# clasts: [('Количество листов', tensor([0.9092]))]
#
#
# clast main: Длина клеевого стержня, мм
# clasts: []
#
#
# clast main: Длина хомута, мм
# clasts: [('Макс. диаметр хомута, мм', tensor([0.9288])), ('Хвост, мм', tensor([0.9000]))]
#
#
# clast main: Макс. увеличение, крат
# clasts: []
#
#
# clast main: Макс. вертикальная нагрузка на фаркоп, кг
# clasts: []
#
#
# clast main: Мин. сварочный ток, А
# clasts: []
#
#
# clast main: Макс. диаметр электрода, мм
# clasts: []
#
#
# clast main: Макс. частота колебаний, кол./мин
# clasts: []
#
#
# clast main: Время работы на одном заряде, ч
# clasts: []
#
#
# clast main: Макс. ширина распила, мм
# clasts: [('Макс. ширина пакета, см', tensor([0.9115])), ('Макс. ширина шасси, см', tensor([0.9200])), ('Максимальная ширина шва, мм', tensor([0.9219])), ('Макс. длина реза, мм', tensor([0.9216])), ('Макс. ширина ворот, см', tensor([0.9141])), ('Макс. длина выноса, мм', tensor([0.9084])), ('Макс. ширина удерживаемого устройства, мм', tensor([0.9223])), ('Макс. диаметр ветвей, мм', tensor([0.9040]))]
#
#
# clast main: Минимальная плотность бумаги, г/м2
# clasts: [('Максимальная плотность бумаги, г/м2', tensor([0.9159]))]
#
#
# clast main: Выходной лоток, листов
# clasts: []
#
#
# clast main: Максимальная ширина чека/этикетки, мм
# clasts: []
#
#
# clast main: Минимальное давление воды (бар)
# clasts: []
#
#
# clast main: Макс. тест, граммы
# clasts: [('Мин. тест, граммы', tensor([0.9340])), ('Тест, кг', tensor([0.9214]))]
#
#
# clast main: Макс. входное напряжение, В
# clasts: [('Мин. входное напряжение, В', tensor([0.9376]))]
#
#
# clast main: Диаметр бурения, мм
# clasts: [('Диаметр шара, мм', tensor([0.9016])), ('Макс. диаметр бревна, см', tensor([0.9022]))]
#
#
# clast main: Разрядность калькулятора
# clasts: []
#
#
# clast main: Мощность массажера, Вт
# clasts: []
#
#
# clast main: Количество бритвенных головок
# clasts: [('Количество метательных головок', tensor([0.9034]))]
#
#
# clast main: Автономное сохранение холода, ч
# clasts: [('Сохраняет холод до, ч', tensor([0.9242]))]
#
#
# clast main: Количество подключаемых устройств
# clasts: [('Число подключаемых вызывных панелей', tensor([0.9003]))]
#
#
# clast main: Количество антенн
# clasts: [('Длина антенны, см', tensor([0.9110]))]
#
#
# clast main: Количество LAN портов
# clasts: [('Количество WAN портов', tensor([0.9448]))]
#
#
# clast main: Количество веток, шт
# clasts: []
#
#
# clast main: Количество ярусов елки
# clasts: [('Количество ярусов', tensor([0.9326]))]
#
#
# clast main: Размер мяча
# clasts: [('Емкость (число мячей)', tensor([0.9339]))]
#
#
# clast main: Максимальный рост пользователя, см
# clasts: []
#
#
# clast main: Минимальный рост пользователя, см
# clasts: []
#
#
# clast main: Количество ребер жесткости
# clasts: [('Вертикальные ребра жесткости, шт', tensor([0.9249])), ('Горизонтальные ребра жесткости, шт', tensor([0.9087]))]
#
#
# clast main: Длина большей стороны, мм
# clasts: []
#
#
# clast main: Светопропускаемость, %
# clasts: []
#
#
# clast main: Количество массажных роликов
# clasts: [('Количество секций массажного стола', tensor([0.9036]))]
#
#
# clast main: Транспортная длина, см
# clasts: []
#
#
# clast main: Максимальный расход, м3/ч
# clasts: [('Номинальный расход, м3/ч', tensor([0.9131])), ('Максимальный расход газа, м³/ч', tensor([0.9193]))]
#
#
# clast main: Глубина пропила в алюминии (легких сплавах), мм
# clasts: []
#
#
# clast main: Размер набора, см
# clasts: []
#
#
# clast main: Сила сцепления, кг
# clasts: []
#
#
# clast main: Количество бегунков
# clasts: []
#
#
# clast main: Макс. темп. снаружи, +°С
# clasts: []
#
#
# clast main: Радиус приема сигнала датчика, м
# clasts: [('Количество датчиков', tensor([0.9020]))]
#
#
# clast main: Макс. число датчиков, шт.
# clasts: []
#
#
# clast main: Межцентровое расстояние, мм
# clasts: []
#
#
# clast main: Содержание спирта, %
# clasts: []
#
#
# clast main: Полная выходная мощность звука, Вт
# clasts: []
#
#
# clast main: Ток утечки, мА
# clasts: []
#
#
# clast main: Степень вакуума, бар
# clasts: []
#
#
# clast main: Интенсивность привода ворот, %
# clasts: []
#
#
# clast main: Расход воздуха, л/мин
# clasts: [('Расход воздуха, м3/час', tensor([0.9314]))]
#
#
# clast main: Толщина тормозного диска, мм
# clasts: []
#
#
# clast main: Пробивная способность, листов
# clasts: []
#
#
# clast main: Расход топлива, гр/ч
# clasts: [('Расход топлива, л/ч', tensor([0.9520]))]
#
#
# clast main: Количество конфорок горелки, шт
# clasts: [('Количество конфорок с двойным рядом пламени', tensor([0.9114])), ('Количество конфорок с тройным рядом пламени', tensor([0.9082]))]
#
#
# clast main: Число степеней очистки
# clasts: []
#
#
# clast main: MTBF, кликов
# clasts: []
#
#
# clast main: Количество точек запирания
# clasts: [('Количество точек крепления', tensor([0.9235])), ('Количество точек фокусировки, шт', tensor([0.9065]))]
#
#
# clast main: Загрузка белья для сушки, кг
# clasts: []
#
#
# clast main: Количество карт
# clasts: [('Количество карт в колоде', tensor([0.9317])), ('Количество RF-карт, шт', tensor([0.9377]))]
#
#
# clast main: Ход вилки, мм
# clasts: []
#
#
# clast main: Контроль
# clasts: []
#
#
# clast main: Срок потребления
# clasts: []
#
#
# clast main: Количество панелей
# clasts: []
#
#
# clast main: Ширина рабочей части, см
# clasts: [('Ширина рабочего стола, мм', tensor([0.9383])), ('Рабочий объем, см3', tensor([0.9383])), ('Длина рабочего основания, мм', tensor([0.9153])), ('Ширина рабочей части, мм', tensor([0.9899])), ('Длина рабочей части, см', tensor([0.9619])), ('Ширина рабочего основания, мм', tensor([0.9526])), ('Диаметр рабочей поверхности, см', tensor([0.9388])), ('Длина рабочей поверхности, см', tensor([0.9334])), ('Рабочая ширина щеток, мм', tensor([0.9196]))]
#
#
# clast main: Количество краников
# clasts: []
#
#
# clast main: Емкость резервуара холодной воды, л
# clasts: [('Емкость резервуара горячей воды, л', tensor([0.9540])), ('Объем резервуара, мл', tensor([0.9038]))]
#
#
# clast main: Диаметр шарика, мм
# clasts: [('Диаметр ершика, мм', tensor([0.9015]))]
#
#
# clast main: Длина шатуна, мм
# clasts: []
#
#
# clast main: Мощность передатчика, dBm
# clasts: [('Мощность передатчика, Вт', tensor([0.9310]))]
#
#
# clast main: Количество одновременно работающих диапазонов
# clasts: []
#
#
# clast main: Вес шасси, кг
# clasts: [('Вес автокресла, кг', tensor([0.9098]))]
#
#
# clast main: Вес коляски, кг
# clasts: []
#
#
# clast main: Ширина прогулочного блока/люльки, см
# clasts: [('Длина прогулочного блока, см', tensor([0.9544])), ('Ширина прогулочного блока, см', tensor([0.9828])), ('Длина прогулочного блока/люльки, см', tensor([0.9744]))]
#
#
# clast main: Длина люльки, см
# clasts: []
#
#
# clast main: Вес люльки, кг
# clasts: []
#
#
# clast main: Сохраняет тепло до, ч
# clasts: [('Время сохранения температуры, ч', tensor([0.9167]))]
#
#
# clast main: Диаметр колонны, мм
# clasts: []
#
#
# clast main: Число перевозимых лыж
# clasts: [('Число перевозимых сноубордов', tensor([0.9137]))]
#
#
# clast main: Число перевозимых велосипедов
# clasts: []
#
#
# clast main: Класс линолеума
# clasts: []
#
#
# clast main: Базовая частота, ГГц
# clasts: []
#
#
# clast main: Турбо-частота, ГГц
# clasts: []
#
#
# clast main: Количество потоков
# clasts: []
#
#
# clast main: Условный проход, мм
# clasts: []
#
#
# clast main: Макс. длина видеокарты, мм
# clasts: []
#
#
# clast main: Макс. высота процессорного кулера, мм
# clasts: []
#
#
# clast main: Время полного высыхания, ч
# clasts: [('Время полной зарядки, ч', tensor([0.9013]))]
#
#
# ...
# clasts: []
#
#
# clast main: Количество предметов в пенале
# clasts: []
#
#
# clast main: Короткая сторона, см
# clasts: []
#
#
# clast main: Макс. крутящий момент, Нм
# clasts: []
#
#
# clast main: Разрежение, мбар
# clasts: []
#
#
# clast main: Полная мощность, кВА
# clasts: []
#
#
# clast main: Макс. потребляемый ток, А
# clasts: [('Макс. ток потребления, А', tensor([0.9719])), ('Ток, А', tensor([0.9031]))]
#
#
# clast main: Напряжение холостого хода, В
# clasts: []
#
#
# clast main: Напряжение дуги, В
# clasts: []
#
#
# clast main: Количество поверхностей
# clasts: []
#
#
# clast main: Номер
# clasts: []
#
#
# clast main: Скорость печати, мм/сек
# clasts: [('Макс. скорость печати (ч/б), стр/мин', tensor([0.9395])), ('Макс. скорость печати фото, секунд', tensor([0.9313])), ('Скорость печати (экструдера), мм/сек', tensor([0.9699]))]
#
#
# clast main: Количество лепестков диафрагмы
# clasts: []
#
#
# clast main: Число оптических элементов
# clasts: [('Число групп оптических элементов', tensor([0.9774]))]
#
#
# clast main: Ширина лопаты, см
# clasts: []
#
#
# clast main: Макс. нагрузка на один снаряд, кг
# clasts: []
#
#
# clast main: Ширина/диаметр формы, см
# clasts: []
#
#
# clast main: Емкость, Вт•ч
# clasts: [('Емкость, мкФ', tensor([0.9282])), ('Вместимость бутылочек, шт', tensor([0.9087])), ('Объем одной емкости, мл', tensor([0.9034]))]
#
#
# clast main: Версия PCI Express
# clasts: []
#
#
# clast main: Высота тюля, см
# clasts: [('Ширина тюля, см', tensor([0.9258]))]
#
#
# clast main: Пятка, мм
# clasts: []
#
#
# clast main: Носок, мм
# clasts: []
#
#
# clast main: Талия, мм
# clasts: [('Обхват талии, см', tensor([0.9277]))]
#
#
# clast main: Максимальное давление, атм (кг/см2)
# clasts: []
#
#
# clast main: Макс. взлетный вес, г
# clasts: []
#
#
# clast main: Угол поворота/наклона, град.
# clasts: []
#
#
# clast main: Макс. воздушный поток, л/мин
# clasts: [('Макс. воздушный поток, CFM', tensor([0.9292]))]
#
#
# clast main: Вес ракетки без струны, г
# clasts: []
#
#
# clast main: Длина ракетки, см
# clasts: [('Размер головки ракетки, кв. дюймов', tensor([0.9008])), ('Длина ручки ракетки, см', tensor([0.9354]))]
#
#
# clast main: Номер иглы
# clasts: []
#
#
# clast main: Кол-во разъемов Molex
# clasts: []
#
#
# clast main: Баланс ракетки, см
# clasts: []
#
#
# clast main: Выход первой страницы, с
# clasts: []
#
#
# clast main: Диаметр до усадки, мм
# clasts: []
#
#
# clast main: Минимальный вес ребёнка, кг
# clasts: [('Минимальный вес животного, кг', tensor([0.9045]))]
#
#
# clast main: Максимальная вязкость материала, DIN
# clasts: []
#
#
# clast main: Высота теннисного стола, мм
# clasts: []
#
#
# clast main: Объем одной бутылки, мл
# clasts: []
#
#
# clast main: Число ступеней, шт
# clasts: []
#
#
# clast main: Макс. рабочая высота, м
# clasts: [('Высота рабочего стола, мм', tensor([0.9017])), ('Макс. рабочая высота пера, мм', tensor([0.9273])), ('Макс. высота потолков, м', tensor([0.9234]))]
#
#
# clast main: Погрешность стабилизации, %
# clasts: []
#
#
# clast main: Диаметр посадочного места для дисков и замков, мм
# clasts: []
#
#
# clast main: Длина грифа, см
# clasts: [('Диаметр грифа, мм', tensor([0.9314]))]
#
#
# clast main: Длина рабочего полотна ножниц, дюймы
# clasts: []
#
#
# clast main: Число лезвий в станке
# clasts: []
#
#
# clast main: Диаметр глобуса, см
# clasts: []
#
#
# clast main: Ширина кисти, мм
# clasts: [('Длина кия, см', tensor([0.9038])), ('Ширина канта, мм', tensor([0.9046]))]
#
#
# clast main: Ширина отделения для тоста, см
# clasts: [('Длина отделения для тоста, см', tensor([0.9654]))]
#
#
# clast main: Число степеней обжаривания
# clasts: []
#
#
# clast main: Год в календарях
# clasts: []
#
#
# clast main: Емкость резервуара для зерен, г
# clasts: []
#
#
# clast main: Диаметр горшка, см
# clasts: [('Диаметр воронки, см', tensor([0.9059])), ('Размер горловины, см', tensor([0.9065]))]
#
#
# clast main: Время работы на полном баке, ч
# clasts: []
#
#
# clast main: Общее количество салфеток, шт
# clasts: []
#
#
# clast main: Диаметр отверстия под свечу, см
# clasts: []
#
#
# clast main: Температура замерзания, °С
# clasts: []
#
#
# clast main: Кол-во гантелей, шт
# clasts: []
#
#
# clast main: Диаметр перекладины, мм
# clasts: [('Длина перекладины, см', tensor([0.9391]))]
#
#
# clast main: Количество точек крепления турника
# clasts: []
#
#
# clast main: Мин. давление струи, кПа
# clasts: [('Макс. давление струи, кПа', tensor([0.9566]))]
#
#
# clast main: Емкость контейнера для воды, мл
# clasts: []
#
#
# clast main: Количество уровней
# clasts: [('Количество граней', tensor([0.9083]))]
#
#
# clast main: Максимальный вес животного, кг
# clasts: []
#
#
# clast main: Диаметр рабочей части вибронаконечника, мм
# clasts: []
#
#
# clast main: Кол-во подключаемых трубок
# clasts: []
#
#
# clast main: Число трубок в комплекте
# clasts: []
#
#
# clast main: Диаметр насоса, мм
# clasts: []
#
#
# clast main: Мощность лодочного мотора, л.с.
# clasts: [('Мощность двигателя, л.с.', tensor([0.9225]))]
#
#
# clast main: Класс износостойкости
# clasts: []
#
#
# clast main: Количество топперов в уп.
# clasts: []
#
#
# clast main: Длина сушильной поверхности , м
# clasts: []
#
#
# clast main: Минимальный ток заряда, А
# clasts: [('Минимальный пусковой ток, А', tensor([0.9367]))]
#
#
# clast main: Кол-во встроенных игр
# clasts: []
#
#
# clast main: Количество лучей
# clasts: []
#
#
# clast main: Макс. вес готового изделия, г
# clasts: []
#
#
# clast main: Количество слотов расширения
# clasts: []
#
#
# clast main: Ширина загрузочного отверстия, мм
# clasts: []
#
#
# clast main: Уровень секретности
# clasts: []
#
#
# clast main: Объем корзины, л
# clasts: [('Количество ванн (корзин), шт.', tensor([0.9062]))]
#
#
# clast main: Количество листов за один раз, шт
# clasts: []
#
#
# clast main: Мин. угол выноса, градусов
# clasts: [('Макс. угол выноса, градусов', tensor([0.9516]))]
#
#
# clast main: Резервуар для сока, л
# clasts: [('Резервуар для мякоти, л', tensor([0.9386]))]
#
#
# clast main: Макс. энергия удара, Дж
# clasts: []
#
#
# clast main: Скорость потока воды, куб.м/ч
# clasts: []
#
#
# clast main: Ширина колодки, мм
# clasts: []
#
#
# clast main: Количество клипс
# clasts: []
#
#
# clast main: Высыхание слоя 2 мм, ч
# clasts: []
#
#
# clast main: Пропускная способность, м³/ч
# clasts: []
#
#
# clast main: Скорость воздушного потока, м/с
# clasts: []
#
#
# clast main: Максимальная скорострельность, мяч/мин
# clasts: [('Минимальная скорострельность, мяч/мин', tensor([0.9078]))]
#
#
# clast main: Время полной зарядки, часов
# clasts: []
#
#
# clast main: Преодолеваемый подъем, °
# clasts: []
#
#
# clast main: Максимальная чувствительность ISO
# clasts: []
#
#
# clast main: Минимальная чувствительность ISO
# clasts: []
#
#
# clast main: Максимальная выдержка, сек
# clasts: [('Минимальная выдержка, сек', tensor([0.9036]))]
#
#
# clast main: Мин. ширина ворот, см
# clasts: []
#
#
# clast main: Расход природного газа, м³/ч
# clasts: [('Минимальный расход газа, м³/ч', tensor([0.9096]))]
#
#
# clast main: Диаметр дымохода, мм
# clasts: []
#
#
# clast main: Количество горшков
# clasts: []
#
#
# clast main: Глубина обработки, см
# clasts: []
#
#
# clast main: Макс. количество порций
# clasts: []
#
#
# clast main: Срок службы, мес
# clasts: []
#
#
# clast main: Количество растений, шт
# clasts: []
#
#
# clast main: Длина иглы, мм
# clasts: [('Диаметр иглы, мм', tensor([0.9624]))]
#
#
# clast main: Мин. длина выноса, мм
# clasts: []
#
#
# clast main: Погрешность, °С
# clasts: [('Погрешность, %', tensor([0.9889]))]
#
#
# clast main: Макс. диаметр завинчиваемых шурупов, мм
# clasts: []
#
#
# clast main: Вес грифа, кг
# clasts: [('Максимальная нагрузка на гриф, кг', tensor([0.9103]))]
#
#
# clast main: Количество тамбуров
# clasts: []
#
#
# clast main: Вес бойка, г
# clasts: []
#
#
# clast main: Размер камня, мм
# clasts: []
#
#
# clast main: Емкость для моющего средства, л
# clasts: []
#
#
# clast main: Максимальная длина палки, см
# clasts: [('Максимальная длина растяжения, см', tensor([0.9284]))]
#
#
# clast main: Объем картриджа/тубы, мл
# clasts: []
#
#
# clast main: Макс. угол наклона столешницы, °
# clasts: [('Максимальный угол наклона, °', tensor([0.9175]))]
#
#
# clast main: Кол-во устанавливаемых дисков
# clasts: []
#
#
# clast main: Кол-во рулонов пластика в комплекте
# clasts: []
#
#
# clast main: Количество дисков, шт.
# clasts: [('Количество дисков', tensor([0.9810]))]
#
#
# clast main: Количество этапов заточки
# clasts: []
#
#
# clast main: Посадочный диаметр вершинки, мм
# clasts: []
#
#
# clast main: Ширина презерватива, мм
# clasts: []
#
#
# clast main: Высота транца, мм
# clasts: []
#
#
# clast main: Количество цилиндров
# clasts: []
#
#
# clast main: Максимальный объем, м3
# clasts: [('Максимальный объем парильни, куб. м', tensor([0.9440]))]
#
#
# clast main: Частота обнаружения, кГц
# clasts: [('Количество частот обнаружения', tensor([0.9561]))]
#
#
# clast main: Число сменных кассет
# clasts: []
#
#
# clast main: Объем станции самоочистки, л
# clasts: []
#
#
# clast main: Ширина пакета, пленки, см
# clasts: []
#
#
# clast main: Шаг регулируемой гантели, кг
# clasts: []
#
#
# clast main: Предельная звёздная величина (разрешение)
# clasts: []
#
#
# clast main: Объем воды, л
# clasts: [('Объем гидробака, л', tensor([0.9284])), ('Объем бака для сливной воды, л', tensor([0.9296])), ('Объем бака для чистой воды, л', tensor([0.9224])), ('Объем бака для грязной воды, л', tensor([0.9167]))]
#
#
# clast main: Длина струны, м
# clasts: [('Диаметр струны, мм', tensor([0.9535]))]
#
#
# clast main: Объем телефонной книги, номеров
# clasts: []
#
#
# clast main: Мин. выходное сопротивление, Ом
# clasts: []
#
#
# clast main: Фокусное расстояние телескопа, мм
# clasts: []
#
#
# clast main: Емкость контейнера для кофе, г
# clasts: []
#
#
# clast main: Класс вязки
# clasts: []
#
#
# clast main: Количество звезд
# clasts: []
#
#
# clast main: Рабочая скорость, м/мин
# clasts: []
#
#
# clast main: Длина в сложенном положении, см
# clasts: []
#
#
# clast main: Количество слоев дерева
# clasts: []
#
#
# clast main: Вес кия, г
# clasts: []
#
#
# clast main: Размер лука, дюймы
# clasts: []
#
#
# clast main: Усиление сигнала UHF, дБ
# clasts: [('Усиление сигнала VHF, дБ', tensor([0.9628]))]
#
#
# clast main: Напряжение катушки управления, В
# clasts: []
#
#
# clast main: Диаметр троса, мм
# clasts: [('Диаметр троса/цепи, мм', tensor([0.9616]))]
#
#
# clast main: Число подвесных игрушек
# clasts: []
#
#
# clast main: Давление, мБар
# clasts: []
#
#
# clast main: Абразивность, грит
# clasts: []
#
#
# clast main: Минимальный уклон, град.
# clasts: []
#
#
# clast main: Длина стрелы, дюймы
# clasts: []
#
#
# clast main: Длина оперения, дюймы
# clasts: []
#
#
# clast main: Макс. сила натяжения, фунты
# clasts: []
#
#
# clast main: Длина стола без подголовника, см
# clasts: []
#
#
# clast main: Классификация по NLGI
# clasts: []
#
#
# clast main: Скорость выстрела, м/с
# clasts: []
#
#
# clast main: Диаметр тарелки, мм
# clasts: []
#
#
# clast main: Размер зерна, мм
# clasts: []
#
#
# clast main: Диаметр отверстия для грифа, мм
# clasts: []
#
#
# clast main: Проба
# clasts: []
#
#
# clast main: Средний вес изделия, гр
# clasts: []
#
#
# clast main: Высота от пола до нижнего положения сиденья, см
# clasts: []
#
#
# clast main: Объем отапливаемого помещения, м³
# clasts: []
#
#
# clast main: Глубина обнаружения монет, см
# clasts: []
#
#
# clast main: Шаг дуги, м
# clasts: []
#
#
# clast main: Радиус действия внутри помещений, м
# clasts: [('Радиус действия на открытом пространстве, м', tensor([0.9270]))]
#
#
# clast main: Количество пробиваемых отверстий
# clasts: []
#
#
# clast main: Количество глазков уровня
# clasts: []
#
#
# clast main: Кол-во плиток на кв.метр
# clasts: []
#
#
# clast main: Количество участников
# clasts: []
#
#
# clast main: Высота стопы, листов
# clasts: []
#
#
# clast main: Концентрация перекиси, %
# clasts: []
#
#
# clast main: Ширина губок, мм
# clasts: []
#
#
# clast main: Ресурс кадров
# clasts: []
#
#
# clast main: Вынос от стены перекладины, см
# clasts: [('Вынос от стены брусьев, см', tensor([0.9384]))]
#
#
# clast main: Количество точек экрана, шт
# clasts: []
#
#
# clast main: Минимальная длина палки, см
# clasts: []
#
#
# clast main: Предел взвешивания, кг
# clasts: []
#
#
# clast main: Знак
# clasts: []
#
#
# clast main: Мин. скорость вращения, об/мин
# clasts: []
#
#
# clast main: Число скоростей эпилятора
# clasts: []
#
#
# clast main: Водонепроницаемость, м
# clasts: []
#
#
# clast main: Высота небесного фонарика, м
# clasts: []
#
#
# clast main: Длительность полета, мин
# clasts: []
#
#
# clast main: Общий угол излучения,°
# clasts: []
#
#
# clast main: Калибр оружия (калибр)
# clasts: []
#
#
# clast main: Максимальный рост ребенка, см
# clasts: []
#
#
# clast main: Макс. диаметр цанги, мм
# clasts: []
#
#
# clast main: Количество воздушных подушек
# clasts: []
#
#
# clast main: Объем ведра, л
# clasts: []
#
#
# clast main: Минимальная толщина слоя, мкм
# clasts: []
#
#
# clast main: Объем воронки, л
# clasts: []
#
#
# clast main: Количество сменных катриджей
# clasts: []
#
#
# clast main: Мин. время измерения, сек
# clasts: []
#
#
# clast main: Вместимость картофельных ломтиков, кг
# clasts: []
#
#
# clast main: Число колыбельных, шт
# clasts: []
#
#
# clast main: Кол-во входных аналоговых каналов, шт.
# clasts: [('Кол-во выходных аналоговых каналов, шт.', tensor([0.9333]))]
#
#
# clast main: Длина щупа, см
# clasts: []
#
#
# clast main: Макс. высота ружей, см
# clasts: []
#
#
# clast main: Макс. кол-во стволов
# clasts: []
#
#
# clast main: Минимальный объем парильни, куб. м
# clasts: []
#
#
# clast main: Максимальный вес камней, кг
# clasts: []
#
#
# clast main: Рейтинг ADAC от 0.5 до 5.5
# clasts: []
#
#
# clast main: Количество горячих клавиш
# clasts: []
#
#
# clast main: Количество линий на дюйм, lpi
# clasts: []
#
#
# clast main: Точность пера, мм
# clasts: []
#
#
# clast main: Макс. угол наклона пера, °
# clasts: []
#
#
# clast main: Охлаждение ниже окр. среды, °С
# clasts: []
#
#
# clast main: Макс. расход воды на 1 кг сухой смеси, л
# clasts: []
#
#
# clast main: Вес шара, г
# clasts: []
#
#
# clast main: Диаметр рулевого колеса, см
# clasts: []
#
#
# clast main: Обхват груди манекена, см
# clasts: []
#
#
# clast main: Обхват бедер, см
# clasts: []
#
#
# clast main: Объем готового раствора, л
# clasts: []
#
#
# clast main: Мощность тыловых колонок, Вт
# clasts: []
#
#
# clast main: Толщина топки над огнем, мм
# clasts: []
#
#
# clast main: Глубина строгания (рейсмус), мм
# clasts: []
#
#
# clast main: Глубина строгания (фуганок), мм
# clasts: []
#
#
# clast main: Число оттенков серого
# clasts: []
#
#
# clast main: Пиковый сброс, л
# clasts: [('Залповый сброс, л', tensor([0.9358]))]
#
#
# clast main: Размер противогаза
# clasts: []
#
#
# clast main: Объем емкости для молока, мл
# clasts: []
#
#
# clast main: Акустическая эффективность (SNR), дБ
# clasts: []
#
#
# clast main: Крепость, %
# clasts: []
#
#
# clast main: Класс рукава
# clasts: []
#
#
# clast main: Кол-во язычков
# clasts: []
#
#
# clast main: Фасовка, гр
# clasts: []
#
#
# clast main: Объем одной ванны, л
# clasts: []
#
#
# clast main: Время корректировки плитки, мин
# clasts: []
#
#
# clast main: Длина гидроуровня, м
# clasts: []
#
#
# clast main: Вес теста, кг
# clasts: []
#
#
# clast main: Количество уровней толщины теста
# clasts: []
#
#
# clast main: Общее кол-во бигуди
# clasts: []
#
#
# clast main: Прочность на сжатие, МПа
# clasts: []
#
#
# clast main: Наибольшее усиление звука, дБ
# clasts: []
#
#
# clast main: Процент обеззараживания
# clasts: []
#
#
# clast main: Диаметр арматуры, мм
# clasts: []
#
#
# clast main: Время работы, число страниц
# clasts: []
#
#
# clast main: Этажи
# clasts: []
#
#
# clast main: Объем одного кормового резервуара, мл
# clasts: []
#
#
# clast main: Вместимость ротора, шт.
# clasts: []
#
#
# clast main: Угол наклона спинки, °
# clasts: []
#
#
# clast main: Норма слойности
# clasts: []
#
#
# clast main: Площадь обработки, см.кв.
# clasts: []
#
#
# clast main: Длина хода клавиш, мм
# clasts: []
#
#
# clast main: Максимальный диаметр ствола ели, см
# clasts: [('Максимальная высота ели, м', tensor([0.9069]))]
#
#
# clast main: Количество SIP-аккаунтов
# clasts: []
#
#
# clast main: Количество абонентов на конференции
# clasts: []
#
#
# clast main: Номинал
# clasts: []
#
#
# clast main: Год изготовления
# clasts: []
#
#
# clast main: Размер, футы
# clasts: []
#
#
# clast main: Макс. глубина обнаружения дерева, мм
# clasts: []
#
#
# clast main: Ширина ступени, см
# clasts: []
#
#
# clast main: Количество мест в лодке
# clasts: []
#
#
# clast main: Паропроницаемость, г/м² в сутки
# clasts: []
#
#
# clast main: Число дисплеев/табло в комплекте, шт.
# clasts: []
#
#
# clast main: Тепловая мощность, кВт
# clasts: []
#
#
# clast main: Площадь тушения, м²
# clasts: []
#
#
# clast main: Вращение мяча
# clasts: []
#
#
# clast main: Высота язычка, мм
# clasts: []
#
#
# clast main: Год урожая
# clasts: []
#
#
# clast main: Выработка хлора г/ч
# clasts: []
#
#
# clast main: Калибр иглы, G
# clasts: []
#
#
# clast main: Кол-во приготовляемых порций
# clasts: []
#
#
# clast main: Длина украшения, см
# clasts: []
#
#
# clast main: Защищаемый объем, л
# clasts: []
#
#
# clast main: Адгезия, МПа
# clasts: []
#
#
# clast main: Размер стола
# clasts: []
#
#
# clast main: Размер инвалидной коляски для животных
# clasts: []
#
#
# clast main: Длина платформы, см
# clasts: []
#
#
# clast main: Плотность блоттера, г/м2
# clasts: []

# %%
num_clast_distribution["Длина шампура, см"]
# Out:
# 6

# %% [markdown]
# Теперь то же самое но с числовыми

# %%
sent_attr = list(filter(lambda x: not x[1][0], zip(uniq_attr.keys(),uniq_attr.values())))
sent_attr
# Out:
# [('Цвет товара', (False, ['бежевый', 'светло-розовый'])),
#  ('Пол ребенка', (False, ['Унисекс'])),
#  ('Бренд', (False, ['Funny Ducks'])),
#  ('Тип', (False, ['Игрушка для ванной'])),
#  ('Страна-изготовитель', (False, ['Китай'])),
#  ('Развитие навыков', (False, ['Воображение', 'Кругозор', 'Моторика'])),
#  ('Код ТРУ', (False, [''])),
#  ('Минимальный возраст ребенка', (False, ['От 3 лет'])),
#  ('Материал', (False, ['ПВХ пластизоль'])),
#  ('Вес товара, г', (False, ['подвесная люстра (лампа не в комплекте)'])),
#  ('Максимальный возраст ребенка', (False, ['До 18 лет'])),
#  ('Количество в упаковке, шт', (False, ['with a charging case'])),
#  ('Материалы набора',
#   (False, ['Акрил', 'Бумага', 'Канва', 'Металл', 'Хлопок'])),
#  ('Техника вышивки', (False, ['Простой крест'])),
#  ('Возрастные ограничения', (False, ['От 7 лет'])),
#  ('Длина по горизонтали, см', (False, ['200 мм'])),
#  ('Длина по вертикали, см', (False, ['200 мм'])),
#  ('Размеры, мм', (False, ['400 х 400'])),
#  ('Ширина, см', (False, ['29 см'])),
#  ('Состав ниток', (False, ['Ткань'])),
#  ('Длина, м', (False, ['1 м Безэкранный'])),
#  ('Название цвета', (False, ['мультиколор'])),
#  ('Минимальная продолжительность партии, мин.', (False, ['30 минут'])),
#  ('Минимальное число игроков', (False, ['2 - 4 игрока'])),
#  ('Максимальное число игроков', (False, ['2 - 4 игрока'])),
#  ('Вид выпуска товара', (False, ['Фабричное производство'])),
#  ('Целевая аудитория', (False, ['Детская'])),
#  ('Вид настольной игры', (False, ['Башни и пирамиды'])),
#  ('Целевая аудитория игры', (False, ['Для компании'])),
#  ('Артикул', (False, ['ОШО 4 - 3 Л'])),
#  ('Вес, кг', (False, ['Механическое'])),
#  ('Размерность', (False, ['200x220'])),
#  ('Материал чехла', (False, ['Поликоттон'])),
#  ('Материал наполнителя', (False, ['Шерсть'])),
#  ('Технология пошива', (False, ['Стеганое'])),
#  ('Комплектация', (False, ['- чайник, 900 мл\n- коробка, картон'])),
#  ('Объем, мл', (False, ['300 мл'])),
#  ('Фильтр', (False, ['Механизм «Гунфу»'])),
#  ('Тип цоколя', (False, ['E14'])),
#  ('Вид ламп', (False, ['Накаливания'])),
#  ('Количество ламп, шт',
#   (False, ['Лампа 12V W16W 16W W2,1x9,5d LYNXauto 1 шт. картон L12816'])),
#  ('Макс. мощность ламп, Вт', (False, ['12W'])),
#  ('Материал плафона', (False, ['Ткань'])),
#  ('Вид питания', (False, ['От сети 220В'])),
#  ('Цвет плафона', (False, ['Бронза'])),
#  ('Площадь освещения, кв.м', (False, ['15-25'])),
#  ('Тип выключателя', (False, ['Механический'])),
#  ('Партномер', (False, ['1274-3T'])),
#  ('Состав',
#   (False,
#    ['5-15% Anionic Surfactants, <5% Non-Ionic Surfactants, Oxygen-Based Bleaching Agents, Phosphonates, Polycarboxylates, Zeolites, Enzymes, Optical Brighteners, Perfumes'])),
#  ('Упаковка', (False, ['Пластиковая коробка'])),
#  ('Назначение средства для стирки', (False, ['Для цветных тканей'])),
#  ('Название аромата', (False, ['Свежий'])),
#  ('Аромат', (False, ['Свежий'])),
#  ('Размер упаковки (Длина х Ширина х Высота), см', (False, ['25 x 22 x 8'])),
#  ('Вид стирки', (False, ['Автоматическая', 'Ручная'])),
#  ('Форма выпуска средства', (False, ['Порошок'])),
#  ('Особенности применения', (False, ['Гипоаллергенность', 'Концентрат'])),
#  ('Единиц в одном товаре', (False, ['взимание денег'])),
#  ('Число стирок', (False, ['18 стирок'])),
#  ('Размерность комплекта', (False, ['2-x спальный'])),
#  ('Гарантийный срок', (False, ['до 200 стирок'])),
#  ('Отделка', (False, ['Без отделки'])),
#  ('Застежка пододеяльника', (False, ['с прорезью'])),
#  ('Название материала', (False, ['Перкаль'])),
#  ('Застежка наволочки/чехла', (False, ['с клапаном'])),
#  ('Образец цвета',
#   (False, ['https://cdn1.ozone.ru/s3/multimedia-v/6234336667.jpg'])),
#  ('Размер простыни', (False, ['195x220'])),
#  ('Состав материала', (False, ['Хлопок'])),
#  ('Размер наволочки', (False, ['70x70'])),
#  ('Размер пододеяльника', (False, ['185x215'])),
#  ('Комплектация постельного белья',
#   (False, ['1 пододеяльник, 1 простыня, 2 наволочки'])),
#  ('Режим стирки', (False, ['При 40 градусах'])),
#  ('Вид простыни', (False, ['стандартная'])),
#  ('Размер крышки, см', (False, ['26х26'])),
#  ('Совместимые плиты',
#   (False,
#    ['Для газовых плит',
#     'Для галогеновых конфорок',
#     'Для индукционных плит',
#     'Для стеклокерамических плит',
#     'Для электрических плит'])),
#  ('Крышка', (False, ['с крышкой'])),
#  ('Особенности посуды', (False, ['Крышка в комплекте'])),
#  ('Диаметр дна, см',
#   (False, ['Бежевый лягушка завтрак горшок (газ) скребок масляная щетка'])),
#  ('Помещение',
#   (False,
#    ['Для балкона',
#     'Для гостиной',
#     'Для коридора/прихожей',
#     'Для офиса/кабинета'])),
#  ('Тип помещения',
#   (False, ['С повышенной влажностью', 'С умеренной влажностью', 'Сухое'])),
#  ('Марка эмали', (False, ['МА-15'])),
#  ('Количество компонентов', (False, ['Однокомпонентная'])),
#  ('Возможность колеровки', (False, ['Нет'])),
#  ('Степень блеска покрытия', (False, ['Глянцевое покрытие'])),
#  ('Время высыхания, часов', (False, ['24 ч'])),
#  ('Основа краски', (False, ['Масляная'])),
#  ('Область применения состава',
#   (False,
#    ['Для беседок', 'Для дверей', 'Для дерева', 'Для заборов', 'Для металла'])),
#  ('Назначение', (False, ['Декоративное', 'Защита от износа', 'Упрочнение'])),
#  ('Работы', (False, ['Внутренние', 'Наружные'])),
#  ('Можно мыть', (False, ['Да'])),
#  ('Вид краски', (False, ['Быстросохнущая', 'Гладкая'])),
#  ('Способ нанесения', (False, ['Валик', 'Кисть', 'Краскопульт'])),
#  ('Объем, л', (False, ['новый L6 белый трехрежимный 12L'])),
#  ('Расход, л/м2', (False, ['12 м²/л'])),
#  ('Аэрозоль', (False, ['Нет'])),
#  ('Тип растворителя', (False, ['Сольвент', 'Уайт-спирит'])),
#  ('Материал основания', (False, ['ДВП', 'ДСП', 'Дерево', 'Металл', 'Фанера'])),
#  ('Вид шампура', (False, ['Палочки'])),
#  ('Материал рукояти', (False, ['Дерево'])),
#  ('Вибрация', (False, ['Без вибрации'])),
#  ('Состав комплекта', (False, ['Фиксатор для запястий и лодыжек'])),
#  ('Размер БДСМ-атрибутики', (False, ['Универсальный'])),
#  ('Пол', (False, ['Для нее'])),
#  ('Назначение товара 18+', (False, ['Для БДСМ', 'Для ролевых игр'])),
#  ('Размер секс-игрушек', (False, ['Medium: 13-20 см'])),
#  ('Длина, см', (False, ['30*40*2 60*40*1'])),
#  ('Тип мастурбатора', (False, ['Вагина'])),
#  ('Вид насадки', (False, ['На член'])),
#  ('Ширина/диаметр, мм', (False, ['2-3.4'])),
#  ('Особенности 18+', (False, ['Для массажа простаты'])),
#  ('Вид стимулятора', (False, ['Классический', 'Реалистичный'])),
#  ('Количество внешних карманов', (False, ['2 шт.'])),
#  ('Количество внутренних отделений', (False, ['1 шт.'])),
#  ('Внешние размеры, мм', (False, ['370x470'])),
#  ('Консистенция краски/клея', (False, ['Масляная'])),
#  ('Цветовые эффекты', (False, ['Классическая'])),
#  ('Форма выпуска краски', (False, ['Поштучно'])),
#  ('Вид ручки', (False, ['Шариковая'])),
#  ('Цвет чернил', (False, ['Синий'])),
#  ('Толщина линии, мм', (False, ['0.3-0.5'])),
#  ('Плотность, г/м2', (False, ['80 г'])),
#  ('Формат', (False, ['A1 (59.4 × 84.1 см)'])),
#  ('Размер одежды/аксессуара для животных', (False, ['XL'])),
#  ('Сезон', (False, ['Демисезон'])),
#  ('Особенности одежды, обуви', (False, ['С капюшоном', 'Со стяжкой'])),
#  ('Размер животного', (False, ['Малый'])),
#  ('Вид одежды', (False, ['Комбинезон'])),
#  ('Предназначено для', (False, ['Для собак'])),
#  ('Содержание мяса, субпродуктов, %',
#   (False,
#    ['мясо и продукты переработки мяса (из которыхтелятина мин. 4%). рыба и продукты переработки рыбы. минеральные вещества. аминокислоты, продукты переработки растительного сырья, сахара, витамины, загустители, консерванты.'])),
#  ('Особенности',
#   (False,
#    ['Без ГМО', 'Без искусственных консервантов', 'Без усилителей вкуса'])),
#  ('Порода собаки', (False, ['Для любой породы'])),
#  ('Основной ингредиент', (False, ['Мясо'])),
#  ('Возраст животного', (False, ['Для маленьких'])),
#  ('Особые потребности', (False, ['Гиперактивные'])),
#  ('Вкус корма для животных', (False, ['Субпродукты', 'Язык'])),
#  ('Консистенция корма для животных', (False, ['Фарш'])),
#  ('Условия хранения', (False, ['При температуре до +25`C'])),
#  ('Упаковка консервированных кормов', (False, ['Консервная банка'])),
#  ('Минеральные вещества', (False, ['фосфор, кальций'])),
#  ('Класс корма', (False, ['Супер-премиум'])),
#  ('Длина большей стороны, см', (False, ['24 см'])),
#  ('Длина меньшей стороны, см', (False, ['24 см'])),
#  ('Наполнитель лежака/домика для животных', (False, ['Алюминий', 'Полиэфир'])),
#  ('Форма выпуска корма', (False, ['Гранулы'])),
#  ('Страна бренда', (False, ['Россия'])),
#  ('Материал подошвы обуви', (False, ['ПВХ (поливинилхлорид)'])),
#  ('Вид каблука', (False, ['Без каблука'])),
#  ('Материал стельки', (False, ['Искусственные материалы'])),
#  ('Российский размер (обуви)', (False, ['37,5'])),
#  ('Полнота', (False, ['F'])),
#  ('Вид застёжки', (False, ['Шнурки'])),
#  ('Особенности модели', (False, ['Низкая модель'])),
#  ('Внутренний материал', (False, ['Байка'])),
#  ('Посадка', (False, ['Нормальная'])),
#  ('Спортивное назначение', (False, ['Спортивная ходьба'])),
#  ('Материал верха', (False, ['Текстиль'])),
#  ('Коллекция', (False, ['Весна-лето 2022'])),
#  ('Размер производителя', (False, ['T11'])),
#  ('Бренд в одежде и обуви', (False, ['Jovinni Rossi'])),
#  ('Праздник',
#   (False,
#    ['14 февраля',
#     '8 марта',
#     'Gender Reveal Party',
#     'День рождения',
#     'Свадьба',
#     'Универсальный'])),
#  ('Эффект от использования уходовой косметики', (False, ['Питание'])),
#  ('Применение', (False, ['От пигментации', 'От покраснений'])),
#  ('Тип кожи', (False, ['Для всех типов кожи'])),
#  ('Область использования', (False, ['Область вокруг глаз'])),
#  ('Способ применения',
#   (False,
#    ['Крем наносится на кожу вокруг глаз 1-3 раза в день (в удобное время), отступив от реснитчатого края нижнего века не менее 1 мм. Дополнительно рекомендуем использовать для ухода за кожей гель "Система Гиалуроновых кислот 1800 мДа-0.8 кДа" (есть три разновидности), крем "Многофакторный Восстановитель кожи" и маску-крем "Система гиалуроновых кислот и витаминов"'])),
#  ('Особенности состава',
#   (False,
#    ['Аптечная косметика',
#     'Без аммиака',
#     'Без дибутилфталата',
#     'Без камфоры',
#     'Без минеральных масел',
#     'Без отдушек',
#     'Без парабенов',
#     'Без спирта',
#     'Без сульфатов',
#     'Без толуола',
#     'Без формальдегида',
#     'Без фтора',
#     'Гипоаллергенная',
#     'Не комедогенна',
#     'Не тестируется на животных',
#     'Органическая косметика',
#     'Подходит для ежедневного применения'])),
#  ('Возрастной диапазон', (False, ['от 20 лет'])),
#  ('Эффект', (False, ['Окрашивание'])),
#  ('Тип волос', (False, ['Для всех типов волос'])),
#  ('Вес, г', (False, ['указан на упаковке.'])),
#  ('Вид средства для ухода', (False, ['пенка'])),
#  ('Бьюти-ингредиент', (False, ['Гиалуроновая кислота', 'Глицерин'])),
#  ('Основной материал', (False, ['Пластик'])),
#  ('Материал щетины', (False, ['Искусственная щетина'])),
#  ('Вид парикмахерской расчески', (False, ['Для стрижки классическая'])),
#  ('Дней до замены', (False, ['1 день'])),
#  ('Режим ношения', (False, ['Дневной'])),
#  ('Диаметр, мм', (False, ['4.0mm'])),
#  ('Количество в упаковке', (False, ['Touchpad'])),
#  ('Особенности контактных линз',
#   (False,
#    ['Безопасный край линзы',
#     'Силикон-гидрогель',
#     'Сферический дизайн',
#     'УФ-фильтр'])),
#  ('Материал контактных линз', (False, ['Нарафилкон А'])),
#  ('Кислородопропускание, Dk/t', (False, ['113,75'])),
#  ('Основа состава', (False, ['Водная'])),
#  ('Эффект интимного средства', (False, ['Возбуждающий'])),
#  ('Признак 18+', (False, ['false'])),
#  ('Уровень шума (при работе), дБ', (False, ['33 дБ'])),
#  ('Вид ингалятора', (False, ['Компрессорный (струйный)'])),
#  ('Мин. размер частиц, мкм', (False, ['0,5'])),
#  ('Скорость ингаляции, мл/мин', (False, ['0,2'])),
#  ('Вид средства для обуви/одежды', (False, ['Крем'])),
#  ('Для каких материалов',
#   (False, ['Искусственная кожа', 'Кожа с покрытием', 'Натуральная кожа'])),
#  ('Эффект от использования', (False, ['Защита'])),
#  ('Тип застежки', (False, ['Молния'])),
#  ('Размер рюкзака', (False, ['Маленький (до 20 л.)'])),
#  ('Вид рюкзака', (False, ['Городской'])),
#  ('Ручки', (False, ['Широкие лямки'])),
#  ('Особенности конструкции сумки', (False, ['Петля для подвешивания'])),
#  ('Материал подкладки', (False, ['Полиэстер'])),
#  ('Фактура материала', (False, ['Махровая'])),
#  ('Размер, см', (False, ['70x130'])),
#  ('Вид принта', (False, ['Животные'])),
#  ('Материал корпуса', (False, ['Пластик'])),
#  ('Длина шнура, м', (False, ['1.8 м'])),
#  ('Системы защиты', (False, ['Защита от перегрева'])),
#  ('Материал чаши', (False, ['Металл'])),
#  ('Планетарный механизм', (False, ['Да'])),
#  ('Тип миксера', (False, ['Планетарный'])),
#  ('Режимы работы', (False, ['Импульсный режим'])),
#  ('Вращающаяся чаша', (False, ['Нет'])),
#  ('Количество скоростей', (False, ['750*285*200'])),
#  ('Турборежим', (False, ['Нет'])),
#  ('Насадки приборов для измельчения продуктов',
#   (False, ['Венчик', 'Для замешивания теста'])),
#  ('Функциональные особенности', (False, ['Плавное изменение скорости'])),
#  ('Конструктивные особенности',
#   (False, ['Защитная крышка', 'Прорезиненные ножки'])),
#  ('Мощность, Вт', (False, ['2х200'])),
#  ('Индикация и сигналы', (False, ['Индикация включения'])),
#  ('Конструктивные особенности тепловых приборов',
#   (False, ['Антипригарное покрытие'])),
#  ('Количество в упаковке, шт.', (False, ['39447|1'])),
#  ('Назначение держателя для кухни', (False, ['для губки, мыла'])),
#  ('Высота, см', (False, ['R \xa0Длинная 250X\xa0высота 134CM'])),
#  ('Крепление держателя для кухни', (False, ['ручное (без крепления)'])),
#  ('Конструкция чайника',
#   (False,
#    ['Индикатор уровня воды', 'Светоиндикатор работы', 'Фильтр от накипи'])),
#  ('Тип управления', (False, ['Механическое'])),
#  ('Внутреннее покрытие бака', (False, ['Эмаль'])),
#  ('Максимальная мощность, кВт', (False, ['0.7/1.3/2 кВт'])),
#  ('Размеры, мм (ШхГхВ)', (False, ['450x450x563'])),
#  ('Объем бака (номинальный), л', (False, ['50 л'])),
#  ('Макс. температура, °С', (False, ['до 75 °C'])),
#  ('Установка водонагревателя', (False, ['Вертикальная'])),
#  ('Форма бака', (False, ['Округлая'])),
#  ('Система управления', (False, ['Независимая'])),
#  ('Количество температурных режимов', (False, ['от 120 до 200°C'])),
#  ('Дополнительные режимы',
#   (False,
#    ['Автоматическое вращение насадки', 'Ионизация', 'Холодный воздух'])),
#  ('Предназначение', (False, ['Бытовое'])),
#  ('Диаметр насадки', (False, ['50 мм'])),
#  ('Насадки для приборов по уходу за волосами', (False, ['Круглая щетка'])),
#  ('Особенности фена, выпрямителя волос',
#   (False,
#    ['Вращение шнура 360°', 'Защита от перегрева', 'Петля для подвешивания'])),
#  ('Макс. мощность, Вт', (False, ['1200 вт'])),
#  ('Программы приготовления', (False, ['Подогрев', 'Разморозка', 'Разогрев'])),
#  ('Направление открывания дверцы', (False, ['Навесная с открытием налево'])),
#  ('Технология СВЧ', (False, ['С поворотным столом'])),
#  ('Открывание дверцы микроволновой печи', (False, ['Ручка'])),
#  ('Макс. мощность гриля, Вт', (False, [' '])),
#  ('Диаметр поворотного стола, см', (False, ['245 РјРј'])),
#  ('Расположение', (False, ['Отдельностоящая'])),
#  ('Глубина, см', (False, ['30.5-42.5'])),
#  ('Режимы работы микроволновой печи', (False, ['С грилем', 'Соло'])),
#  ('Управление', (False, ['Механическое'])),
#  ('Внутреннее покрытие микроволновой печи', (False, ['Эмалевое'])),
#  ('Особенности микроволновой печи', (False, ['Таймер', 'Часы'])),
#  ('Макс. уровень шума, дБ',
#   (False, ['46/53/68 на 1-2-3-й ступенях соответственно'])),
#  ('Доп. принадлежности ПММ', (False, ['Корзина для столовых приборов'])),
#  ('Инверторный двигатель', (False, ['Нет'])),
#  ('Размер (ДхШхВ), см', (False, ['44.8х81.5х55'])),
#  ('Вид посудомоечной машины', (False, ['Узкая (45 см)'])),
#  ('Класс энергопотребления', (False, ['A++'])),
#  ('Класс мойки', (False, ['A'])),
#  ('Класс сушки', (False, ['A+'])),
#  ('Программы мойки',
#   (False,
#    ['90 минут',
#     'Быстрая',
#     'Деликатная/стекло',
#     'Интенсивная',
#     'Стандартная',
#     'Экономичная'])),
#  ('Расход энергии за цикл, кВт', (False, ['0. 75'])),
#  ('Отложенный старт, ч', (False, ['Нет'])),
#  ('Индикация',
#   (False, ['Наличие ополаскивателя', 'Наличие соли', 'Неисправность'])),
#  ('Тип сушки', (False, ['Конденсационная'])),
#  ('Функционал посудомоечной машины',
#   (False,
#    ['Быстрая мойка',
#     'Возможность добавления посуды после запуска',
#     'Деликатная мойка',
#     'Интенсивная мойка',
#     'Использование средств 3-в-1',
#     'Отсрочка запуска',
#     'Половинная загрузка'])),
#  ('Особенности посудомоечной машины',
#   (False, ['Поддон для столовых приборов'])),
#  ('Назначение чехла для мебели', (False, ['для стула'])),
#  ('Стиль', (False, ['Повседневное', 'Праздничное', 'Спорт'])),
#  ('Вид сумки', (False, ['шоппер'])),
#  ('Формат А4', (False, ['вмещает'])),
#  ('Высота ручек, см', (False, ['40 см'])),
#  ('Длина плечевого ремня, см', (False, ['130 см'])),
#  ('Форма поставки матраса', (False, ['В рулоне'])),
#  ('Комната', (False, ['Спальня'])),
#  ('Минимальная жесткость', (False, ['Мягкий'])),
#  ('Максимальная жесткость', (False, ['Полужесткий'])),
#  ('Вид пружинного блока', (False, ['Независимые пружины'])),
#  ('Конструкция матраса', (False, ['Независимые пружины'])),
#  ('Вид матраса', (False, ['Анатомический'])),
#  ('Вид', (False, ['Двусторонний с разной жесткостью'])),
#  ('Особенности матраса', (False, ['Эффект памяти'])),
#  ('Информация о размерах', (False, ['Маломерят на размер'])),
#  ('Высота подошвы, см', (False, ['Полиуретан'])),
#  ('Серия в одежде и обуви', (False, ['Фламинго'])),
#  ('Максимальная температура', (False, ['25,0'])),
#  ('Минимальная температура', (False, ['0,0'])),
#  ('Вид соуса', (False, ['Терияки'])),
#  ('Степень остроты', (False, ['Неострый'])),
#  ('Назначение масла/соуса', (False, ['Для морепродуктов', 'Для мяса'])),
#  ('Название вкуса', (False, ['Crema'])),
#  ('Степень обжарки', (False, ['Средняя'])),
#  ('Интенсивность вкуса', (False, ['Мягкий'])),
#  ('Способ приготовления кофе',
#   (False, ['В чашке', 'Капельная кофеварка', 'Турка', 'Френч-пресс'])),
#  ('Степень помола', (False, ['Средний'])),
#  ('Состав кофе', (False, ['Арабика/Робуста'])),
#  ('Вид шоколада', (False, ['Темный'])),
#  ('Не содержит', (False, ['Без сахара'])),
#  ('Особенности напитков, продуктов питания',
#   (False, ['Биопродукт', 'Диетический продукт'])),
#  ('Вид лапши', (False, ['Рамен'])),
#  ('Амортизация', (False, ['нет'])),
#  ('Класс тренажера', (False, ['Домашний'])),
#  ('Питание тренажера', (False, ['Сеть 220 Вольт'])),
#  ('Особенности тренажеров', (False, ['Транспортировочные ролики'])),
#  ('Измерительные датчики', (False, ['Дистанция'])),
#  ('Российский размер', (False, ['56-182'])),
#  ('Рост', (False, ['165-170'])),
#  ('Тип упаковки одежды', (False, ['Пакет'])),
#  ('Инструкция по уходу', (False, ['бережная стирка при 30 градусах'])),
#  ('Рост модели на фото', (False, ['173 см'])),
#  ('Размер на модели', (False, ['50-52'])),
#  ('Рисунок', (False, ['Однотонный'])),
#  ('Цель', (False, ['Красота и здоровье', 'Набор мышечной массы'])),
#  ('Вид протеина', (False, ['Сывороточный'])),
#  ('Форма выпуска спортивного питания', (False, ['Порошок'])),
#  ('Энергетическая ценность: ккал в 1 порции', (False, ['188-200'])),
#  ('Белок: грамм в 1 порции', (False, ['3-3.5'])),
#  ('Жиры: грамм в 1 порции', (False, ['1.5-2'])),
#  ('Углеводы: грамм в 1 порции', (False, ['27.5-29'])),
#  ('Формат (типоразмер) элементов питания',
#   (False, ['Батареи/аккумуляторы тип AA'])),
#  ('Степень защиты от влаги и пыли', (False, ['IP44'])),
#  ('Оттенок света', (False, ['Холодный белый'])),
#  ('Комплектация элементом питания', (False, ['Не входит в комплект'])),
#  ('Комплектация зарядным устройством',
#   (False, ['Не комплектуется зарядным устройством'])),
#  ('Особенности фонаря', (False, ['Регулировка угла наклона'])),
#  ('Назначение сноуборда', (False, ['Универсальный'])),
#  ('Жесткость', (False, ['Средняя'])),
#  ('Тип крепления сноуборда', (False, ['Классические'])),
#  ('Модельный год', (False, ['2020-21'])),
#  ('Назначение боксёрских перчаток', (False, ['Тренировочные'])),
#  ('Тип застёжки', (False, ['Липучка'])),
#  ('Вид спорта', (False, ['Футбол'])),
#  ('Длина рукава', (False, ['Длинный'])),
#  ('Модель', (False, ['прямая', 'свободная модель'])),
#  ('Длина изделия, см', (False, ['45-65'])),
#  ('Декоративные элементы', (False, ['Воротник', 'Разрезы'])),
#  ('Количество слоев', (False, ['2 слоя'])),
#  ('Система', (False, ['T4'])),
#  ('Количество пар в упаковке', (False, ['3 пары'])),
#  ('Защита от влаги', (False, ['Нет'])),
#  ('Конструкция наушников', (False, ['Вкладыши'])),
#  ('True Wireless', (False, ['false'])),
#  ('Крепление наушников', (False, ['В ушной раковине'])),
#  ('Спортивные', (False, ['Нет'])),
#  ('Способ передачи звука', (False, ['Динамики'])),
#  ('Складные', (False, ['false'])),
#  ('Управление наушниками', (False, ['Кнопочное'])),
#  ('Мин. частота, Гц', (False, ['200\xa0Гц'])),
#  ('Макс. частота, Гц', (False, ['20 000\xa0Гц'])),
#  ('Подключение', (False, ['Проводное'])),
#  ('Импеданс, Ом', (False, ['4+4'])),
#  ('Акустическое оформление', (False, ['Закрытое'])),
#  ('Разъем', (False, ['3.5 мм'])),
#  ('Длина кабеля, см', (False, ['1.3 м'])),
#  ('Опции управления', (False, ['Регулировка громкости'])),
#  ('Материал амбушюров', (False, ['Силикон'])),
#  ('Шумоподавление', (False, ['Пассивное'])),
#  ('Наличие микрофона', (False, ['Да'])),
#  ('Крепление', (False, ['Подвесное'])),
#  ('Высота, мм', (False, ['58.928\xa0мм'])),
#  ('Длина, мм', (False, ['160/100'])),
#  ('Ширина, мм', (False, ['245.11\xa0мм'])),
#  ('Степень защиты', (False, ['IP20'])),
#  ('Защищенность', (False, ['Без защиты'])),
#  ('Форма', (False, ['Нестандартная'])),
#  ('Напряжение питания, В', (False, ['220-240В'])),
#  ('Гарантия', (False, ['18 месяцев'])),
#  ('Тип крепления', (False, ['Планка'])),
#  ('Сертификат', (False, ['ЯНАО'])),
#  ('Вид шапки', (False, ['Бини'])),
#  ('Материал подклада/внутренней отделки', (False, ['Флис'])),
#  ('Световой поток, Лм', (False, ['8 000'])),
#  ('Диаметр воздуховода, мм', (False, ['150 см'])),
#  ('Вентиляция', (False, ['Приточно-вытяжная'])),
#  ('Форма воздуховода', (False, ['Круг'])),
#  ('Установка вентиляции', (False, ['Канальный'])),
#  ('Вид комплектующего для вентиляции', (False, ['Гибкий воздуховод'])),
#  ('Количество фаз электростанции', (False, ['Одна'])),
#  ('Форма рукояти', (False, ['Г-образная'])),
#  ('Назначение мебельной фурнитуры', (False, ['Для основания кровати'])),
#  ('Макс. нагрузка, кг', (False, ['до 150 кг'])),
#  ('Вид ключа', (False, ['Рожковый'])),
#  ('Крыло', (False, ['Правое'])),
#  ('Покрытие', (False, ['Матовое'])),
#  ('Отверстия под смеситель', (False, ['Без отверстий'])),
#  ('Толщина стенок, мм', (False, ['1,5'])),
#  ('Клапан-автомат', (False, ['Нет'])),
#  ('Форма мойки', (False, ['Прямоугольник'])),
#  ('Установка', (False, ['Накладная'])),
#  ('Минимальный размер тумбы', (False, ['80 см'])),
#  ('Год выпуска', (False, ['12/1/1998'])),
#  ('Количество страниц', (False, ['Печатная книга'])),
#  ('Тип книги', (False, ['Печатная книга'])),
#  ('Формат издания', (False, ['140x210'])),
#  ('Автор на обложке', (False, ['Блеквуд Даниэлла'])),
#  ('Издательство', (False, ['ИГ "Весь"'])),
#  ('ISBN', (False, ['978-5-98995-104-8, 978-0-7494-7057-9'])),
#  ('Автор', (False, ['Блеквуд Даниэлла'])),
#  ('Тип обложки', (False, ['Твердый переплет'])),
#  ('Язык издания', (False, ['Русский'])),
#  ('Комментарий', (False, ['Книга-комикс.'])),
#  ('Основной жанр книги', (False, ['Комиксы'])),
#  ('Тираж', (False, ['Печатная книга'])),
#  ('Оригинальное название',
#   (False,
#    ['Coaching Presence: Building Consciousness and Awareness in Coaching Interventions'])),
#  ('Установка бассейна', (False, ['Наземный'])),
#  ('Фильтр водяного насоса', (False, ['Картриджный'])),
#  ('Особенности и комплектация бассейнов', (False, ['Лестница', 'Фильтр'])),
#  ('Надувное дно', (False, ['Нет'])),
#  ('Вид бассейна', (False, ['Каркасный'])),
#  ('Форма бассейна', (False, ['Прямоугольник'])),
#  ('Объем, Л', (False, ['4,5 л'])),
#  ('Антипригарное покрытие', (False, ['Да'])),
#  ('Объем главного отделения, л', (False, ['30 л'])),
#  ('Специальные отделения',
#   (False,
#    ['Боковой карман для бутылки воды',
#     'Отделение для аксессуаров',
#     'Отделение-органайзер'])),
#  ('Вид запчасти', (False, ['Кнопки'])),
#  ('Толщина наматрасника, см', (False, ['30 см'])),
#  ('Непромокаемый наматрасник', (False, ['Да'])),
#  ('Крепление наматрасника', (False, ['с резинкой по периметру'])),
#  ('Назначение спецодежды',
#   (False, ['Для работников производства', 'Для слесарных работ'])),
#  ('Назначение горных лыж', (False, ['Универсальные'])),
#  ('Серия', (False, ['Книжка в тетрадке'])),
#  ('Иллюстратор', (False, ['Цветкова Анастасия'])),
#  ('Партномер (артикул производителя)', (False, ['A07577S'])),
#  ('Переводчик', (False, ['Лейк Ирина'])),
#  ('Спальность', (False, ['Евро'])),
#  ('Для кого',
#   (False,
#    ['Бабушка',
#     'Брат',
#     'Девочка',
#     'Девушка',
#     'Дедушка',
#     'Дочь',
#     'Жена',
#     'Жених',
#     'Женщина',
#     'Коллега',
#     'Любимая',
#     'Любимый',
#     'Малыш',
#     'Мальчик',
#     'Мама',
#     'Молодой человек',
#     'Муж',
#     'Мужчина',
#     'Невеста',
#     'Папа',
#     'Папа и дедушка',
#     'Победитель/Участник',
#     'Подруга',
#     'Ребенок',
#     'Родственники',
#     'Руководитель',
#     'Сестра',
#     'Сын',
#     'Универсально'])),
#  ('Количество заводских упаковок', (False, ['й'])),
#  ('Форма наконечника.', (False, ['Круглая'])),
#  ('Вид фломастера', (False, ['Стираемый'])),
#  ('Тип основы', (False, ['Водная'])),
#  ('Крепление бейджа', (False, ['Без крепления'])),
#  ('Марка ТС', (False, ['Citroen'])),
#  ('Вид техники',
#   (False,
#    ['Авиатехника',
#     'Внедорожники',
#     'Водная техника',
#     'Грузовые автомобили и автобусы',
#     'Квадроциклы',
#     'Коммерческий транспорт',
#     'Легковые автомобили',
#     'Мопеды',
#     'Мотоциклы',
#     'Погрузчики',
#     'Скутеры',
#     'Снегоходы',
#     'Спецтехника',
#     'Стационарные установки'])),
#  ('Область применения', (False, ['Универсальная применяемость'])),
#  ('Форма выпуска', (False, ['Спрей'])),
#  ('Альтернативные артикулы товара', (False, ['A-210-CITROEN-Copper Gold'])),
#  ('Особенности пледа и покрывала', (False, ['Стёганный'])),
#  ('Тип датчика', (False, ['Датчик коленвала'])),
#  ('OEM-номер',
#   (False,
#    ['237314M500; 237314M502; 237314M505; 237314M506; 237314M50A; 237314M50B; 237314M560; 237314M56C; 237315M000; 237315M001; 237315M005; 2373195F0B; 2373195F0D'])),
#  ('Талия', (False, ['Средняя'])),
#  ('Форма бутылочки/соски', (False, ['Ортодонтическая'])),
#  ('Особенности бутылочек и сосок',
#   (False,
#    ['Для новорожденных',
#     'Не содержит Бисфенол A',
#     'С вентиляционной системой',
#     'С футляром'])),
#  ('Тип используемого кофе', (False, ['Молотый'])),
#  ('Приготовление напитка', (False, ['Подогрев чашек'])),
#  ('Конструкция кофеварок/кофемашин', (False, ['Отсек для шнура'])),
#  ('Сабвуфер', (False, ['Нет'])),
#  ('Версия HDMI', (False, ['HDMI 1.4'])),
#  ('Доп. режимы телевизора', (False, ['Гостиничный режим'])),
#  ('Запись эфира', (False, ['PVR', 'Time Shift'])),
#  ('Встроенный медиаплеер', (False, ['Да'])),
#  ('Управление телевизором', (False, ['Пульт ДУ'])),
#  ('Изогнутый экран', (False, ['Нет'])),
#  ('Интерфейсы',
#   (False,
#    ['3.5 мм',
#     'CI+',
#     'D-Sub (VGA)',
#     'HDMI',
#     'RJ-45 (Ethernet)',
#     'S/PDIF',
#     'USB',
#     'Композитный',
#     'Компонентный'])),
#  ('Технология HDR', (False, ['Нет'])),
#  ('Диагональ экрана, дюймы', (False, ['5"'])),
#  ('Технология матрицы ТВ', (False, ['VA'])),
#  ('Тип подсветки', (False, ['Direct LED'])),
#  ('Стандарт разрешения', (False, ['HD'])),
#  ('ТВ-тюнер', (False, ['DVB-C', 'DVB-T', 'DVB-T2', 'NICAM', 'PAL', 'SECAM'])),
#  ('Размер без подставки (ШxВxГ), мм', (False, ['737 x 438 x 74'])),
#  ('Разрешение', (False, ['1280×720 HD'])),
#  ('Интерьерный телевизор', (False, ['Нет'])),
#  ('Smart TV', (False, ['Нет'])),
#  ('Частота обновления', (False, ['60 Гц'])),
#  ('Стандарт крепления VESA', (False, ['100x100 мм'])),
#  ('Диаметр колес, дюймы', (False, ['28-29'])),
#  ('Вид велосипеда', (False, ['Городской'])),
#  ('Материал рамы', (False, ['Алюминиевый сплав'])),
#  ('Форма поставки', (False, ['В разобранном виде'])),
#  ('Размер рамы, дюймы', (False, ['Универсальный'])),
#  ('Вид ухода', (False, ['Уход за шерстью и кожей'])),
#  ('Возраст ребенка', (False, ['От 5 лет'])),
#  ('Число цветов, шт', (False, ['Унисекс'])),
#  ('Цилиндр (CYL)', (False, [''])),
#  ('Стиль украшения', (False, ['Повседневный'])),
#  ('Размер изделия', (False, ['Безразмерный'])),
#  ('Вставка', (False, ['Стразы'])),
#  ('Вид замка', (False, ['Без замка'])),
#  ('Возраст украшения', (False, ['Современное'])),
#  ('Вид пюре', (False, ['Фруктовое'])),
#  ('Вид фруктов', (False, ['Черника'])),
#  ('Возраст в продуктах питания', (False, ['С 8 месяцев'])),
#  ('Тип мотора', (False, ['AC'])),
#  ('Тип бумаги в книге', (False, ['Офсетная'])),
#  ('Вид клейкой ленты', (False, ['Односторонняя'])),
#  ('Толщина, мкм', (False, ['40 мкм'])),
#  ('Вид шерсти', (False, ['Альпака', 'Меринос'])),
#  ('Вкусовой акцент (вкус)', (False, ['Клубника'])),
#  ('Количество порций', (False, ['30-60'])),
#  ('Плотность плетения', (False, ['40 ден'])),
#  ('Эквивалентная мощность лампы накаливания, Вт', (False, ['60 Вт'])),
#  ('Свет', (False, ['Теплый белый'])),
#  ('Температура света, К', (False, ['3000/4200/6500'])),
#  ('Диммируемость', (False, ['Нет'])),
#  ('Форма лампочки', (False, ['Шар'])),
#  ('Тип колбы', (False, ['G95'])),
#  ('Место применения',
#   (False,
#    ['Для административных учреждений',
#     'Для гаража',
#     'Для гостиниц',
#     'Для дачи и загородного дома',
#     'Для дома',
#     'Для кафе и ресторана',
#     'Для киностудии',
#     'Для магазина',
#     'Для медицинских учреждений',
#     'Для музея и выставочного зала',
#     'Для образовательных учреждений',
#     'Для предприятий и складов',
#     'Для спортивных объектов',
#     'Для театра',
#     'Для фотостудии'])),
#  ('Голосовой помощник', (False, ['Нет'])),
#  ('Управление со смартфона', (False, ['Нет'])),
#  ('Индекс цветопередачи, Ra', (False, ['80-89 (класс 1В)'])),
#  ('Технология', (False, ['Светодиодная'])),
#  ('Вид LED лампы', (False, ['SMD'])),
#  ('Назначение лампы',
#   (False,
#    ['Для витрин',
#     'Для дач и загородных домов',
#     'Для декоративной подсветки',
#     'Для люстр и светильников',
#     'Для предприятий, складов, гаражей',
#     'Для фото',
#     'Общего назначения'])),
#  ('Комплектация лампочками', (False, ['Нет'])),
#  ('Форма ковра', (False, ['Прямоугольник'])),
#  ('Ширина, м', (False, ['0.5�'])),
#  ('Стиль дизайна', (False, ['Лофт', 'Современный'])),
#  ('Основа ковра', (False, ['Без основы'])),
#  ('Цвет тонера/чернил', (False, ['Пурпурный (magenta)'])),
#  ('Цветность', (False, ['Цветной'])),
#  ('Тип расходного материала для печати', (False, ['Чернила'])),
#  ('Ресурс', (False, ['7500 страниц'])),
#  ('Емкость', (False, ['Стандартная'])),
#  ('Оригинальность расходника', (False, ['оригинал'])),
#  ('Количество, шт', (False, ['90x420mm'])),
#  ('Назначение средства от насекомых/грызунов',
#   (False, ['Уничтожение насекомых'])),
#  ('Форма выпуска средств от вредителей', (False, ['Концентрат суспензии'])),
#  ('Вид вредителя', (False, ['Клоп', 'Таракан'])),
#  ('Гипоаллергенно', (False, ['Да'])),
#  ('Название принта', (False, ['ГОБЕЛЕНОВАЯ 45Х45 "АРИСТОКРАТ АГНЕССА"'])),
#  ('Браслет/ремешок', (False, ['Пластик'])),
#  ('Тип часов', (False, ['Кварцевые'])),
#  ('Диаметр корпуса, мм', (False, ['8,5'])),
#  ('Водонепроницаемость', (False, ['10 Bar'])),
#  ('Функции часов',
#   (False,
#    ['Автоматический календарь',
#     'Будильник',
#     'Второй часовой пояс',
#     'День недели',
#     'Месяц',
#     'Секундомер',
#     'Таймер'])),
#  ('Стекло', (False, ['Пластик'])),
#  ('Тип индикации', (False, ['Арабские цифры'])),
#  ('Ширина ремешка, мм', (False, ['20 ATM'])),
#  ('Тип батареи', (False, ['CR2032'])),
#  ('Длина подола', (False, ['средняя длина'])),
#  ('Вид крепления штор', (False, ['Зажимы'])),
#  ('Расположение блока управления', (False, ['Справа'])),
#  ('Монтаж без сверления', (False, ['Да'])),
#  ('Светопроницаемость', (False, ['День ночь'])),
#  ('С дозатором', (False, ['Да'])),
#  ('Назначение моющего, чистящего средства',
#   (False, ['Для ковров', 'Для мебели', 'Для обуви'])),
#  ('Тип загрузки', (False, ['Фронтальная'])),
#  ('Количество листов, шт', (False, ['40 шт.'])),
#  ('Количество уровней нагрузки', (False, [' бесступенчатая система'])),
#  ('Регулировка нагрузки', (False, ['Ручная'])),
#  ('Тренируемые группы мышц', (False, ['Ноги', 'Пресс'])),
#  ('Дисплей', (False, ['LCD'])),
#  ('Макс. угол наклона полотна, %', (False, ['не меняется'])),
#  ('Система нагрузки беговой дорожки', (False, ['Электрическая'])),
#  ('Тип питания', (False, ['От сети'])),
#  ('Класс инструмента', (False, ['Полупрофессиональный'])),
#  ('Диаметр опорного диска, мм', (False, ['30\xa0мм'])),
#  ('Длина шнура питания, м', (False, ['Без цоколя'])),
#  ('Плавный пуск', (False, ['Нет'])),
#  ('Работа с направляющей шиной', (False, ['Да'])),
#  ('Для работы по металлу', (False, ['Нет'])),
#  ('Погружная пила', (False, ['Нет'])),
#  ('Глубина реза/выборки, мм', (False, ['металл/ дерево 10/100 мм'])),
#  ('Тип двигателя', (False, ['Электродвигатель'])),
#  ('Глубина пропила в дереве, мм', (False, ['65\xa0мм'])),
#  ('Высота голенища, см', (False, ['для размера 42: 32 см'])),
#  ('Температурный режим', (False, ['от 10 до -20'])),
#  ('Ортопедический', (False, ['Нет'])),
#  ('Тип пронации', (False, ['Нейтральная'])),
#  ('Материал оправы', (False, ['Металл'])),
#  ('Поляризация', (False, ['Да'])),
#  ('Цвет линзы', (False, ['Серый'])),
#  ('Категория защиты линзы', (False, ['3 (18–8% светопропускания)'])),
#  ('Форма очков', (False, ['Прямоугольные'])),
#  ('Материал линзы', (False, ['Поликарбонат'])),
#  ('Цвет оправы', (False, ['Темно-серый'])),
#  ('Материал спортивных поясов и манжет', (False, ['Натуральная кожа'])),
#  ('Размер', (False, ['Универсальный'])),
#  ('Вид обоев', (False, ['Виниловые'])),
#  ('Основа обоев', (False, ['Бумага с клеевым покрытием'])),
#  ('Покрытие обоев', (False, ['Винил'])),
#  ('Особенности обоев', (False, ['Водостойкие', 'Моющиеся'])),
#  ('Особенности изделия', (False, ['Выраженный финал', 'Звуковые эффекты'])),
#  ('Тип пиротехники', (False, ['Парковые'])),
#  ('Калибр, дюймы', (False, ['0,8"'])),
#  ('Класс опасности пиротехнического изделия', (False, ['III'])),
#  ('Радиус безопасной зоны, м', (False, ['Более 20'])),
#  ('Радиус действия, м',
#   (False, ['до 5 км (зависит от местности и других условий)'])),
#  ('Питание радиоуправляемой модели', (False, ['Сменный аккумулятор'])),
#  ('Типоразмер батареек', (False, ['AA'])),
#  ('Типоразмер батареек пульта', (False, ['AA'])),
#  ('Управление радиоуправляемой моделью', (False, ['Пульт Д/У'])),
#  ('Питание пульта', (False, ['Сменная батарея'])),
#  ('Масштаб радиоуправляемой игрушки', (False, ['1/14'])),
#  ('Вид транспорта', (False, ['Масштабные модели'])),
#  ('Вид зеркала', (False, ['Настенное'])),
#  ('Конструкция зеркала', (False, ['Одностороннее'])),
#  ('Размер, мм', (False, ['51х30х5'])),
#  ('Вид водного спорта', (False, ['Дайвинг', 'Плавание', 'Фридайвинг'])),
#  ('Длина стопы, см', (False, ['17.0-17,5'])),
#  ('Тематика', (False, ['Другое'])),
#  ('Стандарты связи',
#   (False,
#    ['2G',
#     '3G',
#     '4G',
#     'EDGE',
#     'GSM 1800',
#     'GSM 1900',
#     'GSM 850',
#     'GSM 850/1800/1900',
#     'GSM 850/900/1800/1900',
#     'GSM 900',
#     'GSM 900/1800',
#     'GSM 900/1800/1900',
#     'HSDPA',
#     'HSPA+',
#     'LTE',
#     'LTE 1800',
#     'LTE 2600',
#     'LTE 800',
#     'UMTS 2100',
#     'UMTS 900',
#     'WCDMA'])),
#  ('Размещение', (False, ['Уличная'])),
#  ('Направленность антенны', (False, ['Направленная'])),
#  ('Вид антенны', (False, ['Внешняя'])),
#  ('Индикаторы', (False, ['Нагрев'])),
#  ('Вертикальное отпаривание', (False, ['Да'])),
#  ('Свойства подошвы', (False, ['Антипригарное'])),
#  ('Беспроводное использование', (False, ['Нет'])),
#  ('Объем резервуара для воды, мл', (False, ['2500 мл'])),
#  ('Подача пара, г/мин', (False, ['до 90 г/мин'])),
#  ('Покрытие подошвы', (False, ['Керамическое'])),
#  ('Особенности утюга, отпаривателя',
#   (False, ['Противокапельная система', 'Функция самоочистки'])),
#  ('Циферблат', (False, ['Аналоговый'])),
#  ('Стиль часов', (False, ['повседневные'])),
#  ('Особенности часов', (False, ['Винтовая задняя крышка'])),
#  ('Вид обложки', (False, ['для автодокументов'])),
#  ('Материал полотенцесушителя', (False, ['Сталь'])),
#  ('Наличие полок', (False, ['Нет'])),
#  ('Форма полотенцесушителя', (False, ['Нестандартная'])),
#  ('Вариант подключения', (False, ['Боковое левое', 'Боковое правое'])),
#  ('Вид браслета', (False, ['на запястье'])),
#  ('Модель браслета', (False, ['из камней'])),
#  ('Тип вставки', (False, ['Натуральный камень'])),
#  ('Тип анкера', (False, ['С гайкой'])),
#  ('Форма головки анкера', (False, ['Гайка'])),
#  ('Резьба', (False, ['M12'])),
#  ('Головка', (False, ['Шестигранная'])),
#  ('Длина стельки, см', (False, ['23,5'])),
#  ('Вместимость папки, листов', (False, ['350 листов'])),
#  ('Толщина обложки, мм', (False, ['2 мм'])),
#  ('Вид папки', (False, ['Папка-регистратор'])),
#  ('Фиксация документов', (False, ['Арочный механизм'])),
#  ('Расположение сиденья', (False, ['Передние сиденья'])),
#  ('Покрытие корпуса', (False, ['Матовое'])),
#  ('С ножками', (False, ['Нет'])),
#  ('Подъемный механизм', (False, ['Да'])),
#  ('Расположение изголовья', (False, ['Сверху'])),
#  ('Матрас в комплекте', (False, ['Нет'])),
#  ('Ящики для белья', (False, ['Да'])),
#  ('Вид основания', (False, ['Ортопедические ламели'])),
#  ('Назначение (помещение)', (False, ['Для дачи', 'Для дома'])),
#  ('Исполнение', (False, ['Деревянное'])),
#  ('Материал обивки', (False, ['Велюр искусственный'])),
#  ('Модель шейного украшения', (False, ['На цепочке'])),
#  ('Степень газирования', (False, ['Сильногазированная'])),
#  ('Вкус (лимонад)', (False, ['Ягоды'])),
#  ('Количество режимов', (False, ['39447|1'])),
#  ('Длина рабочей части, мм', (False, ['13.8\xa0см'])),
#  ('Размер крючка, N', (False, ['12/0'])),
#  ('Вид крючка', (False, ['Одинарный'])),
#  ('Абажур в комплекте', (False, ['Да'])),
#  ('Вид  детского средства', (False, ['Пенка'])),
#  ('Допуски OEM', (False, ['Нет'])),
#  ('Вязкость по SAE', (False, ['5W-40'])),
#  ('Вид масла', (False, ['Синтетическое'])),
#  ('Классификация по API', (False, ['SN', 'SN PLUS', 'SP'])),
#  ('Двигатель', (False, ['Бензин'])),
#  ('ACEA', (False, ['A3', 'B3', 'B4'])),
#  ('Вид чая', (False, ['Травяной'])),
#  ('Ферментация', (False, ['Ферментированный'])),
#  ('Свойства чая', (False, ['Бодрящий', 'Восстанавливающий', 'Очищающий'])),
#  ('Содержит', (False, ['Минеральные вещества'])),
#  ('Форма чая', (False, ['Гранулированный'])),
#  ('Сорт чая', (False, ['Иван-чай'])),
#  ('Макс. ток, А', (False, ['6А'])),
#  ('Возрастная группа', (False, ['Взрослые (SR)'])),
#  ('Уровень подготовки', (False, ['Продвинутый'])),
#  ('Материалы внутреннего ботинка', (False, ['Капровелюр'])),
#  ('Материалы внешнего ботинка', (False, ['Полимерный материал'])),
#  ('Материал лезвия', (False, ['Нержавеющая сталь'])),
#  ('Позиция игрока', (False, ['Полевой игрок'])),
#  ('Особенности ключницы', (False, ['С дверцей', 'С крючками'])),
#  ('Декоративный элемент', (False, ['Принт'])),
#  ('Основа картины', (False, ['Холст'])),
#  ('Выкладка/вышивка', (False, ['Полная'])),
#  ('Форма страз', (False, ['Квадратная'])),
#  ('Наполнитель', (False, ['Винилискожа', 'Изолон', 'Текстиль'])),
#  ('Диаметр, см', (False, ['10.10, 5,11, 5,14'])),
#  ('Степень водо-пылезащиты', (False, ['IP44'])),
#  ('Вид розетки', (False, ['Евровилка'])),
#  ('Электроустановочные особенности',
#   (False, ['Заземление', 'Защитные шторки', 'Крышка'])),
#  ('Тип зажима проводов', (False, ['Винтовой'])),
#  ('Материал рамки', (False, ['Пластик'])),
#  ('Модель светодиода', (False, ['Samsung LH351D'])),
#  ('Механизм зонта', (False, ['Полный автомат'])),
#  ('Конструкция зонта', (False, ['3 сложения'])),
#  ('Высота каблука, см', (False, ['Низкий'])),
#  ('Тип направляющих для мебели', (False, ['Шариковые'])),
#  ('Принцип игры', (False, ['Перемещение сегментов'])),
#  ('Вид головоломки', (False, ['Головоломки Рубика'])),
#  ('Назначение чистящего средства для ванной и туалета',
#   (False, ['Для унитаза'])),
#  ('Технология производства', (False, ['Сублимированный'])),
#  ('Без кофеина', (False, ['Нет'])),
#  ('Тип фиксатора БДСМ', (False, ['Наручники'])),
#  ('Электробезопасность',
#   (False,
#    ['OTP (защита от перегрева)', 'SCP (защита от короткого замыкания)'])),
#  ('Входное напряжение, В', (False, ['12-24'])),
#  ('Вид розеток', (False, ['Евровилка'])),
#  ('Количество розеток, шт', (False, ['0, 0, 0, 0, 0, 0, 0'])),
#  ('Номинальный ток, А', (False, ['16 А'])),
#  ('Стандарт защиты', (False, ['IP20'])),
#  ('Материал ручки', (False, ['Пластик'])),
#  ('Антишторм', (False, ['Да'])),
#  ('Материал купола', (False, ['Полиэстер'])),
#  ('Шаг зубьев', (False, ['2/3"'])),
#  ('Совместимый инструмент', (False, ['Пила ленточная'])),
#  ('Назначение полотна', (False, ['Для металла'])),
#  ('Вид планшета для рисования', (False, ['Магнитный'])),
#  ('Тип краски в наборе', (False, ['Акрил'])),
#  ('Особенности картин по номерам', (False, ['Без смешивания красок'])),
#  ('Ориентация картины', (False, ['Вертикальная'])),
#  ('Форма тарелки', (False, ['Круг'])),
#  ('Особенности одноразовой посуды',
#   (False, ['Без рисунка', 'Подходит для горячего'])),
#  ('Материал одноразовой посуды', (False, ['Пластик'])),
#  ('Место для выращивания', (False, ['Улица'])),
#  ('Регион выращивания', (False, ['Для всех регионов'])),
#  ('Вид посадочного материала', (False, ['Тыквы'])),
#  ('Сорт семян', (False, ['Тыква крупноплодная Россиянка'])),
#  ('Материал деки', (False, ['Пластик'])),
#  ('Материал колес', (False, ['Полиуретан'])),
#  ('Назначение самоката', (False, ['Городской'])),
#  ('Длина деки, см', (False, ['Sprite Deluxe LED'])),
#  ('Подшипники', (False, ['ABEC 7'])),
#  ('Тормоз самоката', (False, ['Ножной'])),
#  ('Особенности самоката', (False, ['Регулируемый руль', 'Светящиеся колеса'])),
#  ('Конструкция самоката', (False, ['Складной'])),
#  ('Подходит для', (False, ['Lenovo'])),
#  ('Вид запчасти ноутбука/планшета', (False, ['Клавиатура'])),
#  ('Вид термостата', (False, ['Электронный'])),
#  ('Управление обогревателем', (False, ['Пульт ДУ'])),
#  ('Вид обогревателя', (False, ['Конвекционный'])),
#  ('Особенности климатической техники',
#   (False,
#    ['Имитация пламени',
#     'Пульт ДУ',
#     'Режим работы без нагрева',
#     'Таймер',
#     'Термостат'])),
#  ('Тип нагревательного элемента', (False, ['ТЭН'])),
#  ('Входная резьба', (False, ['1/2"'])),
#  ('Расположение резьбы', (False, ['Внешняя', 'Внутренняя'])),
#  ('Выходная резьба', (False, ['1/2"'])),
#  ('Высота платформы, см', (False, ['1.5 см'])),
#  ('Длина щетки, см', (False, ['600\xa0мм'])),
#  ('Назначение удобрения', (False, ['Универсальное'])),
#  ('Гарантия на товар, мес.', (False, ['0,5 месяцев'])),
#  ('Параметры модели на фото', (False, ['102-82-118'])),
#  ('Тип антипригарного покрытия', (False, ['Xylan'])),
#  ('Вид блюда',
#   (False, ['Блины', 'Жаркое', 'Мясо', 'Овощи', 'Плов', 'Птица', 'Рыба'])),
#  ('Форма сковороды', (False, ['Круг'])),
#  ('Вид маски', (False, ['Кремовая'])),
#  ('Материал подкладки/внутренней отделки', (False, ['Замша'])),
#  ('Материал фурнитуры', (False, ['Металл'])),
#  ('Модель штампа', (False, ['Trodat 5435'])),
#  ('Размер основного шрифта, мм', (False, ['3 мм'])),
#  ('Комплектация штемпельной продукции', (False, ['Сменная подушка'])),
#  ('Вид датера/штампа', (False, ['Самонаборный'])),
#  ('Вид гриля', (False, ['Гриль'])),
#  ('Назначение гриля', (False, ['Для дома'])),
#  ('Вид рабочей поверхности', (False, ['Гриль'])),
#  ('Расположение нагревательного элемента', (False, ['Сверху и снизу'])),
#  ('Материал рабочей поверхности', (False, ['Алюминий'])),
#  ('Датчики', (False, ['Термостат'])),
#  ('Нагревательный элемент', (False, ['Закрытый'])),
#  ('Съемные панели', (False, ['Да'])),
#  ('Вид пастели', (False, ['Масляная'])),
#  ('Совместимость с фотокамерами',
#   (False, ['Eken', 'GoPro', 'SJCAM', 'Xiaomi'])),
#  ('Вид застежки', (False, ['Молния'])),
#  ('Вид цветных линз', (False, ['Тонирующие'])),
#  ('Вид мозаики', (False, ['Классическая'])),
#  ('Тип стоматологического средства',
#   (False, ['Ортодонтический воск для брекетов'])),
#  ('Цвет ниток', (False, ['Однотонный'])),
#  ('Предмет вышивки', (False, ['Картина'])),
#  ('Размер канвы, каунт', (False, ['14 Aida'])),
#  ('Патрон/шпиндель/крепление', (False, ['Резьба 1 1/4"'])),
#  ('Пол животного', (False, ['Мужской'])),
#  ('Материал подклада', (False, ['Флис'])),
#  ('Обхват шеи, см', (False, ['28-42'])),
#  ('Обхват груди животного, см', (False, ['64-70'])),
#  ('Длина спины, см', (False, ['26-27'])),
#  ('Место крепления штор',
#   (False, ['В проем', 'На потолок', 'На раму', 'На створку', 'На стену'])),
#  ('Изгиб ресниц', (False, ['L'])),
#  ('Длина ресниц, мм', (False, ['6-13'])),
#  ('Толщина ресниц, мм', (False, ['0.085+'])),
#  ('Тип волокна ресниц', (False, ['Глянцевые'])),
#  ('Вид батареи звонка', (False, ['AAA'])),
#  ('Питание звонка', (False, ['От батареи'])),
#  ('Класс защиты', (False, ['IP44'])),
#  ('Особенности штекера/кабеля', (False, ['Одностороннее подключение кабеля'])),
#  ('Особенности шапки', (False, ['двухслойная'])),
#  ('Тип аккумулятора', (False, ['Li-ion'])),
#  ('Список совместимых устройств',
#   (False, ['Lenovo Ideapad L340-15IRH, L340-17IRH'])),
#  ('Напряжение, В', (False, ['220/380'])),
#  ('Емкость, мА•ч', (False, ['30Ahx1 ChargerX1'])),
#  ('Глубина плиты, см', (False, ['60 см'])),
#  ('Тип установки', (False, ['Независимая'])),
#  ('Тип конфорок', (False, ['Комбинированные'])),
#  ('Материал решеток', (False, ['Сталь'])),
#  ('Объем духовки, л', (False, ['Нет'])),
#  ('Внутреннее покрытие', (False, ['Эмаль'])),
#  ('Тип духовки', (False, ['Электрический'])),
#  ('Очистка духовки', (False, ['Традиционная'])),
#  ('Особенности духовки, плиты', (False, ['Ящик для посуды'])),
#  ('Потребляемая мощность, Вт', (False, ['5.8 Вт'])),
#  ('Тип панели (плиты)', (False, ['Комбинированная'])),
#  ('Совместимость', (False, ['Android; IOS; Windows'])),
#  ('Внешняя оболочка кабеля', (False, ['ПВХ (поливинилхлорид)'])),
#  ('Материал проводника', (False, ['Медь'])),
#  ('Коннектор 1', (False, ['Apple Lightning'])),
#  ('Коннектор 2', (False, ['USB 2.0 Type-A'])),
#  ('Тип коннектора 1', (False, ['Штекер (male)'])),
#  ('Тип коннектора 2', (False, ['Штекер (male)'])),
#  ('Прокладывание кабеля', (False, ['Внутреннее (для помещений)'])),
#  ('Версия интерфейса', (False, ['USB 2.0'])),
#  ('Сохранность книги', (False, ['Хорошая'])),
#  ('Назначение посадочного материала', (False, ['Для огорода'])),
#  ('Количество элементов, шт', (False, ['Нет'])),
#  ('Материал покрытия', (False, ['Текстиль'])),
#  ('Вид гигиенических прокладок', (False, ['Дневные'])),
#  ('Вид фитиля', (False, ['хлопковый'])),
#  ('Материал подсвечника', (False, ['Стекло'])),
#  ('Подарочная упаковка в комплекте', (False, ['Нет'])),
#  ('Состав свечи', (False, ['Соевый воск'])),
#  ('Крышка в комплекте', (False, ['Да'])),
#  ('Время горения, ч', (False, ['до 18'])),
#  ('В подсвечнике', (False, ['Да'])),
#  ('Солнцезащитная косметика', (False, ['Нет'])),
#  ('Вид ароматизатора', (False, ['Аэрозоль'])),
#  ('Тип дверной ручки', (False, ['На розетке'])),
#  ('С узором', (False, ['Нет'])),
#  ('Вид заготовки для бижутерии', (False, ['Застежка'])),
#  ('Количество фигурок', (False, ['Элемент миниатюры'])),
#  ('Совместим с LEGO', (False, ['true'])),
#  ('Количество деталей конструктора', (False, ['от 500 до 1000 шт'])),
#  ('Тематика конструкторов', (False, ['Принцессы'])),
#  ('Особенности конструктора', (False, ['Блочный', 'Сборная модель'])),
#  ('Вид ткани', (False, ['Принтованная'])),
#  ('Тип накопителя', (False, ['HDD'])),
#  ('Размер корпуса', (False, ['Midi Tower'])),
#  ('Модель процессора', (False, ['Intel Core i5'])),
#  ('Модель графического процессора', (False, ['GeForce GTX 1050 Ti'])),
#  ('Чипсет', (False, ['Intel H610'])),
#  ('Оперативная память', (False, ['16 ГБ'])),
#  ('Тип памяти', (False, ['DDR4'])),
#  ('Возможность расширения RAM, до', (False, ['64 ГБ'])),
#  ('Форм-фактор RAM', (False, ['DIMM'])),
#  ('Бренд процессора', (False, ['Intel'])),
#  ('Бренд графического процессора', (False, ['NVIDIA'])),
#  ('Оптический привод', (False, ['Отсутствует'])),
#  ('Версия Windows', (False, ['Windows 10 Pro'])),
#  ('Тип видеокарты', (False, ['Дискретная'])),
#  ('Видеопамять', (False, ['4 ГБ'])),
#  ('Конфигурация',
#   (False,
#    ['Игровой ПК ARENA 5037 (Intel Core i5-12400F/GeForce GTX 1050Ti 4 ГБ/16 ГБ DDR4/1000 ГБ HDD)'])),
#  ('Сетевая карта', (False, ['1000 Мбит/с (GE)'])),
#  ('Интерфейсы и разъемы',
#   (False, ['3.5 мм', 'DVI', 'HDMI', 'RJ-45 Ethernet'])),
#  ('Процессор', (False, ['Intel Core i5-12400F'])),
#  ('Видеокарта', (False, ['NVIDIA GeForce GTX 1050 Ti (4 Гб)'])),
#  ('ОС (краткое название)', (False, ['Windows 10 Pro'])),
#  ('Назначение материала', (False, ['Брючная', 'Костюмная'])),
#  ('Исполнение излива', (False, ['Поворотный'])),
#  ('Вид крепления смесителя', (False, ['На гайке'])),
#  ('Стандарт подводки шланга', (False, ['1/2" х 10 мм'])),
#  ('Запорный клапан смесителя', (False, ['Керамический картридж'])),
#  ('Материал лотка', (False, ['Пластик'])),
#  ('Реверс', (False, ['Нет'])),
#  ('Вид игрушки для животных', (False, ['Мягкая (текстильная)'])),
#  ('Место для игр', (False, ['Дом', 'Улица'])),
#  ('Особенности игрушки', (False, ['С запахом'])),
#  ('Назначение игрушки',
#   (False,
#    ['Для борьбы со стрессом',
#     'Для отвлечения во время отсутствия хозяина',
#     'Для поддержания питомца в форме'])),
#  ('Тип реза', (False, ['Сухой'])),
#  ('Посадочный размер', (False, ['M14'])),
#  ('Насадки', (False, ['Насадка с регулировкой длины'])),
#  ('Число установок длины', (False, ['0,2-0,8 мм'])),
#  ('Класс машинки', (False, ['Профессиональный'])),
#  ('Способ регулировки длины', (False, ['С помощью насадок и регулятора'])),
#  ('Питание', (False, ['От сети'])),
#  ('Материал гребного винта', (False, ['Сталь'])),
#  ('Вращение гребного винта', (False, ['Вправо'])),
#  ('Диаметр гребного винта, дюймы', (False, ['9 1/4'])),
#  ('Фасовка, кг', (False, ['Де Барао красный'])),
#  ('Время посадки в грунт', (False, ['Май'])),
#  ('Высота растения, см', (False, ['180-200'])),
#  ('Жизненный цикл', (False, ['Однолетник'])),
#  ('Время урожая', (False, ['Июнь'])),
#  ('Защита от детей', (False, ['Нет'])),
#  ('Функционал духовки', (False, ['Гриль', 'Конвекция'])),
#  ('Управление духовкой', (False, ['Таймер'])),
#  ('Телескопические направляющие духовки', (False, ['Нет'])),
#  ('Ширина встраивания, см', (False, ['Нестандарт'])),
#  ('Размер ниши, мм', (False, ['595х560х580'])),
#  ('Таймер', (False, ['Звуковой'])),
#  ('Подсветка духовки', (False, ['Галогеновая'])),
#  ('Класс энергоэффективности', (False, ['A'])),
#  ('Форма выпуска мыла', (False, ['Жидкое мыло'])),
#  ('Количество отделений', (False, ['13 шт.'])),
#  ('Конструкция очков', (False, ['Ободковые'])),
#  ('Материал оправы очков', (False, ['Пластик'])),
#  ('Материал линз', (False, ['Пластик'])),
#  ('Стиль оправы', (False, ['Повседневный'])),
#  ('Наличие флексов', (False, ['Нет'])),
#  ('Коллекция (год)', (False, ['1985+'])),
#  ('Высота линзы, мм', (False, ['48,7'])),
#  ('Форма лица',
#   (False,
#    ['Квадратная', 'Круглая', 'Овальная', 'Прямоугольная', 'Треугольная'])),
#  ('Покрытие линз',
#   (False,
#    ['Упрочняющее, просветляющее, металлизированное (защита от электромагнитных волн) UV-380, водоотталкивающее и антистатическое'])),
#  ('Расстояние между оптическими центрами', (False, ['62-64'])),
#  ('Форма оправы', (False, ['Классическая'])),
#  ('Основа холста', (False, ['Подрамник'])),
#  ('Комплект аксессуаров', (False, ['Да'])),
#  ('Форма пазла', (False, ['Фигурный'])),
#  ('Нижняя температура комфорта, °C ', (False, ['От 0 до +5'])),
#  ('Экстремальная температура, °C', (False, ['-5°C'])),
#  ('Верхняя температура комфорта, °С', (False, ['От 0 до +5'])),
#  ('Материал наполнителя спального мешка', (False, ['Синтетика'])),
#  ('Материал наружного слоя', (False, ['Синтетика'])),
#  ('Материал подкладки спального мешка', (False, ['Фланель'])),
#  ('Назначение спального мешка', (False, ['Кемпинговое'])),
#  ('Расположение молнии', (False, ['Справа'])),
#  ('Особенности спальных мешков',
#   (False, ['Анатомический капюшон', 'Возможность состегивания'])),
#  ('Вид спального мешка', (False, ['Одеяло'])),
#  ('Материал столового прибора', (False, ['Нержавеющая сталь'])),
#  ('Измерения параметров тела', (False, ['Вес'])),
#  ('Материал платформы', (False, ['Стекло'])),
#  ('Максимальная нагрузка, кг', (False, ['11 кг'])),
#  ('Единицы измерения', (False, ['Кг'])),
#  ('Тип инструмента для гончарного дела', (False, ['Стек'])),
#  ('Вид сюжетно-ролевой игрушки', (False, ['Игрушечный магазин'])),
#  ('Вид шайбы', (False, ['Кузовная'])),
#  ('Стандарт DIN', (False, ['5299С'])),
#  ('Материал прокладки', (False, ['Резина'])),
#  ('Расположение выходной резьбы', (False, ['Внешняя'])),
#  ('Диаметр', (False, ['1/2"'])),
#  ('Диаметр соединения', (False, ['1"'])),
#  ('Механизм насоса', (False, ['Вихревой'])),
#  ('Двигатель для садовой техники', (False, ['Электродвигатель'])),
#  ('Тип запуска', (False, ['Электрический'])),
#  ('Защита от сухого хода', (False, ['Нет'])),
#  ('Производительность, л/мин', (False, ['10 л/мин'])),
#  ('ILSAC', (False, ['GF-6A'])),
#  ('Вид спортивной игры', (False, ['Футбол'])),
#  ('Вид воздушного фильтра', (False, ['Пылевой'])),
#  ('Исполнение фильтра', (False, ['Фильтр-патрон'])),
#  ('Место установки', (False, ['Передние', 'Слева'])),
#  ('Среда обитания', (False, ['Пресноводная'])),
#  ('Разновидность рыбы',
#   (False,
#    ['Карась',
#     'Карповые',
#     'Лещ',
#     'Линь',
#     'Морские',
#     'Плотва',
#     'Подлещик',
#     'Сазан',
#     'Сомовые',
#     'Толстолобик',
#     'Тунец',
#     'Форель'])),
#  ('Тип блендера/комбайна', (False, ['Планетарный'])),
#  ('Рекомендованный размер спиц', (False, ['2,5', '3', '3,5'])),
#  ('Рекомендованный размер крючка', (False, ['3,5'])),
#  ('Назначение пряжи',
#   (False,
#    ['Джемперы, кардиганы', 'Носки, перчатки, варежки', 'Одежда для детей'])),
#  ('Структура пряжи', (False, ['Классическая'])),
#  ('Способ вязания', (False, ['Крючок', 'Спицы'])),
#  ('Тип окраски пряжи', (False, ['Однотонная'])),
#  ('Соответствие стандарту (ФГОС)', (False, ['Да'])),
#  ('Предмет обучения', (False, ['Иностранный язык'])),
#  ('Класс', (False, ['7 класс'])),
#  ('Форм-фактор', (False, ['2.5"'])),
#  ('Тип флеш-памяти', (False, ['TLC 2D NAND'])),
#  ('Интерфейс SSD', (False, ['SATA2 3.0 Гбит/с'])),
#  ('Вид добавки (начинки)', (False, ['Дробленая'])),
#  ('Начинка конфет/шоколада', (False, ['Карамельная'])),
#  ('Вид конфет', (False, ['Драже'])),
#  ('Разметка канвы', (False, ['Однотонная'])),
#  ('Тип канвы', (False, ['Ткань блочного переплетения'])),
#  ('Механизм качания', (False, ['Нет'])),
#  ('Поддержка поясницы', (False, ['Нет'])),
#  ('Подставка для ног', (False, ['Нет'])),
#  ('С подлокотниками', (False, ['Нет'])),
#  ('С подголовником', (False, ['Нет'])),
#  ('Вид крючка для рукоделия', (False, ['Классический'])),
#  ('Материал ворса кисти', (False, ['Синтетика'])),
#  ('Текстура', (False, ['Таблетки'])),
#  ('Время посадки на рассаду', (False, ['Март'])),
#  ('Время цветения', (False, ['Август', 'Июль', 'Июнь', 'Сентябрь'])),
#  ('Раздвижной карниз', (False, ['Нет'])),
#  ('Вид карниза', (False, ['для классических штор'])),
#  ('Крепление карниза', (False, ['К потолку', 'На стену', 'Универсальное'])),
#  ('Рядность карниза', (False, ['1 ряд'])),
#  ('Классификация аромата', (False, ['Акватический', 'Цветочный'])),
#  ('Вид электроподжига', (False, ['Автоматический'])),
#  ('Тип гриля', (False, ['Газовый'])),
#  ('Электроподжиг духовки', (False, ['Автоматический'])),
#  ('Дополнительные функции весов', (False, ['Автоматическое выключение'])),
#  ('Функции весов', (False, ['Сброс веса тары'])),
#  ('Форм-фактор батареи', (False, ['AAA'])),
#  ('Номер СГР', (False, ['RU.77.99.11.003.Е.005690.12.18'])),
#  ('Показания',
#   (False,
#    ['В качестве биологически активной добавки к пище для мужчин - дополнительного источника аскорбиновой кислоты, источника L-карнитина, ацетил-L-карнитина, альфа-липоевой кислоты.'])),
#  ('Направление витаминов', (False, ['Для мужского здоровья'])),
#  ('Срок годности', (False, ['3 года'])),
#  ('Противопоказания БАД',
#   (False, ['БАД. НЕ ЯВЛЯЕТСЯ ЛЕКАРСТВЕННЫМ СРЕДСТВОМ'])),
#  ('Форма выпуска продукта', (False, ['Порошок'])),
#  ('МНН/Действующее вещество', (False, ['10 г '])),
#  ('Конструкция полки', (False, ['Прямая'])),
#  ('Расположение полки', (False, ['Настенная'])),
#  ('Ориентация', (False, ['Универсальный'])),
#  ('Состав комплекта аксессуаров', (False, ['перчатки'])),
#  ('Макс. температура нагрева, °С', (False, ['200 С'])),
#  ('Сезонность одеяла', (False, ['Всесезонное', 'Летнее'])),
#  ('Плавучесть', (False, ['Тонущий (Sinking)'])),
#  ('Вид воблера', (False, ['Стикбейт (StickBait)'])),
#  ('Дополнительные функции', (False, ['Развивающая'])),
#  ('Высота игрушки, см', (False, ['20. 4'])),
#  ('Вид сережек', (False, ['асимметричные'])),
#  ('Дизайн', (False, ['Надписи'])),
#  ('Вид глазури/посыпки', (False, ['Шоколадная'])),
#  ('Добавки',
#   (False, ['Кедровый орех', 'Клюква', 'Сосновая шишка', 'Шоколад'])),
#  ('Ассорти', (False, ['Да'])),
#  ('Тип соединения', (False, ['проводная'])),
#  ('Бесшумное нажатие', (False, ['Да'])),
#  ('Тип клавиатуры', (False, ['Оптико-механическая'])),
#  ('Тип клавиш', (False, ['Физические'])),
#  ('Дополнительные клавиши', (False, ['Клавиши управления мультимедиа'])),
#  ('Конструкция клавиатуры', (False, ['Полноразмерная'])),
#  ('Тип механических клавиш', (False, ['Razer Opto-Mechanical Red'])),
#  ('Длина кабеля, м', (False, ['104 мм'])),
#  ('Подсветка', (False, ['Да'])),
#  ('Интерфейс', (False, ['USB'])),
#  ('Назначение приправы', (False, ['Универсальная'])),
#  ('Звуковая схема', (False, ['моно'])),
#  ('Назначение акустики', (False, ['Фронтальные колонки'])),
#  ...]

# %%
sentences = list(map(lambda x: x[0], sent_attr)) #num_attr #['товар цвет', ]
preproc_sentences = list(map(lambda x: preprocess_text(x), sentences))
embeddings = model.encode(preproc_sentences)
print(preproc_sentences)
# Out:
# ['цвет товар', 'пол ребенок', 'бренд', 'тип', 'странаизготовитель', 'развитие навык', 'код тереть', 'минимальный возраст ребенок', 'материал', 'вес товар г', 'максимальный возраст ребенок', 'количество в упаковка шт', 'материал набор', 'техника вышивка', 'возрастной ограничение', 'длина по горизонталь см', 'длина по вертикаль см', 'размер мм', 'ширина см', 'состав нитка', 'длина м', 'название цвет', 'минимальный продолжительность партия мина', 'минимальный число игрок', 'максимальный число игрок', 'вид выпуск товар', 'целевой аудитория', 'вид настольный игра', 'целевой аудитория игра', 'артикул', 'вес кг', 'размерность', 'материал чехол', 'материал наполнитель', 'технология пошив', 'комплектация', 'объем мл', 'фильтр', 'тип цоколь', 'вид лампа', 'количество лампа шт', 'макс мощность лампа вт', 'материал плафон', 'вид питание', 'цвет плафон', 'площадь освещение квм', 'тип выключатель', 'партномер', 'состав', 'упаковка', 'назначение средство для стирка', 'название аромат', 'аромат', 'размер упаковка длина х ширина х высота см', 'вид стирка', 'форма выпуск средство', 'особенность применение', 'единица в один товар', 'число стирка', 'размерность комплект', 'гарантийный срок', 'отделка', 'застежка пододеяльник', 'название материал', 'застежка наволочкичехол', 'образец цвет', 'размер простыня', 'состав материал', 'размер наволочка', 'размер пододеяльник', 'комплектация постельный белье', 'режим стирка', 'вид простыня', 'размер крышка см', 'совместимый плита', 'крышка', 'особенность посуда', 'диаметр дно см', 'помещение', 'тип помещение', 'марка эмаль', 'количество компонент', 'возможность колеровка', 'степень блеск покрытие', 'время высыхание час', 'основа краска', 'область применение состав', 'назначение', 'работа', 'можно мыть', 'вид краска', 'способ нанесение', 'объем л', 'расход лм', 'аэрозоль', 'тип растворитель', 'материал основание', 'вид шампур', 'материал рукоять', 'вибрация', 'состав комплект', 'размер бдсматрибутика', 'пол', 'назначение товар', 'размер сексигрушка', 'длина см', 'тип мастурбатор', 'вид насадка', 'ширинадиаметр мм', 'особенность', 'вид стимулятор', 'количество внешний карман', 'количество внутренний отделение', 'внешний размер мм', 'консистенция краскиклея', 'цветовой эффект', 'форма выпуск краска', 'вид ручка', 'цвет чернила', 'толщина линия мм', 'плотность гм', 'формат', 'размер одеждыаксессуар для животное', 'сезон', 'особенность одежда обувь', 'размер животное', 'вид одежда', 'предназначить для', 'содержание мясо субпродукт', 'особенность', 'порода собака', 'основной ингредиент', 'возраст животное', 'особый потребность', 'вкус корм для животное', 'консистенция корм для животное', 'условие хранение', 'упаковка консервированный корм', 'минеральный вещество', 'класс корм', 'длина больший сторона см', 'длина малый сторона см', 'наполнитель лежакадомик для животное', 'форма выпуск корм', 'страна бренд', 'материал подошва обувь', 'вид каблук', 'материал стелька', 'российский размер обувь', 'полнота', 'вид застежка', 'особенность модель', 'внутренний материал', 'посадка', 'спортивный назначение', 'материал верх', 'коллекция', 'размер производитель', 'бренд в одежда и обувь', 'праздник', 'эффект от использование уходовой косметика', 'применение', 'тип кожа', 'область использование', 'способ применение', 'особенность состав', 'возрастной диапазон', 'эффект', 'тип волос', 'вес г', 'вид средство для уход', 'бьютиингредиент', 'основной материал', 'материал щетина', 'вид парикмахерский расческа', 'день до замена', 'режим ношение', 'диаметр мм', 'количество в упаковка', 'особенность контактный линза', 'материал контактный линза', 'кислородопропускание dkt', 'основа состав', 'эффект интимный средство', 'признак', 'уровень шум при работа дб', 'вид ингалятор', 'мина размер частица мкм', 'скорость ингаляция млмин', 'вид средство для обувиодежда', 'для какой материал', 'эффект от использование', 'тип застежка', 'размер рюкзак', 'вид рюкзак', 'ручка', 'особенность конструкция сумка', 'материал подкладка', 'фактура материал ...

# %%
torch_embeddings = embeddings_to_torch(embeddings)
sent_clast_lst, sent_clast_distribution = clastarize(sentences, torch_embeddings, 0.92)
print(len(sent_clast_lst))
# Out:
# 2608

# %%
print(len(sentences))
for clast in sent_clast_lst:
    print(f"clast main: {clast[0][0]}")
    print(f"clasts: {clast[1:]}")
    print("\n")
# Out:
# 4621
# clast main: Цвет товара
# clasts: []
#
#
# clast main: Пол ребенка
# clasts: []
#
#
# clast main: Бренд
# clasts: [('Страна бренда', tensor([0.9476])), ('Поддерживаемые бренды', tensor([0.9500])), ('Совместимый бренд', tensor([0.9412]))]
#
#
# clast main: Тип
# clasts: [('Формат', tensor([0.9209])), ('Тип застежки', tensor([0.9224])), ('Вид принта', tensor([0.9220])), ('Тип сушки', tensor([0.9217])), ('Вид', tensor([0.9456])), ('Тип застёжки', tensor([0.9224])), ('Форма', tensor([0.9276])), ('Тип основы', tensor([0.9535])), ('Тип часов', tensor([0.9229])), ('Тип пронации', tensor([0.9494])), ('Тип вставки', tensor([0.9371])), ('Тип установки', tensor([0.9309])), ('Тип конфорок', tensor([0.9353])), ('Тип духовки', tensor([0.9323])), ('Тип коннектора 1', tensor([0.9515])), ('Тип коннектора 2', tensor([0.9515])), ('Тип реза', tensor([0.9233])), ('Тип канвы', tensor([0.9298])), ('Тип соединения', tensor([0.9266])), ('Категория', tensor([0.9201])), ('Типоразмер', tensor([0.9401])), ('Тип расцепления', tensor([0.9367])), ('Тип открывания', tensor([0.9276])), ('Тип челнока', tensor([0.9261])), ('Тип протектора', tensor([0.9234])), ('Тип корпуса', tensor([0.9331])), ('Тип направляющих', tensor([0.9326])), ('Тип комплектующего', tensor([0.9294])), ('Вид основы', tensor([0.9248])), ('Тип элемента', tensor([0.9362])), ('Тип тока', tensor([0.9521])), ('Тип призмы', tensor([0.9632])), ('Тип скакалки', tensor([0.9231])), ('Тип ствола', tensor([0.9281])), ('Тип кратности', tensor([0.9473])), ('Тип связи', tensor([0.9310])), ('Тип биты', tensor([0.9462])), ('Тип поставки', tensor([0.9205])), ('Тип держателя', tensor([0.9368])), ('Тип присоединения', tensor([0.9231])), ('Тип ростовки', tensor([0.9427])), ('Тип подрамника', tensor([0.9587])), ('Тип зап. части', tensor([0.9343])), ('Тип дюбеля', tensor([0.9393])), ('Тип пленки', tensor([0.9388])), ('Тип профиля', tensor([0.9364])), ('Тип фрезы', tensor([0.9231])), ('Вид шва', tensor([0.9248])), ('Тип швов', tensor([0.9705])), ('Тип сложения', tensor([0.9464])), ('Тип пропила', tensor([0.9328])), ('Тип фигурки', tensor([0.9335])), ('Тип МФУ', tensor([0.9418])), ('Тип механизма', tensor([0.9219])), ('Тип переносицы', tensor([0.9391])), ('Тип завесы', tensor([0.9662])), ('Тип теста', tensor([0.9306])), ('Тип паяльника', tensor([0.9233])), ('Тип обруча', tensor([0.9536])), ('Тип шредера', tensor([0.9228])), ('Тип средства', tensor([0.9523])), ('Тип ношения', tensor([0.9209])), ('Тип вспенивателя', tensor([0.9279])), ('Тип пароварки', tensor([0.9242])), ('Тип скоб', tensor([0.9391])), ('Тип устройства', tensor([0.9326])), ('Тип конструкции', tensor([0.9274])), ('Тип коннектора', tensor([0.9515])), ('Тип головки', tensor([0.9489])), ('Тип перфорации', tensor([0.9290])), ('Тип передачи', tensor([0.9267]))]
#
#
# clast main: Страна-изготовитель
# clasts: []
#
#
# clast main: Развитие навыков
# clasts: []
#
#
# clast main: Код ТРУ
# clasts: [('Код АТХ', tensor([0.9211]))]
#
#
# clast main: Минимальный возраст ребенка
# clasts: [('Возраст ребенка', tensor([0.9314])), ('Минимальный возраст от', tensor([0.9473]))]
#
#
# clast main: Материал
# clasts: [('Материалы набора', tensor([0.9357])), ('Название материала', tensor([0.9220])), ('Состав материала', tensor([0.9626])), ('Материал основания', tensor([0.9508])), ('Материал верха', tensor([0.9224])), ('Основной материал', tensor([0.9222])), ('Для каких материалов', tensor([0.9506])), ('Материал подкладки', tensor([0.9216])), ('Фактура материала', tensor([0.9744])), ('Материал корпуса', tensor([0.9333])), ('Материал оправы', tensor([0.9724])), ('Материал обивки', tensor([0.9346])), ('Материал рамки', tensor([0.9254])), ('Материал деки', tensor([0.9377])), ('Материал подклада', tensor([0.9343])), ('Материал решеток', tensor([0.9231])), ('Назначение материала', tensor([0.9376])), ('Материал прокладки', tensor([0.9343])), ('Материал оболочки', tensor([0.9378])), ('Материал подстолья', tensor([0.9457])), ('Материал обода', tensor([0.9450])), ('Применение материала', tensor([0.9470])), ('Материал сверла', tensor([0.9560])), ('Материал изготовления', tensor([0.9386])), ('Материал кейкапов', tensor([0.9232])), ('Материал тента', tensor([0.9376])), ('Материал изоленты', tensor([0.9419])), ('Материал поддона', tensor([0.9407])), ('Материал ', tensor([1.0000])), ('Материал ворса', tensor([0.9433])), ('Материал призмы', tensor([0.9701])), ('Материал казана', tensor([0.9351])), ('Материал подставки', tensor([0.9254])), ('Материал полотна', tensor([0.9220])), ('Поддерживаемые материалы', tensor([0.9355])), ('Материал колбы', tensor([0.9206])), ('Материал основы', tensor([0.9539])), ('Материал шнека', tensor([0.9311])), ('Материал подложки', tensor([0.9399])), ('Материал тонарма', tensor([0.9403])), ('Материал поверхности', tensor([0.9238])), ('Материал формы', tensor([0.9258])), ('Материал порожка', tensor([0.9407])), ('Материал дуг', tensor([0.9560])), ('Материал бойка', tensor([0.9314])), ('Обрабатываемый материал', tensor([0.9253])), ('Материал поддонов', tensor([0.9407])), ('Обнаруживаемые материалы', tensor([0.9320])), ('Шовный материал', tensor([0.9694])), ('Материал древка', tensor([0.9484])), ('Материал абразива', tensor([0.9524])), ('Подстилочный материал', tensor([0.9627])), ('Материал раковины', tensor([0.9252])), ('Материал прищепки', tensor([0.9334])), ('Материал палки', tensor([0.9209])), ('Материал древка весла', tensor([0.9266])), ('Материал кия', tensor([0.9361])), ('Материал хайбэка', tensor([0.9237])), ('Материал массива', tensor([0.9244]))]
#
#
# clast main: Вес товара, г
# clasts: [('Вес, кг', tensor([0.9282])), ('Вес, г', tensor([0.9501]))]
#
#
# clast main: Максимальный возраст ребенка
# clasts: []
#
#
# clast main: Количество в упаковке, шт
# clasts: [('Упаковка', tensor([0.9354])), ('Количество в упаковке', tensor([0.9827])), ('Количество в упаковке, шт.', tensor([1.])), ('Количество пар в упаковке', tensor([0.9532])), ('Количество заводских упаковок', tensor([0.9517])), ('Количество, шт', tensor([0.9298]))]
#
#
# clast main: Техника вышивки
# clasts: [('Технология пошива', tensor([0.9438])), ('Предмет вышивки', tensor([0.9594]))]
#
#
# clast main: Возрастные ограничения
# clasts: []
#
#
# clast main: Длина по горизонтали, см
# clasts: [('Длина по вертикали, см', tensor([0.9672]))]
#
#
# clast main: Размеры, мм
# clasts: [('Размерность', tensor([0.9276])), ('Ширина/диаметр, мм', tensor([0.9398])), ('Внешние размеры, мм', tensor([0.9641])), ('Диаметр, мм', tensor([0.9589])), ('Размер, см', tensor([0.9658])), ('Длина, мм', tensor([0.9369])), ('Ширина, мм', tensor([0.9418])), ('Размер', tensor([0.9508])), ('Размер, мм', tensor([1.])), ('Диаметр, см', tensor([0.9475])), ('Размер ниши, мм', tensor([0.9449])), ('Диаметр', tensor([0.9226])), ('Диаметр, дюймы', tensor([0.9211])), ('Размер открытки, см', tensor([0.9345])), ('Наружный диаметр, мм', tensor([0.9201])), ('Ширина/максимальный диаметр, мм', tensor([0.9260])), ('Размер шлица', tensor([0.9323])), ('Ширина основания, мм', tensor([0.9217])), ('Размеры проема, мм', tensor([0.9367])), ('Размеры', tensor([0.9508])), ('Размер, дюйм', tensor([0.9451])), ('Размер (Толщина х Диаметр), мм', tensor([0.9286]))]
#
#
# clast main: Ширина, см
# clasts: [('Длина, м', tensor([0.9207])), ('Длина, см', tensor([0.9445])), ('Ширина, м', tensor([0.9873])), ('Длина деки, см', tensor([0.9226])), ('Ширина встраивания, см', tensor([0.9414])), ('Макс. ширина стежка, мм', tensor([0.9349])), ('Ширина обода', tensor([0.9527])), ('Ширина рабочей поверхности, см', tensor([0.9254])), ('Ширина горлышка', tensor([0.9337])), ('Ширина колеи', tensor([0.9280]))]
#
#
# clast main: Состав ниток
# clasts: []
#
#
# clast main: Название цвета
# clasts: [('Цвет оправы', tensor([0.9204]))]
#
#
# clast main: Минимальная продолжительность партии, мин.
# clasts: []
#
#
# clast main: Минимальное число игроков
# clasts: []
#
#
# clast main: Максимальное число игроков
# clasts: [('Количество игроков', tensor([0.9224]))]
#
#
# clast main: Вид выпуска товара
# clasts: [('Форма выпуска продукта', tensor([0.9429])), ('Вид продукта', tensor([0.9353]))]
#
#
# clast main: Целевая аудитория
# clasts: [('Целевая аудитория игры', tensor([0.9416]))]
#
#
# clast main: Вид настольной игры
# clasts: [('Жанр настольной игры', tensor([0.9670])), ('Автор настольной игры', tensor([0.9355]))]
#
#
# clast main: Артикул
# clasts: [('Составитель', tensor([0.9247]))]
#
#
# clast main: Материал чехла
# clasts: [('Съемный чехол', tensor([0.9670])), ('Вид чехла', tensor([0.9592])), ('Размер чехла', tensor([0.9342])), ('Фиксация чехла', tensor([0.9379])), ('Подкладка чехла', tensor([0.9519])), ('Особенность покрытия чехла', tensor([0.9221])), ('Особенности чехлов', tensor([0.9358]))]
#
#
# clast main: Материал наполнителя
# clasts: [('Наполнитель', tensor([0.9724])), ('Особенности наполнителя', tensor([0.9359])), ('Состав наполнителя', tensor([0.9674])), ('Тип наполнителя', tensor([0.9481]))]
#
#
# clast main: Комплектация
# clasts: [('Размерность комплекта', tensor([0.9430])), ('Состав комплекта', tensor([0.9585])), ('Абажур в комплекте', tensor([0.9379])), ('Крышка в комплекте', tensor([0.9228])), ('Конфигурация', tensor([0.9236])), ('Комплект аксессуаров', tensor([0.9221])), ('Раковина в комплекте', tensor([0.9225])), ('Комплектация постера', tensor([0.9333])), ('Инструменты в комплекте', tensor([0.9329])), ('Аксессуары в комплекте', tensor([0.9298])), ('Оснастка в комплекте', tensor([0.9722])), ('Что в комплекте', tensor([0.9656])), ('Состав набора', tensor([0.9234])), ('Оснастка', tensor([0.9460])), ('Комплект', tensor([0.9780])), ('Направляющая в комплекте', tensor([0.9415])), ('Реек в комплекте', tensor([0.9236])), ('Принадлежности в комплекте', tensor([0.9382])), ('Емкости в комплекте', tensor([0.9390])), ('Насадки в комплекте', tensor([0.9418])), ('Подставка в комплекте', tensor([0.9493])), ('Комплектация набора', tensor([0.9716])), ('Доп. комплектация', tensor([0.9781])), ('Дополнительная комплектация', tensor([0.9356])), ('Комплектация мольберта', tensor([0.9279])), ('Метиз в комплекте', tensor([0.9299])), ('Вид набора', tensor([0.9222])), ('Вид комплектующих', tensor([0.9428])), ('Кейс в комплекте', tensor([0.9413])), ('Вид комплектующего', tensor([0.9533])), ('Комплектация сетки', tensor([0.9337]))]
#
#
# clast main: Объем, мл
# clasts: [('Объем, л', tensor([0.9444])), ('Объем, Л', tensor([0.9444])), ('Объем', tensor([0.9422])), ('Объем, мл.', tensor([1.0000])), ('Объем диспенсера, мл', tensor([0.9462]))]
#
#
# clast main: Фильтр
# clasts: [('Исполнение фильтра', tensor([0.9658])), ('Вид фильтра вытяжки', tensor([0.9368])), ('Фильтры', tensor([1.0000])), ('Вид фильтра', tensor([0.9756])), ('Корпус фильтра', tensor([0.9524])), ('Дезодорирующий фильтр', tensor([0.9463])), ('Плазменный фильтр', tensor([0.9305])), ('Класс фильтрации', tensor([0.9378])), ('Класс HEPA-фильтра', tensor([0.9288])), ('Материал фильтра', tensor([0.9691])), ('Особенности фильтра', tensor([0.9449])), ('Типоразмер фильтра', tensor([0.9568])), ('Способ действия фильтра', tensor([0.9372])), ('Угольный фильтр', tensor([0.9279])), ('Вид фильтров', tensor([0.9756])), ('Фильтрация', tensor([0.9801])), ('Наличие фильтра', tensor([0.9740]))]
#
#
# clast main: Тип цоколя
# clasts: []
#
#
# clast main: Вид ламп
# clasts: [('Форма лампочки', tensor([0.9538])), ('Вид LED лампы', tensor([0.9831])), ('Назначение лампы', tensor([0.9423])), ('Комплектация лампочками', tensor([0.9233])), ('Тип лампы', tensor([0.9788])), ('Тип лампы для террариума', tensor([0.9246])), ('Вид установленной лампы', tensor([0.9700]))]
#
#
# clast main: Количество ламп, шт
# clasts: []
#
#
# clast main: Макс. мощность ламп, Вт
# clasts: [('Эквивалентная мощность лампы накаливания, Вт', tensor([0.9209]))]
#
#
# clast main: Материал плафона
# clasts: []
#
#
# clast main: Вид питания
# clasts: [('Тип питания', tensor([0.9750])), ('Вид блюда', tensor([0.9253])), ('Питание', tensor([0.9677])), ('Питание от', tensor([0.9501])), ('Тип элементов питания', tensor([0.9282])), ('Тип питания устройства', tensor([0.9292])), ('Способ питания', tensor([0.9618])), ('Коннектор питания', tensor([0.9393])), ('Питание ЗУ', tensor([0.9459])), ('Элементы питания', tensor([0.9317])), ('Источник питания', tensor([0.9235]))]
#
#
# clast main: Цвет плафона
# clasts: []
#
#
# clast main: Площадь освещения, кв.м
# clasts: []
#
#
# clast main: Тип выключателя
# clasts: [('Тип электроподключения', tensor([0.9283])), ('Наличие выключателя', tensor([0.9383]))]
#
#
# clast main: Партномер
# clasts: [('Коннектор 1', tensor([0.9375])), ('Коннектор 2', tensor([0.9375])), ('Таймер', tensor([0.9315])), ('Нитеобрезатель', tensor([0.9210]))]
#
#
# clast main: Состав
# clasts: [('Особенности состава', tensor([0.9306])), ('Основа состава', tensor([0.9490])), ('Назначение состава', tensor([0.9422]))]
#
#
# clast main: Назначение средства для стирки
# clasts: [('Назначение моющего, чистящего средства', tensor([0.9265]))]
#
#
# clast main: Название аромата
# clasts: [('Аромат', tensor([0.9552])), ('Вид ароматизатора', tensor([0.9262])), ('Классификация аромата', tensor([0.9354])), ('Ароматизация', tensor([0.9342])), ('Аромат 18+', tensor([0.9552])), ('Вкус ароматизатора', tensor([0.9204]))]
#
#
# clast main: Размер упаковки (Длина х Ширина х Высота), см
# clasts: []
#
#
# clast main: Вид стирки
# clasts: [('Число стирок', tensor([0.9480])), ('Режим стирки', tensor([0.9494])), ('Вид стиральной машины', tensor([0.9351])), ('Программы стирки', tensor([0.9315])), ('Класс стирки', tensor([0.9517]))]
#
#
# clast main: Форма выпуска средства
# clasts: [('Форма выпуска', tensor([0.9680])), ('Форма выпуска средств от вредителей', tensor([0.9323])), ('Форма выпуска мыла', tensor([0.9217])), ('Форма выпуска препарата', tensor([0.9533])), ('Форма выпуска смеси', tensor([0.9309]))]
#
#
# clast main: Особенности применения
# clasts: [('Особенности 18+', tensor([0.9460])), ('Особенности', tensor([0.9460])), ('Применение', tensor([0.9416])), ('Способ применения', tensor([0.9308])), ('Эффект от использования', tensor([0.9235])), ('Функциональные особенности', tensor([0.9438])), ('Особенности изделия', tensor([0.9203])), ('Особенности рольставен', tensor([0.9295])), ('Особенности оснастки', tensor([0.9367])), ('Особое применение подгузников', tensor([0.9272])), ('Особенности средства', tensor([0.9548])), ('Особенности жилета', tensor([0.9266])), ('Особенности оформления', tensor([0.9218])), ('Объекты применения', tensor([0.9246]))]
#
#
# clast main: Единиц в одном товаре
# clasts: []
#
#
# clast main: Гарантийный срок
# clasts: [('Гарантия', tensor([0.9323]))]
#
#
# clast main: Отделка
# clasts: [('Материал подкладки/внутренней отделки', tensor([0.9238])), ('Оформление', tensor([0.9259])), ('Внешняя отделка', tensor([0.9740])), ('Внутренняя отделка', tensor([0.9406]))]
#
#
# clast main: Застежка пододеяльника
# clasts: [('Застежка наволочки/чехла', tensor([0.9290])), ('Вид застёжки', tensor([0.9360])), ('Вид застежки', tensor([0.9360])), ('Тип застежки подгузника', tensor([0.9225])), ('Застежка', tensor([0.9455]))]
#
#
# clast main: Образец цвета
# clasts: [('Число цветов, шт', tensor([0.9211])), ('Цветность', tensor([0.9337])), ('Сорт цветов', tensor([0.9351])), ('Цвет отражателя', tensor([0.9366]))]
#
#
# clast main: Размер простыни
# clasts: []
#
#
# clast main: Размер наволочки
# clasts: [('Размер подгузника', tensor([0.9250]))]
#
#
# clast main: Размер пододеяльника
# clasts: []
#
#
# clast main: Комплектация постельного белья
# clasts: []
#
#
# clast main: Вид простыни
# clasts: [('Вид пропитки', tensor([0.9206]))]
#
#
# clast main: Размер крышки, см
# clasts: [('Материал крышки', tensor([0.9221]))]
#
#
# clast main: Совместимые плиты
# clasts: [('Материал плиты', tensor([0.9344]))]
#
#
# clast main: Крышка
# clasts: [('Форма крышки', tensor([0.9447])), ('Вид крыши', tensor([0.9327])), ('С крышкой', tensor([0.9858]))]
#
#
# clast main: Особенности посуды
# clasts: [('Особенности посудомоечной машины', tensor([0.9261])), ('Особенности одноразовой посуды', tensor([0.9511])), ('Особенности детской посуды', tensor([0.9417]))]
#
#
# clast main: Диаметр дна, см
# clasts: [('Глубина, см', tensor([0.9303]))]
#
#
# clast main: Помещение
# clasts: [('Тип помещения', tensor([0.9522])), ('Комната', tensor([0.9642])), ('Назначение (помещение)', tensor([0.9512])), ('Комнаты и помещения', tensor([0.9316]))]
#
#
# clast main: Марка эмали
# clasts: []
#
#
# clast main: Количество компонентов
# clasts: [('Количество элементов, шт', tensor([0.9424]))]
#
#
# clast main: Возможность колеровки
# clasts: []
#
#
# clast main: Степень блеска покрытия
# clasts: []
#
#
# clast main: Время высыхания, часов
# clasts: []
#
#
# clast main: Основа краски
# clasts: [('Вид краски', tensor([0.9435])), ('Эффект краски', tensor([0.9298]))]
#
#
# clast main: Область применения состава
# clasts: [('Область использования', tensor([0.9553])), ('Область применения', tensor([0.9612])), ('Сфера применения', tensor([0.9317])), ('Зона применения', tensor([0.9312]))]
#
#
# clast main: Назначение
# clasts: [('Предназначение', tensor([0.9279])), ('Назначение приправы', tensor([0.9696])), ('Назначение БАД', tensor([0.9437])), ('Назначение рольставен', tensor([0.9487])), ('Назначение прицела', tensor([0.9219])), ('Материал назначения', tensor([0.9553])), ('Назначение копилки', tensor([0.9371])), ('Назначение ', tensor([1.0000])), ('Назначение порожка', tensor([0.9479])), ('Назначение верстака', tensor([0.9283])), ('Назначение напильника', tensor([0.9484])), ('Назначение подставки', tensor([0.9281])), ('Назначение закваски', tensor([0.9435]))]
#
#
# clast main: Работы
# clasts: [('Режимы работы', tensor([0.9287])), ('Действие', tensor([0.9254]))]
#
#
# clast main: Можно мыть
# clasts: []
#
#
# clast main: Способ нанесения
# clasts: [('Принцип нанесения', tensor([0.9207])), ('Метод нанесения', tensor([0.9795])), ('Способ ввода', tensor([0.9291]))]
#
#
# clast main: Расход, л/м2
# clasts: [('Расход', tensor([0.9647]))]
#
#
# clast main: Аэрозоль
# clasts: []
#
#
# clast main: Тип растворителя
# clasts: [('Тип раствора', tensor([0.9699]))]
#
#
# clast main: Вид шампура
# clasts: []
#
#
# clast main: Материал рукояти
# clasts: [('Ручки', tensor([0.9218])), ('Форма рукояти', tensor([0.9430])), ('Материал ручки', tensor([0.9477])), ('Ручка катушки', tensor([0.9215])), ('Конструкция рукоятки', tensor([0.9613])), ('Тип рукоятки', tensor([0.9528])), ('Ручка', tensor([0.9218])), ('Материал рукоятки', tensor([0.9969])), ('Вид рукояток ножниц', tensor([0.9245])), ('Телескопическая рукоятка', tensor([0.9293])), ('Покрытие ручки', tensor([0.9256])), ('Материал ручки (упора)', tensor([0.9256])), ('Съемная ручка', tensor([0.9277]))]
#
#
# clast main: Вибрация
# clasts: []
#
#
# clast main: Размер БДСМ-атрибутики
# clasts: []
#
#
# clast main: Пол
# clasts: [('Вид пола', tensor([0.9606]))]
#
#
# clast main: Назначение товара 18+
# clasts: []
#
#
# clast main: Размер секс-игрушек
# clasts: []
#
#
# clast main: Тип мастурбатора
# clasts: []
#
#
# clast main: Вид насадки
# clasts: [('Насадки', tensor([0.9723])), ('Вид оснастки', tensor([0.9356])), ('Насадки пароочистителя', tensor([0.9208])), ('Вид насадки пылесоса', tensor([0.9208])), ('Тип насадки', tensor([0.9784])), ('Вид установки', tensor([0.9294])), ('Виды насадок', tensor([1.0000])), ('Вид присадки', tensor([0.9442])), ('Форма насадки', tensor([0.9660])), ('Особенности насадок', tensor([0.9460])), ('Вид средства', tensor([0.9223])), ('Со сменными насадками', tensor([0.9216]))]
#
#
# clast main: Вид стимулятора
# clasts: [('Тип стимулятора', tensor([0.9811]))]
#
#
# clast main: Количество внешних карманов
# clasts: [('Кол-во внешних карманов', tensor([0.9358]))]
#
#
# clast main: Количество внутренних отделений
# clasts: [('Количество отделений', tensor([0.9341])), ('Количество внутренних отсеков 3.5"', tensor([0.9597]))]
#
#
# clast main: Консистенция краски/клея
# clasts: []
#
#
# clast main: Цветовые эффекты
# clasts: [('Эффект', tensor([0.9208])), ('Цветовая гамма', tensor([0.9281])), ('Эффекты', tensor([0.9208]))]
#
#
# clast main: Форма выпуска краски
# clasts: []
#
#
# clast main: Вид ручки
# clasts: [('Высота ручек, см', tensor([0.9217])), ('Тип дверной ручки', tensor([0.9571])), ('Длина ручки', tensor([0.9528])), ('Форма ручки', tensor([0.9668])), ('Вид мебельной ручки', tensor([0.9308])), ('Тормозные ручки', tensor([0.9232])), ('Дверная ручка', tensor([0.9681])), ('Длина ручки, см', tensor([0.9441])), ('Рука', tensor([0.9310])), ('Телескопическая ручка', tensor([0.9386])), ('Назначение ручки', tensor([0.9469]))]
#
#
# clast main: Цвет чернил
# clasts: []
#
#
# clast main: Толщина линии, мм
# clasts: [('Толщина стенок, мм', tensor([0.9281])), ('Толщина, мкм', tensor([0.9420])), ('Толщина звена, мм (дюймы)', tensor([0.9289])), ('Мин. толщина слоя, мм', tensor([0.9233])), ('Толщина ленты, мм', tensor([0.9516]))]
#
#
# clast main: Плотность, г/м2
# clasts: [('Плотность бумаги, г/м2', tensor([0.9336])), ('Плотность ткани, г/м2', tensor([0.9487])), ('Плотность пасты', tensor([0.9433]))]
#
#
# clast main: Размер одежды/аксессуара для животных
# clasts: [('Размер обуви для животных', tensor([0.9389])), ('Размер товаров для животных', tensor([0.9344]))]
#
#
# clast main: Сезон
# clasts: [('Сезон снасти', tensor([0.9420])), ('Сезонность', tensor([0.9725]))]
#
#
# clast main: Особенности одежды, обуви
# clasts: [('Особенности спортивной обуви', tensor([0.9452])), ('Тип обуви', tensor([0.9360]))]
#
#
# clast main: Размер животного
# clasts: []
#
#
# clast main: Вид одежды
# clasts: [('Тип упаковки одежды', tensor([0.9245])), ('Вид ткани', tensor([0.9208]))]
#
#
# clast main: Предназначено для
# clasts: [('Для кого', tensor([0.9257])), ('Подходит для', tensor([0.9390]))]
#
#
# clast main: Содержание мяса, субпродуктов, %
# clasts: []
#
#
# clast main: Порода собаки
# clasts: [('Порода кошки', tensor([0.9275]))]
#
#
# clast main: Основной ингредиент
# clasts: [('Основной компонент', tensor([0.9258]))]
#
#
# clast main: Возраст животного
# clasts: []
#
#
# clast main: Особые потребности
# clasts: []
#
#
# clast main: Вкус корма для животных
# clasts: [('Консистенция корма для животных', tensor([0.9568])), ('Подходит для корма', tensor([0.9204]))]
#
#
# clast main: Условия хранения
# clasts: [('Условия и сроки хранения', tensor([0.9463]))]
#
#
# clast main: Упаковка консервированных кормов
# clasts: []
#
#
# clast main: Минеральные вещества
# clasts: [('МНН/Действующее вещество', tensor([0.9255])), ('Минерализация', tensor([0.9338]))]
#
#
# clast main: Класс корма
# clasts: [('Ступень кормления', tensor([0.9217]))]
#
#
# clast main: Длина большей стороны, см
# clasts: []
#
#
# clast main: Длина меньшей стороны, см
# clasts: []
#
#
# clast main: Наполнитель лежака/домика для животных
# clasts: []
#
#
# clast main: Форма выпуска корма
# clasts: []
#
#
# clast main: Материал подошвы обуви
# clasts: []
#
#
# clast main: Вид каблука
# clasts: [('Высота каблука, см', tensor([0.9243]))]
#
#
# clast main: Материал стельки
# clasts: [('Вид стельки', tensor([0.9334]))]
#
#
# clast main: Российский размер (обуви)
# clasts: [('Размер обуви', tensor([0.9336]))]
#
#
# clast main: Полнота
# clasts: []
#
#
# clast main: Особенности модели
# clasts: [('Модель', tensor([0.9351]))]
#
#
# clast main: Внутренний материал
# clasts: [('Внутреннее покрытие', tensor([0.9221])), ('Материал внутренней поверхности', tensor([0.9592])), ('Материал внутреннего бака', tensor([0.9590]))]
#
#
# clast main: Посадка
# clasts: []
#
#
# clast main: Спортивное назначение
# clasts: [('Спортивные', tensor([0.9324]))]
#
#
# clast main: Коллекция
# clasts: [('Коллекция (год)', tensor([0.9597]))]
#
#
# clast main: Размер производителя
# clasts: [('Размер изделия', tensor([0.9275])), ('Производитель', tensor([0.9273]))]
#
#
# clast main: Бренд в одежде и обуви
# clasts: [('Серия в одежде и обуви', tensor([0.9222]))]
#
#
# clast main: Праздник
# clasts: []
#
#
# clast main: Эффект от использования уходовой косметики
# clasts: []
#
#
# clast main: Тип кожи
# clasts: []
#
#
# clast main: Возрастной диапазон
# clasts: [('Возраст', tensor([0.9241]))]
#
#
# clast main: Тип волос
# clasts: []
#
#
# clast main: Вид средства для ухода
# clasts: [('Вид ухода', tensor([0.9490]))]
#
#
# clast main: Бьюти-ингредиент
# clasts: []
#
#
# clast main: Материал щетины
# clasts: [('Жесткость щетины', tensor([0.9328])), ('Материал щетины щетки', tensor([0.9850]))]
#
#
# clast main: Вид парикмахерской расчески
# clasts: [('Виды парикмахерских ножниц', tensor([0.9432]))]
#
#
# clast main: Дней до замены
# clasts: []
#
#
# clast main: Режим ношения
# clasts: [('Режимы', tensor([0.9238])), ('Способ ношения', tensor([0.9358]))]
#
#
# clast main: Особенности контактных линз
# clasts: [('Материал контактных линз', tensor([0.9333])), ('Тип контактных линз', tensor([0.9503]))]
#
#
# clast main: Кислородопропускание, Dk/t
# clasts: []
#
#
# clast main: Эффект интимного средства
# clasts: []
#
#
# clast main: Признак 18+
# clasts: [('Индикация', tensor([0.9244])), ('Индикаторы', tensor([0.9305])), ('Признак Меркурий', tensor([0.9323]))]
#
#
# clast main: Уровень шума (при работе), дБ
# clasts: [('Макс. уровень шума, дБ', tensor([0.9454]))]
#
#
# clast main: Вид ингалятора
# clasts: []
#
#
# clast main: Мин. размер частиц, мкм
# clasts: []
#
#
# clast main: Скорость ингаляции, мл/мин
# clasts: []
#
#
# clast main: Вид средства для обуви/одежды
# clasts: []
#
#
# clast main: Размер рюкзака
# clasts: [('Вид рюкзака', tensor([0.9372])), ('Размер чемодана', tensor([0.9202]))]
#
#
# clast main: Особенности конструкции сумки
# clasts: []
#
#
# clast main: Длина шнура, м
# clasts: [('Длина шнура питания, м', tensor([0.9332])), ('Шнуровка', tensor([0.9419]))]
#
#
# clast main: Системы защиты
# clasts: [('Вид защиты', tensor([0.9248])), ('Защита', tensor([0.9378])), ('Технологии защиты', tensor([0.9355]))]
#
#
# clast main: Материал чаши
# clasts: [('Материал чаши гриля', tensor([0.9339]))]
#
#
# clast main: Планетарный механизм
# clasts: []
#
#
# clast main: Тип миксера
# clasts: []
#
#
# clast main: Вращающаяся чаша
# clasts: []
#
#
# clast main: Количество скоростей
# clasts: [('Индекс скорости', tensor([0.9281])), ('Переключение скоростей', tensor([0.9261])), ('Число скоростей', tensor([0.9918])), ('Скорость потока', tensor([0.9264])), ('Класс скорости', tensor([0.9259])), ('Регулировка скорости', tensor([0.9277])), ('Кол-во скоростей', tensor([0.9287]))]
#
#
# clast main: Турборежим
# clasts: [('Турбонаддув', tensor([0.9758]))]
#
#
# clast main: Насадки приборов для измельчения продуктов
# clasts: []
#
#
# clast main: Конструктивные особенности
# clasts: [('Технологические особенности', tensor([0.9231])), ('Конструктивные особенности вытяжки', tensor([0.9408])), ('Конструктивные особенности весов', tensor([0.9379])), ('Особенности конструкции', tensor([0.9430]))]
#
#
# clast main: Мощность, Вт
# clasts: [('Макс. мощность, Вт', tensor([0.9472])), ('Потребляемая мощность, Вт', tensor([0.9513])), ('Максимальная мощность, Вт', tensor([0.9323])), ('Мощность, кВт', tensor([0.9739])), ('Мощность нагрева, Вт', tensor([0.9399])), ('Настройка мощности', tensor([0.9372])), ('Усиление, мощность', tensor([0.9243]))]
#
#
# clast main: Индикация и сигналы
# clasts: []
#
#
# clast main: Конструктивные особенности тепловых приборов
# clasts: []
#
#
# clast main: Назначение держателя для кухни
# clasts: [('Крепление держателя для кухни', tensor([0.9331]))]
#
#
# clast main: Высота, см
# clasts: [('Высота подошвы, см', tensor([0.9382])), ('Высота, мм', tensor([0.9781])), ('Высота голенища, см', tensor([0.9307])), ('Высота излива, мм', tensor([0.9506])), ('Высота поддона', tensor([0.9372])), ('Высота, м', tensor([0.9809])), ('Высота', tensor([0.9817]))]
#
#
# clast main: Конструкция чайника
# clasts: [('Особенности чайника', tensor([0.9279]))]
#
#
# clast main: Тип управления
# clasts: [('Система управления', tensor([0.9226])), ('Управление', tensor([0.9450])), ('Опции управления', tensor([0.9254])), ('Для управления', tensor([0.9263])), ('Вид управления', tensor([0.9739])), ('Управление моделью', tensor([0.9254]))]
#
#
# clast main: Внутреннее покрытие бака
# clasts: []
#
#
# clast main: Максимальная мощность, кВт
# clasts: [('Макс. мощность конвекции, Вт', tensor([0.9281]))]
#
#
# clast main: Размеры, мм (ШхГхВ)
# clasts: [('Размер (ДхШхВ), см', tensor([0.9401])), ('Габариты (ДхШхВ, см)', tensor([0.9339])), ('Габариты (ДхШхВ, мм)', tensor([0.9402]))]
#
#
# clast main: Объем бака (номинальный), л
# clasts: [('Объем бака (фактический), л', tensor([0.9513]))]
#
#
# clast main: Макс. температура, °С
# clasts: [('Максимальная температура', tensor([0.9380])), ('Макс. температура нагрева, °С', tensor([0.9695])), ('Макс. температура эксплуатации, С°', tensor([0.9480])), ('Макс. температура теплоносителя, °C', tensor([0.9592]))]
#
#
# clast main: Установка водонагревателя
# clasts: [('Защита водонагревателя', tensor([0.9279])), ('Тип водонагревателя', tensor([0.9340]))]
#
#
# clast main: Форма бака
# clasts: [('Форма мусорного бака', tensor([0.9353])), ('Форма бойка', tensor([0.9472])), ('Форма бака для белья', tensor([0.9277]))]
#
#
# clast main: Количество температурных режимов
# clasts: [('Температурный режим', tensor([0.9632]))]
#
#
# clast main: Дополнительные режимы
# clasts: [('Дополнительные режимы вытяжки', tensor([0.9341]))]
#
#
# clast main: Диаметр насадки
# clasts: []
#
#
# clast main: Насадки для приборов по уходу за волосами
# clasts: []
#
#
# clast main: Особенности фена, выпрямителя волос
# clasts: []
#
#
# clast main: Программы приготовления
# clasts: []
#
#
# clast main: Направление открывания дверцы
# clasts: [('Направление открытия', tensor([0.9663])), ('Открывание', tensor([0.9274])), ('Направление открывания дверей', tensor([0.9355]))]
#
#
# clast main: Технология СВЧ
# clasts: [('Технология', tensor([0.9614])), ('Технология производства', tensor([0.9323])), ('Технологии', tensor([0.9614])), ('Поддержка технологий', tensor([0.9224])), ('Облачные технологии', tensor([0.9282]))]
#
#
# clast main: Открывание дверцы микроволновой печи
# clasts: [('Внутреннее покрытие микроволновой печи', tensor([0.9231])), ('Особенности микроволновой печи', tensor([0.9336]))]
#
#
# clast main: Макс. мощность гриля, Вт
# clasts: []
#
#
# clast main: Диаметр поворотного стола, см
# clasts: []
#
#
# clast main: Расположение
# clasts: [('Размещение', tensor([0.9527])), ('Расположение сиденья', tensor([0.9330])), ('Расположение изголовья', tensor([0.9419])), ('Расположение резьбы', tensor([0.9201])), ('Расположение полки', tensor([0.9211])), ('Расположение детали', tensor([0.9262])), ('Положение', tensor([0.9229])), ('Расположение бачка', tensor([0.9271])), ('Расположение тостов', tensor([0.9495])), ('Расположение БП', tensor([0.9368]))]
#
#
# clast main: Режимы работы микроволновой печи
# clasts: []
#
#
# clast main: Доп. принадлежности ПММ
# clasts: []
#
#
# clast main: Инверторный двигатель
# clasts: [('Двигатель', tensor([0.9240]))]
#
#
# clast main: Вид посудомоечной машины
# clasts: [('Функционал посудомоечной машины', tensor([0.9504])), ('Назначение средств для посудомоечных машин', tensor([0.9280])), ('Мойка в посудомоечной машине', tensor([0.9563]))]
#
#
# clast main: Класс энергопотребления
# clasts: [('Класс энергоэффективности', tensor([0.9575])), ('Класс сезонной энергоэффективности', tensor([0.9202]))]
#
#
# clast main: Класс мойки
# clasts: [('Класс машинки', tensor([0.9312])), ('Класс', tensor([0.9577]))]
#
#
# clast main: Класс сушки
# clasts: []
#
#
# clast main: Программы мойки
# clasts: []
#
#
# clast main: Расход энергии за цикл, кВт
# clasts: []
#
#
# clast main: Отложенный старт, ч
# clasts: [('Отложенный старт', tensor([0.9926]))]
#
#
# clast main: Назначение чехла для мебели
# clasts: []
#
#
# clast main: Стиль
# clasts: [('Стиль дизайна', tensor([0.9566])), ('Стиль часов', tensor([0.9394])), ('Стиль оправы', tensor([0.9742])), ('Дизайн', tensor([0.9274])), ('Стиль игры', tensor([0.9287]))]
#
#
# clast main: Вид сумки
# clasts: []
#
#
# clast main: Формат А4
# clasts: [('Форма мойки', tensor([0.9203])), ('Формат издания', tensor([0.9356])), ('Форма оправы', tensor([0.9208])), ('Поддерживаемые форматы', tensor([0.9402])), ('Формат пакета', tensor([0.9216])), ('Форматы изображений', tensor([0.9310])), ('Формат/размеры', tensor([0.9557])), ('Формат пленки', tensor([0.9320])), ('Вид формы', tensor([0.9203])), ('Формат фона, м', tensor([0.9330])), ('Форматы воспроизведения', tensor([0.9241]))]
#
#
# clast main: Длина плечевого ремня, см
# clasts: [('Плечевой ремень', tensor([0.9619]))]
#
#
# clast main: Форма поставки матраса
# clasts: [('Тип матраса', tensor([0.9212]))]
#
#
# clast main: Минимальная жесткость
# clasts: []
#
#
# clast main: Максимальная жесткость
# clasts: [('Жесткость', tensor([0.9333]))]
#
#
# clast main: Вид пружинного блока
# clasts: []
#
#
# clast main: Конструкция матраса
# clasts: [('Вид матраса', tensor([0.9446])), ('Особенности матраса', tensor([0.9231])), ('Матрас в комплекте', tensor([0.9254])), ('Матрас раскладушки', tensor([0.9411]))]
#
#
# clast main: Информация о размерах
# clasts: []
#
#
# clast main: Минимальная температура
# clasts: [('Нижний порог температуры, °C', tensor([0.9270])), ('Минимальная температура эксплуатации', tensor([0.9491]))]
#
#
# clast main: Вид соуса
# clasts: [('Консистенция соуса', tensor([0.9588]))]
#
#
# clast main: Степень остроты
# clasts: [('Степень растяжимости', tensor([0.9259]))]
#
#
# clast main: Назначение масла/соуса
# clasts: []
#
#
# clast main: Название вкуса
# clasts: [('Вкус', tensor([0.9360])), ('Вид вкуса', tensor([0.9372]))]
#
#
# clast main: Степень обжарки
# clasts: []
#
#
# clast main: Интенсивность вкуса
# clasts: [('Вкусовой акцент (вкус)', tensor([0.9377]))]
#
#
# clast main: Способ приготовления кофе
# clasts: [('Тип используемого кофе', tensor([0.9218])), ('Рецепт кофе', tensor([0.9522]))]
#
#
# clast main: Степень помола
# clasts: [('Степень затемнения', tensor([0.9241])), ('Количество степеней помола', tensor([0.9566])), ('Степень затемнения, %', tensor([0.9241])), ('Регулировка степени помола', tensor([0.9232]))]
#
#
# clast main: Состав кофе
# clasts: [('Сорт кофе', tensor([0.9384]))]
#
#
# clast main: Вид шоколада
# clasts: [('Форма выпуска шоколада', tensor([0.9415]))]
#
#
# clast main: Не содержит
# clasts: []
#
#
# clast main: Особенности напитков, продуктов питания
# clasts: []
#
#
# clast main: Вид лапши
# clasts: []
#
#
# clast main: Амортизация
# clasts: [('Количество амортизаторов', tensor([0.9367])), ('Задний амортизатор', tensor([0.9379])), ('Система амортизации', tensor([0.9488])), ('Жесткость амортизаторов', tensor([0.9372]))]
#
#
# clast main: Класс тренажера
# clasts: [('Особенности тренажеров', tensor([0.9256])), ('Привод тренажёра', tensor([0.9301])), ('Вид тренажера', tensor([0.9528]))]
#
#
# clast main: Питание тренажера
# clasts: []
#
#
# clast main: Измерительные датчики
# clasts: [('Тип датчика', tensor([0.9539])), ('Датчики', tensor([0.9745])), ('Встроенные датчики', tensor([0.9542])), ('Датчик', tensor([0.9745])), ('Датчик сканера', tensor([0.9425])), ('Датчик алкотестера', tensor([0.9326])), ('Технология датчиков', tensor([0.9469])), ('Датчики контроллера', tensor([0.9268]))]
#
#
# clast main: Российский размер
# clasts: []
#
#
# clast main: Рост
# clasts: [('Рекомендуемый рост, см', tensor([0.9266])), ('Увеличение', tensor([0.9620]))]
#
#
# clast main: Инструкция по уходу
# clasts: []
#
#
# clast main: Рост модели на фото
# clasts: []
#
#
# clast main: Размер на модели
# clasts: [('Масштаб модели', tensor([0.9511]))]
#
#
# clast main: Рисунок
# clasts: [('Вид раскраски', tensor([0.9326])), ('3D-изображение', tensor([0.9289])), ('Подгонка рисунка', tensor([0.9684])), ('Рисунок на обивке', tensor([0.9451])), ('Художник', tensor([0.9301])), ('Вид росписи', tensor([0.9250]))]
#
#
# clast main: Цель
# clasts: []
#
#
# clast main: Вид протеина
# clasts: [('Вид прикормки', tensor([0.9209])), ('Вид кинезиотейпа', tensor([0.9210])), ('Вид полозьев', tensor([0.9275])), ('Вид порожка', tensor([0.9216])), ('Тип протеза', tensor([0.9360])), ('Вид пробирки', tensor([0.9205]))]
#
#
# clast main: Форма выпуска спортивного питания
# clasts: [('Тип спортивного питания', tensor([0.9393]))]
#
#
# clast main: Энергетическая ценность: ккал в 1 порции
# clasts: [('Энергетическая ценность, ккал/100 г', tensor([0.9497]))]
#
#
# clast main: Белок: грамм в 1 порции
# clasts: []
#
#
# clast main: Жиры: грамм в 1 порции
# clasts: []
#
#
# clast main: Углеводы: грамм в 1 порции
# clasts: []
#
#
# clast main: Формат (типоразмер) элементов питания
# clasts: []
#
#
# clast main: Степень защиты от влаги и пыли
# clasts: []
#
#
# clast main: Оттенок света
# clasts: [('Свет', tensor([0.9614])), ('Подсветка', tensor([0.9339])), ('Цвет свечения', tensor([0.9283])), ('С подсветкой', tensor([0.9304])), ('Тип светосилы', tensor([0.9230])), ('Цвет подсветки', tensor([0.9412]))]
#
#
# clast main: Комплектация элементом питания
# clasts: []
#
#
# clast main: Комплектация зарядным устройством
# clasts: [('Возможность зарядки устройств', tensor([0.9511])), ('Способ зарядки', tensor([0.9252])), ('Вид зарядного устройства', tensor([0.9576])), ('Комплектация зарядного устройства', tensor([1.0000])), ('Насадки для зарядного устройства', tensor([0.9430]))]
#
#
# clast main: Особенности фонаря
# clasts: []
#
#
# clast main: Назначение сноуборда
# clasts: [('Прогиб сноуборда', tensor([0.9248])), ('Ростовка сноуборда', tensor([0.9336]))]
#
#
# clast main: Тип крепления сноуборда
# clasts: [('Форма сноуборда', tensor([0.9238])), ('Система креплений сноуборда', tensor([0.9455]))]
#
#
# clast main: Модельный год
# clasts: []
#
#
# clast main: Назначение боксёрских перчаток
# clasts: [('Назначение перчаток', tensor([0.9293]))]
#
#
# clast main: Вид спорта
# clasts: [('Вид водного спорта', tensor([0.9244])), ('Вид спортивной игры', tensor([0.9617])), ('Вид спортивного бандажа', tensor([0.9324])), ('Вид спортивных игр', tensor([0.9617]))]
#
#
# clast main: Длина рукава
# clasts: []
#
#
# clast main: Длина изделия, см
# clasts: [('Вид изделия', tensor([0.9378]))]
#
#
# clast main: Декоративные элементы
# clasts: [('Декоративный элемент', tensor([1.0000])), ('Элемент лепного декора', tensor([0.9438])), ('Вид элемента', tensor([0.9259])), ('Конструкция элемента', tensor([0.9275])), ('Вид декоративной отсыпки', tensor([0.9327]))]
#
#
# clast main: Количество слоев
# clasts: []
#
#
# clast main: Система
# clasts: [('Операционная система', tensor([0.9490])), ('Автоматические системы', tensor([0.9361])), ('Системы обнаружения', tensor([0.9343])), ('Механизм', tensor([0.9365])), ('Система помола', tensor([0.9686])), ('Система качания', tensor([0.9398]))]
#
#
# clast main: Защита от влаги
# clasts: []
#
#
# clast main: Конструкция наушников
# clasts: [('Крепление наушников', tensor([0.9571])), ('Управление наушниками', tensor([0.9389])), ('Модель наушников', tensor([0.9500])), ('Особенности наушников', tensor([0.9325])), ('Разъем наушников', tensor([0.9472]))]
#
#
# clast main: True Wireless
# clasts: []
#
#
# clast main: Способ передачи звука
# clasts: [('Форматы записи звука', tensor([0.9202])), ('Характеристики звука', tensor([0.9215])), ('Имитация звука', tensor([0.9222]))]
#
#
# clast main: Складные
# clasts: [('Складная рама', tensor([0.9206]))]
#
#
# clast main: Мин. частота, Гц
# clasts: [('Макс. частота, Гц', tensor([0.9339])), ('Диапазон частот, МГц', tensor([0.9261]))]
#
#
# clast main: Подключение
# clasts: [('Вариант подключения', tensor([0.9711])), ('Подключение к нескольким устройствам', tensor([0.9271])), ('Способ подключения', tensor([0.9631])), ('Тип подключения', tensor([0.9526])), ('Подключение к электросети', tensor([0.9297])), ('Интерфейс подключения', tensor([0.9419]))]
#
#
# clast main: Импеданс, Ом
# clasts: []
#
#
# clast main: Акустическое оформление
# clasts: [('Назначение акустики', tensor([0.9450])), ('Вид акустики', tensor([0.9439])), ('Комплект акустики', tensor([0.9365]))]
#
#
# clast main: Разъем
# clasts: [('Разъемы', tensor([1.0000])), ('Разъем на блоке', tensor([0.9438])), ('Разъем на кабеле', tensor([0.9370]))]
#
#
# clast main: Длина кабеля, см
# clasts: [('Длина кабеля, м', tensor([0.9890])), ('Вид кабеля', tensor([0.9271])), ('Вид кабельной протяжки', tensor([0.9510]))]
#
#
# clast main: Материал амбушюров
# clasts: []
#
#
# clast main: Шумоподавление
# clasts: [('Шумоподавление микрофона', tensor([0.9377])), ('Шумоизоляция', tensor([0.9341])), ('Звукосниматель', tensor([0.9252])), ('Вид шумопоглощения', tensor([0.9674]))]
#
#
# clast main: Наличие микрофона
# clasts: [('Вид микрофона', tensor([0.9549])), ('Крепление микрофона', tensor([0.9268]))]
#
#
# clast main: Крепление
# clasts: [('Тип крепления', tensor([0.9575])), ('Крепление наматрасника', tensor([0.9586])), ('Крепление бейджа', tensor([0.9256])), ('Крепление карниза', tensor([0.9337])), ('Вид крепления', tensor([0.9707])), ('Покрытие крепежа', tensor([0.9377])), ('Крепление веток', tensor([0.9375])), ('Способ крепления', tensor([0.9610])), ('Крепление подушки', tensor([0.9224])), ('Место крепления', tensor([0.9682])), ('Регулировка крепления', tensor([0.9560])), ('Вид крепления дефлектора', tensor([0.9224])), ('Назначение перфорированного крепежа', tensor([0.9234])), ('Ориентация крепежа', tensor([0.9511])), ('Место крепления держателя', tensor([0.9433])), ('Усилие DIN крепления', tensor([0.9550])), ('Потолочное крепление', tensor([0.9653])), ('Входное крепление', tensor([0.9362])), ('Выходное крепление', tensor([0.9356])), ('Крепление шлифлиста', tensor([0.9508])), ('Крепление АКБ', tensor([0.9250])), ('Способ установки креплений', tensor([0.9380])), ('Механизм крепления', tensor([0.9511])), ('Способ крепления/застегивания', tensor([0.9245])), ('Крепление головки к штативу', tensor([0.9299])), ('Наличие креплений', tensor([0.9779])), ('Способ крепления 18+', tensor([0.9610])), ('Крепление VESA', tensor([0.9662])), ('Крепление оголовья', tensor([0.9460])), ('Крепление щитка', tensor([0.9337]))]
#
#
# clast main: Степень защиты
# clasts: [('Защищенность', tensor([0.9246])), ('Класс защиты', tensor([0.9297])), ('Фактор защиты', tensor([0.9268]))]
#
#
# clast main: Напряжение питания, В
# clasts: [('Напряжение адаптера питания', tensor([0.9343]))]
#
#
# clast main: Сертификат
# clasts: [('Сертификат 80 PLUS', tensor([0.9427]))]
#
#
# clast main: Вид шапки
# clasts: [('Особенности шапки', tensor([0.9383])), ('Вид шляпы', tensor([0.9325])), ('Тип заклепок', tensor([0.9212])), ('Вид заклепки', tensor([0.9448]))]
#
#
# clast main: Материал подклада/внутренней отделки
# clasts: []
#
#
# clast main: Световой поток, Лм
# clasts: []
#
#
# clast main: Диаметр воздуховода, мм
# clasts: [('Диаметр воздушного штуцера', tensor([0.9300])), ('Сечение воздуховода, мм', tensor([0.9479]))]
#
#
# clast main: Вентиляция
# clasts: [('Установка вентиляции', tensor([0.9646])), ('Вид комплектующего для вентиляции', tensor([0.9245])), ('Тип вентилятора', tensor([0.9244])), ('Система вентиляции', tensor([0.9515])), ('Размещение вентиляции', tensor([0.9515])), ('Вентиляция террариума', tensor([0.9494]))]
#
#
# clast main: Форма воздуховода
# clasts: []
#
#
# clast main: Количество фаз электростанции
# clasts: []
#
#
# clast main: Назначение мебельной фурнитуры
# clasts: []
#
#
# clast main: Макс. нагрузка, кг
# clasts: [('Максимальная нагрузка, кг', tensor([0.9747])), ('Макс. нагрузка, т', tensor([0.9613]))]
#
#
# clast main: Вид ключа
# clasts: [('Особенности ключницы', tensor([0.9274])), ('Материал ключа', tensor([0.9560])), ('Стандарт ключа', tensor([0.9240])), ('Размер ключа', tensor([0.9353])), ('Особенности ключей', tensor([0.9480])), ('Количество ключей, шт', tensor([0.9222])), ('M.2 ключ E', tensor([0.9448]))]
#
#
# clast main: Крыло
# clasts: []
#
#
# clast main: Покрытие
# clasts: [('Антипригарное покрытие', tensor([0.9309])), ('Покрытие обоев', tensor([0.9229])), ('Покрытие подошвы', tensor([0.9344])), ('Покрытие корпуса', tensor([0.9465])), ('Материал покрытия', tensor([0.9724])), ('Покрытие линз', tensor([0.9240])), ('Покрытие фасада', tensor([0.9215])), ('Особенности покрытия', tensor([0.9462])), ('Покрытие рабочей поверхности', tensor([0.9255])), ('Тип покрытия', tensor([0.9577])), ('Характеристика покрытия', tensor([0.9558])), ('Покрытие приборов', tensor([0.9251])), ('Покрытие грифа', tensor([0.9247])), ('Оболочка', tensor([0.9339])), ('Материал внешнего покрытия', tensor([0.9387]))]
#
#
# clast main: Отверстия под смеситель
# clasts: []
#
#
# clast main: Клапан-автомат
# clasts: []
#
#
# clast main: Установка
# clasts: [('Место установки', tensor([0.9677])), ('Монтаж', tensor([0.9362])), ('Вариант установки', tensor([0.9645])), ('Ориентация установки', tensor([0.9517])), ('Сторона установки', tensor([0.9530])), ('Установлено', tensor([0.9350])), ('Встроенные устройства', tensor([0.9370])), ('Установка вытяжки', tensor([0.9394])), ('Возможна установка', tensor([0.9452])), ('Автоматическая установка', tensor([0.9397])), ('Настенная установка', tensor([0.9218])), ('Монтировка', tensor([0.9298])), ('Установка парктроников', tensor([0.9275])), ('Угол установки', tensor([0.9303]))]
#
#
# clast main: Минимальный размер тумбы
# clasts: []
#
#
# clast main: Год выпуска
# clasts: [('Номер выпуска', tensor([0.9212])), ('Год выпуска а/м', tensor([0.9517]))]
#
#
# clast main: Количество страниц
# clasts: [('Многоразовые страницы', tensor([0.9219]))]
#
#
# clast main: Тип книги
# clasts: [('Тип бумаги в книге', tensor([0.9526])), ('Форматы книг', tensor([0.9503]))]
#
#
# clast main: Автор на обложке
# clasts: [('Тип обложки', tensor([0.9285])), ('Вид обложки', tensor([0.9449])), ('Материал обложки', tensor([0.9556])), ('Дизайн обложки', tensor([0.9353])), ('Обложка', tensor([0.9593])), ('Назначение обложки', tensor([0.9313])), ('Оформление обложки', tensor([0.9489]))]
#
#
# clast main: Издательство
# clasts: []
#
#
# clast main: ISBN
# clasts: [('ISSN', tensor([0.9456]))]
#
#
# clast main: Автор
# clasts: [('Редактор', tensor([0.9290]))]
#
#
# clast main: Язык издания
# clasts: [('Год издания', tensor([0.9298]))]
#
#
# clast main: Комментарий
# clasts: []
#
#
# clast main: Основной жанр книги
# clasts: []
#
#
# clast main: Тираж
# clasts: []
#
#
# clast main: Оригинальное название
# clasts: [('Оригинальное название пасты', tensor([0.9498]))]
#
#
# clast main: Установка бассейна
# clasts: [('Вид бассейна', tensor([0.9389])), ('Форма бассейна', tensor([0.9272])), ('Вид оборудования для бассейна', tensor([0.9504])), ('Тип запчасти к оборудованию для бассейна', tensor([0.9293]))]
#
#
# clast main: Фильтр водяного насоса
# clasts: [('Насос', tensor([0.9245])), ('Вид насоса', tensor([0.9219]))]
#
#
# clast main: Особенности и комплектация бассейнов
# clasts: []
#
#
# clast main: Надувное дно
# clasts: [('Материал дна', tensor([0.9267])), ('Дно казана', tensor([0.9254])), ('Тип дна', tensor([0.9230])), ('Наличие дна', tensor([0.9256]))]
#
#
# clast main: Объем главного отделения, л
# clasts: []
#
#
# clast main: Специальные отделения
# clasts: [('Отделения', tensor([0.9338]))]
#
#
# clast main: Вид запчасти
# clasts: [('Вид поводка', tensor([0.9204])), ('Вид сверла', tensor([0.9246])), ('Вид шлица', tensor([0.9218])), ('Вид запчасти для инструмента', tensor([0.9202])), ('Вид добора', tensor([0.9206])), ('Вид задвижки', tensor([0.9234])), ('Вид запчасти проектора', tensor([0.9508])), ('Вид намотки', tensor([0.9246]))]
#
#
# clast main: Толщина наматрасника, см
# clasts: [('Макс. толщина слоя, мм', tensor([0.9247])), ('Толщина раскатки теста, мм', tensor([0.9212]))]
#
#
# clast main: Непромокаемый наматрасник
# clasts: [('Непромокаемые', tensor([0.9601]))]
#
#
# clast main: Назначение спецодежды
# clasts: [('Назначение спецтехники', tensor([0.9615])), ('Размер спецодежды', tensor([0.9205]))]
#
#
# clast main: Назначение горных лыж
# clasts: [('Назначение беговых лыж', tensor([0.9338])), ('Назначение для горнолыжных палок', tensor([0.9269]))]
#
#
# clast main: Серия
# clasts: []
#
#
# clast main: Иллюстратор
# clasts: []
#
#
# clast main: Партномер (артикул производителя)
# clasts: []
#
#
# clast main: Переводчик
# clasts: []
#
#
# clast main: Спальность
# clasts: []
#
#
# clast main: Форма наконечника.
# clasts: [('Форма наконечника', tensor([1.])), ('Наконечник', tensor([0.9442])), ('Форма поперечины', tensor([0.9213])), ('Тип наконечника', tensor([0.9667])), ('Материал наконечника', tensor([0.9408]))]
#
#
# clast main: Вид фломастера
# clasts: []
#
#
# clast main: Марка ТС
# clasts: [('Модель ТС', tensor([0.9227]))]
#
#
# clast main: Вид техники
# clasts: [('Вид спецтехники', tensor([0.9255])), ('Техника изображения', tensor([0.9386])), ('Тип оборудования', tensor([0.9407])), ('Вид станка', tensor([0.9350])), ('Техника валяния', tensor([0.9288])), ('Вид машинки', tensor([0.9250])), ('Вид инструмента', tensor([0.9249]))]
#
#
# clast main: Альтернативные артикулы товара
# clasts: []
#
#
# clast main: Особенности пледа и покрывала
# clasts: []
#
#
# clast main: OEM-номер
# clasts: [('Номер насечки', tensor([0.9264]))]
#
#
# clast main: Талия
# clasts: []
#
#
# clast main: Форма бутылочки/соски
# clasts: [('Вид бутылочки', tensor([0.9541]))]
#
#
# clast main: Особенности бутылочек и сосок
# clasts: []
#
#
# clast main: Приготовление напитка
# clasts: [('Вкус (напитки)', tensor([0.9444])), ('Виды напитков', tensor([0.9343]))]
#
#
# clast main: Конструкция кофеварок/кофемашин
# clasts: [('Особенности кофеварок/кофемашин', tensor([0.9425])), ('Назначение средств для кофемашины', tensor([0.9223]))]
#
#
# clast main: Сабвуфер
# clasts: [('Подключение сабвуфера', tensor([0.9394]))]
#
#
# clast main: Версия HDMI
# clasts: []
#
#
# clast main: Доп. режимы телевизора
# clasts: []
#
#
# clast main: Запись эфира
# clasts: [('Запись', tensor([0.9424]))]
#
#
# clast main: Встроенный медиаплеер
# clasts: []
#
#
# clast main: Управление телевизором
# clasts: []
#
#
# clast main: Изогнутый экран
# ...
# clasts: []
#
#
# clast main: Тип нагревателя аэрогриля
# clasts: []
#
#
# clast main: Тип ритуального аксессуара
# clasts: []
#
#
# clast main: Таблетки в комплекте
# clasts: []
#
#
# clast main: Форма теплицы
# clasts: []
#
#
# clast main: Тип аксессуара для жалюзи
# clasts: []
#
#
# clast main: Размер тыловых колонок, см
# clasts: [('Размер фронтальных колонок, см', tensor([0.9407]))]
#
#
# clast main: Тип усилителя
# clasts: []
#
#
# clast main: Количество тарифов
# clasts: []
#
#
# clast main: Индикация родительского блока
# clasts: []
#
#
# clast main: Вид судомодели
# clasts: []
#
#
# clast main: Форма горнолыжной палки
# clasts: []
#
#
# clast main: Стандарт радиотелефона
# clasts: []
#
#
# clast main: Вид комплектующего для активаторов
# clasts: []
#
#
# clast main: Тематика адвент-календаря
# clasts: []
#
#
# clast main: Тип пожарного инвентаря
# clasts: []
#
#
# clast main: Назначение ареометра
# clasts: []
#
#
# clast main: Диапазон измерения этилового спирта
# clasts: []
#
#
# clast main: Транспортировочный элемент
# clasts: []
#
#
# clast main: Вид гладильной доски
# clasts: []
#
#
# clast main: Применение растворителя и очистителя
# clasts: []
#
#
# clast main: Тип тяжелоатлетического диска
# clasts: []
#
#
# clast main: Длина иглы
# clasts: []
#
#
# clast main: Цвет лазера
# clasts: []
#
#
# clast main: Тип эквалайзера
# clasts: []
#
#
# clast main: Вид аксессуара для натяжного потолка
# clasts: []
#
#
# clast main: Материал спирали штопора
# clasts: []
#
#
# clast main: Радиус поворота
# clasts: []
#
#
# clast main: Вкус (энергетик)
# clasts: []
#
#
# clast main: Вид латодержателя
# clasts: []
#
#
# clast main: Вид съемника
# clasts: [('Вид намордника', tensor([0.9312]))]
#
#
# clast main: Йодированная
# clasts: []
#
#
# clast main: Скользящая поверхность лыж
# clasts: []
#
#
# clast main: Вид тисков
# clasts: []
#
#
# clast main: Состав стартового набора для животного
# clasts: []
#
#
# clast main: Форма нити
# clasts: []
#
#
# clast main: Как подобрать форму зубной нити
# clasts: []
#
#
# clast main: Способ обработки молока
# clasts: []
#
#
# clast main: Расположение фазоинвертера
# clasts: []
#
#
# clast main: Форма выпуска аптечки
# clasts: []
#
#
# clast main: Конструкция столика
# clasts: []
#
#
# clast main: Установка камина
# clasts: []
#
#
# clast main: Особенности камина
# clasts: []
#
#
# clast main: Тип фотопленки
# clasts: []
#
#
# clast main: Тип управления светорегулятором
# clasts: []
#
#
# clast main: Погодные условия
# clasts: []
#
#
# clast main: С музыкой
# clasts: [('Мелодии', tensor([0.9427]))]
#
#
# clast main: Движение шара
# clasts: []
#
#
# clast main: Вид ходунков
# clasts: []
#
#
# clast main: Размер воротника
# clasts: []
#
#
# clast main: Отстегивающийся темляк
# clasts: []
#
#
# clast main: Вид тяги
# clasts: []
#
#
# clast main: Вид хирургического инструмента
# clasts: []
#
#
# clast main: Особенности горнолыжной маски
# clasts: []
#
#
# clast main: Вид весов
# clasts: []
#
#
# clast main: Механизм дивертора
# clasts: []
#
#
# clast main: Вид лестницы
# clasts: [('Тип лестницы', tensor([0.9805])), ('Тип элемента лестницы', tensor([0.9466]))]
#
#
# clast main: Механизм поднятия головы
# clasts: []
#
#
# clast main: Наличие функции самоочищения
# clasts: []
#
#
# clast main: Особенности стерилизаторов и подогревателей
# clasts: []
#
#
# clast main: Управление воспроизведением
# clasts: []
#
#
# clast main: Русификация
# clasts: []
#
#
# clast main: Вид заболевания
# clasts: []
#
#
# clast main: Вид аксессуара для палатки, тента, шатра
# clasts: []
#
#
# clast main: Тип RFID считывателя
# clasts: []
#
#
# clast main: Система измельчения
# clasts: []
#
#
# clast main: Оповещение о радаре
# clasts: []
#
#
# clast main: Назначение почтового ящика
# clasts: [('Материал почтового ящика', tensor([0.9281]))]
#
#
# clast main: Насадки эпилятора
# clasts: []
#
#
# clast main: Способ соединения труб
# clasts: []
#
#
# clast main: Назначение шкафа
# clasts: []
#
#
# clast main: Форма небесного фонарика
# clasts: []
#
#
# clast main: Тип RFID карт
# clasts: []
#
#
# clast main: Назначение рогатки
# clasts: []
#
#
# clast main: Упаковка швейного набора
# clasts: []
#
#
# clast main: Совместимые модели минимоек
# clasts: []
#
#
# clast main: Тип управления (PTZ)
# clasts: []
#
#
# clast main: Вид аксессуара для снаряжения патронов
# clasts: [('Тип аксессуара для оружейного магазина', tensor([0.9425]))]
#
#
# clast main: Копчение
# clasts: []
#
#
# clast main: Вид волана
# clasts: []
#
#
# clast main: Вид бигудей
# clasts: []
#
#
# clast main: Скорости эпилятора
# clasts: []
#
#
# clast main: Назначение насосной части
# clasts: []
#
#
# clast main: Вид запчасти лебедки
# clasts: []
#
#
# clast main: Точность
# clasts: []
#
#
# clast main: Персоны в книге
# clasts: []
#
#
# clast main: Степень затемнения в осветленном состоянии
# clasts: []
#
#
# clast main: Запчасть для снегоуборщика
# clasts: []
#
#
# clast main: Шаг измерения
# clasts: []
#
#
# clast main: Выборка четверти
# clasts: []
#
#
# clast main: Назначение щетки
# clasts: []
#
#
# clast main: Установочная глубина
# clasts: []
#
#
# clast main: Функции радио-будильника
# clasts: []
#
#
# clast main: Материал кувшина
# clasts: []
#
#
# clast main: Вид торта
# clasts: []
#
#
# clast main: Начинка
# clasts: []
#
#
# clast main: Особенности очков для беговых лыж
# clasts: []
#
#
# clast main: Способ брошюровки
# clasts: []
#
#
# clast main: Применение термометра
# clasts: [('Назначение термометра', tensor([0.9593]))]
#
#
# clast main: Особенности скейтов и скутеров
# clasts: []
#
#
# clast main: Вид штангенциркуля
# clasts: []
#
#
# clast main: Тип инструмента для брекетов
# clasts: []
#
#
# clast main: Вид расходных материалов для брекетов
# clasts: []
#
#
# clast main: Вид аксессуара для фасадных панелей
# clasts: []
#
#
# clast main: Размер манжеты
# clasts: []
#
#
# clast main: Максимальная температура эксплуатации
# clasts: []
#
#
# clast main: Вид наркотического вещества
# clasts: []
#
#
# clast main: Назначение кондитерской насадки
# clasts: []
#
#
# clast main: Платформа беговых лыж
# clasts: []
#
#
# clast main: Баланс ракетки
# clasts: []
#
#
# clast main: Жесткость стрежня
# clasts: []
#
#
# clast main: Вид антикражной системы
# clasts: []
#
#
# clast main: Форма выпуска удобрений для аквариумных растений
# clasts: []
#
#
# clast main: Тип медицинских ножниц
# clasts: []
#
#
# clast main: Регулировки качелей/шезлонга
# clasts: []
#
#
# clast main: Высота живой ёлки, см
# clasts: []
#
#
# clast main: Вид слинга
# clasts: []
#
#
# clast main: Вид морепродуктов
# clasts: []
#
#
# clast main: Назначение черенка
# clasts: []
#
#
# clast main: Тип пакета медицинского
# clasts: []
#
#
# clast main: Намотка красящей ленты
# clasts: [('Материал красящей ленты', tensor([0.9518])), ('Цвет ленты', tensor([0.9227]))]
#
#
# clast main: Назначение 3D очков
# clasts: []
#
#
# clast main: Диапазон измерений, мм
# clasts: []
#
#
# clast main: Область применения кулинарных инструментов
# clasts: []
#
#
# clast main: Секундный
# clasts: []
#
#
# clast main: Вид дровницы
# clasts: [('Тип резьбы дровокола', tensor([0.9301]))]
#
#
# clast main: Армирование
# clasts: []
#
#
# clast main: Особенности велокресел
# clasts: []
#
#
# clast main: Форма лыж
# clasts: []
#
#
# clast main: Вид солода
# clasts: [('Особенности солода', tensor([0.9342]))]
#
#
# clast main: Функции туризма и навигации
# clasts: []
#
#
# clast main: Вид флипчарта
# clasts: []
#
#
# clast main: Держатель блокнота
# clasts: []
#
#
# clast main: Уничтожаемые материалы
# clasts: []
#
#
# clast main: Зернистость, грит
# clasts: []
#
#
# clast main: Тематика наборов для лепки
# clasts: []
#
#
# clast main: Звуковой чип
# clasts: []
#
#
# clast main: Характеристики ЦАП/АЦП
# clasts: []
#
#
# clast main: Чувствительность к нажатию
# clasts: []
#
#
# clast main: Особенности графического планшета
# clasts: []
#
#
# clast main: Дискретный возраст
# clasts: []
#
#
# clast main: Тип дрона
# clasts: []
#
#
# clast main: Назначение иглы
# clasts: []
#
#
# clast main: Особенности касок
# clasts: []
#
#
# clast main: Тип регулировки оголовья
# clasts: []
#
#
# clast main: Антистатический эффект
# clasts: []
#
#
# clast main: Технология солнечной батареи
# clasts: []
#
#
# clast main: Назначение клея
# clasts: []
#
#
# clast main: Эффект лечебного средства
# clasts: []
#
#
# clast main: Размер сабвуфера, см
# clasts: []
#
#
# clast main: Гарантия страховой компании
# clasts: []
#
#
# clast main: Тип открытия/поднятия пресса
# clasts: []
#
#
# clast main: Тип антисептика
# clasts: []
#
#
# clast main: Размещение бара
# clasts: []
#
#
# clast main: Формат плитки, см
# clasts: []
#
#
# clast main: Индикация велокомпьютера
# clasts: []
#
#
# clast main: Механизм складывания палки
# clasts: []
#
#
# clast main: Вид средства для бороды
# clasts: []
#
#
# clast main: Крышка аэрогриля
# clasts: []
#
#
# clast main: Диаметр входа, дюйм
# clasts: []
#
#
# clast main: Вид крахмала
# clasts: []
#
#
# clast main: Высота, юниты
# clasts: []
#
#
# clast main: Размерная сетка в EPG
# clasts: []
#
#
# clast main: Форма маховика
# clasts: []
#
#
# clast main: Пол манекена
# clasts: [('Вид манекена', tensor([0.9384]))]
#
#
# clast main: Размер манекена
# clasts: []
#
#
# clast main: Принцип действия бетоносмесителя
# clasts: []
#
#
# clast main: Венец
# clasts: []
#
#
# clast main: Назначение геля
# clasts: []
#
#
# clast main: Уровень вязкости
# clasts: []
#
#
# clast main: Смыв
# clasts: []
#
#
# clast main: Тип управления духовым шкафом
# clasts: []
#
#
# clast main: Размер центрального канала, см
# clasts: []
#
#
# clast main: Шторка
# clasts: []
#
#
# clast main: Вид аксессуара для танцев
# clasts: []
#
#
# clast main: Наличие сигнатурного анализа
# clasts: []
#
#
# clast main: Режимы радар-детектора
# clasts: []
#
#
# clast main: Вид аксессуара для мобильных ограждений
# clasts: []
#
#
# clast main: Вид аксессуара для лука, арбалета, рогатки
# clasts: []
#
#
# clast main: Вид букета
# clasts: []
#
#
# clast main: Форма выпуска хлеба
# clasts: [('Вид хлеба', tensor([0.9330]))]
#
#
# clast main: Сорт хлеба
# clasts: []
#
#
# clast main: Назначение добавки
# clasts: []
#
#
# clast main: Материал зубной нити
# clasts: [('Фактура зубной нити', tensor([0.9746]))]
#
#
# clast main: Тип скальпеля
# clasts: []
#
#
# clast main: Вид мангала
# clasts: []
#
#
# clast main: Вид флакона
# clasts: []
#
#
# clast main: Способ заправки флакона
# clasts: []
#
#
# clast main: Насадка для заправки
# clasts: []
#
#
# clast main: Спецификация ISO-4925
# clasts: []
#
#
# clast main: Подключение вентиля
# clasts: []
#
#
# clast main: Размер бумажного фильтра
# clasts: [('Форма бумажного фильтра', tensor([0.9331]))]
#
#
# clast main: Особенности скалки
# clasts: []
#
#
# clast main: Аксессуар для гидропомпы
# clasts: [('Аксессуар для помпы', tensor([0.9257]))]
#
#
# clast main: Размер чипа мозаики, мм
# clasts: []
#
#
# clast main: Возраст для смеси
# clasts: []
#
#
# clast main: Особенности молокоотсосов
# clasts: []
#
#
# clast main: Регулировка силы сцеживания
# clasts: []
#
#
# clast main: Цвет пива
# clasts: [('Вид пива', tensor([0.9506])), ('Вкус пива', tensor([0.9329]))]
#
#
# clast main: Наполнение террасной доски
# clasts: [('Поверхность террасной доски', tensor([0.9544]))]
#
#
# clast main: Особенности пленки для окон
# clasts: []
#
#
# clast main: Словари
# clasts: []
#
#
# clast main: Форма отверстия
# clasts: []
#
#
# clast main: Вид аксессуара для окон
# clasts: []
#
#
# clast main: Двустороннее сканирование
# clasts: []
#
#
# clast main: Вид оборудования для сенсорной комнаты
# clasts: []
#
#
# clast main: Размер слинга/кенгуру
# clasts: []
#
#
# clast main: Назначение емкости для алкоголя
# clasts: []
#
#
# clast main: Вид обезжиривателя
# clasts: []
#
#
# clast main: Подключение денежного ящика
# clasts: []
#
#
# clast main: Вид арбалета / лука
# clasts: []
#
#
# clast main: Аксессуар для мольберта
# clasts: []
#
#
# clast main: Вид аксессуара для конного спорта
# clasts: []
#
#
# clast main: Вид средства для ремонта и ухода
# clasts: []
#
#
# clast main: Вид запчасти кассового оборудования
# clasts: [('Комплектация кассового оборудования', tensor([0.9508]))]
#
#
# clast main: Особенности трубочек
# clasts: []
#
#
# clast main: Ширина груди, см
# clasts: []
#
#
# clast main: Вид медицинской мебели
# clasts: []
#
#
# clast main: Вид расходника, аксессуара для бильярда
# clasts: []
#
#
# clast main: Вид добавки в раствор
# clasts: []
#
#
# clast main: Размер изделий на выходе
# clasts: []
#
#
# clast main: Размеры гамака (-ов)
# clasts: []
#
#
# clast main: Диаметр бигуди
# clasts: []
#
#
# clast main: Вид робототехнического модуля
# clasts: []
#
#
# clast main: Тип установки полки
# clasts: []
#
#
# clast main: Упаковка автомобильной аптечки
# clasts: []
#
#
# clast main: Размещение стоппера
# clasts: []
#
#
# clast main: Вид краг
# clasts: []
#
#
# clast main: Тип корпуса рециркулятора
# clasts: []
#
#
# clast main: Вид аксессуара для детского транспорта
# clasts: []
#
#
# clast main: Измерение SpO2
# clasts: []
#
#
# clast main: Вид пульсоксиметра
# clasts: []
#
#
# clast main: Вид мармита
# clasts: []
#
#
# clast main: Вид плетения цепочки
# clasts: []
#
#
# clast main: Форма сборки
# clasts: []
#
#
# clast main: Макс. толщина стекол, мм
# clasts: []
#
#
# clast main: Вид аксессуара для металлоискателя
# clasts: []
#
#
# clast main: Вид чехла для принадлежностей барбекю
# clasts: []
#
#
# clast main: Детские украшения
# clasts: []
#
#
# clast main: Тип крепления двигателя
# clasts: []
#
#
# clast main: Типоразмер счетчика газа
# clasts: [('Тип счетчика газа', tensor([0.9810]))]
#
#
# clast main: Цвет вина
# clasts: []
#
#
# clast main: Температура подачи
# clasts: []
#
#
# clast main: Вид мороженицы
# clasts: []
#
#
# clast main: Материал корпуса машинки
# clasts: []
#
#
# clast main: Тип расходного материала для хирургии
# clasts: []
#
#
# clast main: Вид питания лодочного мотора
# clasts: []
#
#
# clast main: Вид тапочек/стелек
# clasts: []
#
#
# clast main: Вид имплантов
# clasts: []
#
#
# clast main: Закаленный
# clasts: []
#
#
# clast main: Тип самовара
# clasts: []
#
#
# clast main: Вид инструмента для дорожных работ
# clasts: []
#
#
# clast main: Целевая аудитория в Мебели
# clasts: []
#
#
# clast main: Класс вязкости по ISO
# clasts: []
#
#
# clast main: Усилие закрывания
# clasts: []
#
#
# clast main: Вид генератора спецэффектов
# clasts: []
#
#
# clast main: Температура замерзания, °C
# clasts: []
#
#
# clast main: Теплоноситель
# clasts: []
#
#
# clast main: Усилитель ТВ-сигнала
# clasts: []
#
#
# clast main: Вид йогурта
# clasts: []
#
#
# clast main: Наличие линзы
# clasts: []
#
#
# clast main: Вид стерилизатора
# clasts: []
#
#
# clast main: Тип крепления веток
# clasts: []
#
#
# clast main: Способ подключения карты захвата
# clasts: []
#
#
# clast main: Валюта
# clasts: []
#
#
# clast main: Вид надгробия
# clasts: []
#
#
# clast main: Сохранность
# clasts: []
#
#
# clast main: Сорт винограда
# clasts: []
#
#
# clast main: Число и исполнение контактов
# clasts: []
#
#
# clast main: Вид комплектующих для очков
# clasts: []
#
#
# clast main: Вид аппаратной процедуры
# clasts: []
#
#
# clast main: Применение трубореза
# clasts: []
#
#
# clast main: Форма сайдинга
# clasts: []
#
#
# clast main: Размер детского фартука
# clasts: []
#
#
# clast main: Основа стеклохолста
# clasts: []
#
#
# clast main: Тип бумаги для полиграфии
# clasts: []
#
#
# clast main: Вид полиграфического аппарата
# clasts: []
#
#
# clast main: Особенности АКБ
# clasts: []
#
#
# clast main: Тип аксессуара для аквагрима
# clasts: []
#
#
# clast main: Регион происхождения
# clasts: []
#
#
# clast main: Авторская работа
# clasts: []
#
#
# clast main: Предмет искусства
# clasts: []
#
#
# clast main: Вид средства/аксессуара для стомы
# clasts: []
#
#
# clast main: Модель балеток
# clasts: []
#
#
# clast main: Клеевой слой
# clasts: []
#
#
# clast main: Вид костылей
# clasts: []
#
#
# clast main: Тип иглы для биопсии
# clasts: []
#
#
# clast main: Подходящий размер обуви
# clasts: []
#
#
# clast main: Тип химии для ювелирных работ
# clasts: []
#
#
# clast main: Вид сауны/кабины
# clasts: []
#
#
# clast main: Вид кирпича
# clasts: [('Формат кирпича', tensor([0.9437])), ('Поверхность кирпича', tensor([0.9414]))]
#
#
# clast main: Пустотность
# clasts: []
#
#
# clast main: Маркировка прочности
# clasts: []
#
#
# clast main: Тип укладки и набора
# clasts: []
#
#
# clast main: Регулируемая
# clasts: []
#
#
# clast main: Тип запчасти для тату-машинки
# clasts: []
#
#
# clast main: Назначение опоры
# clasts: []
#
#
# clast main: Особенности электро-гаджета
# clasts: []
#
#
# clast main: Тип свистка
# clasts: []
#
#
# clast main: Вид аксессуара для тяжелой атлетики
# clasts: []
#
#
# clast main: Сертификация шлема
# clasts: []
#
#
# clast main: Особенности циркуля
# clasts: []
#
#
# clast main: Спектр волн
# clasts: []
#
#
# clast main: Вид опечатывающего устройства
# clasts: []
#
#
# clast main: Макс. грузоподъемность термопривода
# clasts: []
#
#
# clast main: Вид лузы
# clasts: []
#
#
# clast main: Сукно
# clasts: []
#
#
# clast main: Рост в холке, см
# clasts: []
#
#
# clast main: Вид декора для воздушного шара
# clasts: []
#
#
# clast main: Вид алкотестера
# clasts: []
#
#
# clast main: Вид аксессуара для сауны
# clasts: []
#
#
# clast main: Тип ларингоскопа
# clasts: []
#
#
# clast main: Беспроводные интерфейсы электротранспорта
# clasts: []
#
#
# clast main: Тип подвеса
# clasts: []
#
#
# clast main: Вид мезонитей
# clasts: []
#
#
# clast main: Вид аксессуара для яхты
# clasts: []
#
#
# clast main: Шланг в комплекте
# clasts: []
#
#
# clast main: Система скручивания шланга
# clasts: []
#
#
# clast main: Вид гранаты
# clasts: [('Наполнитель гранаты', tensor([0.9282]))]
#
#
# clast main: Размер блоттера, мм
# clasts: []
#
#
# clast main: Аппелласьон
# clasts: []

# %%
num_attr_length = len()
